# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Trabajo de Fin de Máster</title>
#     <!-- Cargar MathJax para renderizar ecuaciones LaTeX -->
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS_HTML"></script>
#     <style>
#         /* Estilos generales según APA 7 */
#         body {
#             font-family: Arial, sans-serif;
#             font-size: 11pt;
#             line-height: 2; /* Doble espaciado */
#             margin: 2.54cm; /* Márgenes de 1 pulgada */
#             text-align: justify;
#         }
#         /* Indentación de párrafos */
#         p {
#             margin: 0 0 0 1.27cm; /* Indentación de 0.5 pulgadas solo en la primera línea */
#             text-indent: 1.27cm;
#         }
#         /* Encabezados según APA 7 */
#         h1 {
#             font-size: 11pt;
#             font-weight: bold;
#             text-align: center;
#             margin-top: 24pt;
#             margin-bottom: 12pt;
#         }
#         h2 {
#             font-size: 11pt;
#             font-weight: bold;
#             text-align: left;
#             margin-top: 18pt;
#             margin-bottom: 6pt;
#         }
#         h3 {
#             font-size: 11pt;
#             font-weight: bold;
#             font-style: italic;
#             text-align: left;
#             margin-top: 18pt;
#             margin-bottom: 6pt;
#         }
#         /* Numeración de páginas en la esquina superior derecha */
#         @media print {
#             body::after {
#                 content: counter(page);
#                 position: fixed;
#                 top: 0;
#                 right: 2.54cm;
#                 font-size: 11pt;
#             }
#             body {
#                 counter-reset: page 1;
#             }
#             .page-break {
#                 page-break-before: always;
#             }
#         }
#         /* Estilo para ecuaciones LaTeX */
#         .MathJax {
#             font-size: 11pt !important;
#         }
#         /* Lista con numeración APA */
#         ol {
#             margin-left: 1.27cm;
#             list-style-type: decimal;
#         }
#         ul {
#             margin-left: 1.27cm;
#             list-style-type: disc;
#         }
#     </style>
# </head>
# <body>
#     <!-- Título del documento en el notebook -->
#     <h1>Financiando Equipos para la Industria Camaronera en Ecuador: Factoring y Arbitraje para Consolidar una Start-Up en el Sector</h1>
#     <!-- Instrucción para Pandoc: no incluir esta celda en la exportación -->
#     <p style="display: none;"> jupytext: { "cell_metadata_filter": "-all" } </p>
# </body>
# </html>
# Trabajo de Fin de Máster – 2 3400_11 Grupo 2
#
# Financiando Equipos para la Industria Camaronera en Ecuador:
# Factoring y Arbitraje para Consolidar una Start-Up en el Sector
#
# Tutor
# Martí Pachamè Barrera
#
# Integrantes
# Niño Gavilán, Deisy Marisol
# Rodriguez Sixto, Luis Angel
# Sottoli Di Tore, Gian Carlo
# Vinatea Barberena, Luis Paulo
# ## Agradecimientos
#
# Nely Apolo Carrión
# Acuicultura Beraqua Aquiber S.A.
# ## **Abstract**
#
# This thesis proposes the creation of an innovative financial company to provide credit to Ecuadorian shrimp farmers for acquiring aeration systems, enhancing operational efficiency, environmental sustainability, and profitability. Using an empirical-inductive approach with quantitative support, it analyzes Ecuador’s macroeconomic context, the shrimp sector’s financing challenges, and the economic viability of high-efficiency aerators. Financial projections, optimized via stochastic simulation, yield a Net Present Value of $34,156, a Return on Investment of 26.57%, and an Enterprise Value of $572,688 (DCF model), confirming feasibility. Switzerland is identified as the optimal funding source.
#
# **Keywords:** **Shrimp**, **Aquaculture**, **Financing**, **Aeration**, **Sustainability**, **Ecuador**, **Business Model**, **Viability**
# ## **Tabla de Contenidos**
#
# **Capítulo I: Introducción y Contexto del Sector Camaronero**
# - 1.1. Introducción
# - 1.2. Análisis Macroeconómico de Ecuador
# - 1.3. Análisis de la Industria Camaronera en Ecuador
# - 1.4. Objetivos del Proyecto
# - 1.5. Pregunta Fundamental de la Investigación
# - 1.6. Metodología Empleada
#   - 1.6.1. Fuentes de Información
#   - 1.6.2. Procesamiento y Análisis de Datos
#   - 1.6.3. Validación y Justificación
# - 1.7. Marco Teórico
#   - 1.7.1. Aireación y Calidad del Agua en Acuicultura
#   - 1.7.2. Puente hacia la Economía: Ganancias de Escala y Curvas de Costo
#   - 1.7.3. Costos de Oportunidad y la Inversión en Aireadores
# - 1.8. ¿Por Qué Apostar por los Aireadores de Alta Gama?
#   - 1.8.1. Análisis Técnico y Costo Total de Propiedad (CTP)
#   - 1.8.2. Vida Útil y Frecuencia de Reemplazo: Un Factor Crítico en el CTP
#   - 1.8.3. Eficiencia Relativa y Consumo Energético: El Impacto de las RPM
#   - 1.8.4. Ventajas Económicas: TIR e Índice de Costo-Efectividad (ICE)
#   - 1.8.5. Gestión del Riesgo y Solvencia del Sector Camaronero
#
# **Capítulo II: Modelo de Negocio de la Empresa Financiera**
# - 2.1. Modelo de Negocio de la Empresa Financiera
# - 2.2. Constitución y Tipo de Sociedad
# - 2.3. Análisis Comparativo de Fuentes de Financiamiento Internacional
#   - 2.3.1. Marco Legal y Operacional por Jurisdicción
#   - 2.3.2. Contexto y Definición de Factoring
#   - 2.3.3. Viabilidad y Plan de Acción Detallado por Jurisdicción
#     - 2.3.3.1. Financiamiento en Estados Unidos
#     - 2.3.3.2. Financiamiento en Suiza
#     - 2.3.3.3. Financiamiento en la Eurozona
#     - 2.3.3.4. Financiamiento en Japón
#   - 2.3.4. Implicaciones Fiscales y Estructura Corporativa
# - 2.4. Estructura de Ingresos de la Empresa
# - 2.5. Costos Operativos
# - 2.6. Gestión de Liquidez y Estrategia de Riesgo
#   - 2.6.1. Paso 1: Obtención del Crédito Externo
#   - 2.6.2. Paso 2: Conversión de Fondos en Créditos a Productores Camaroneros
#   - 2.6.3. Paso 3: Gestión de Pagos y Riesgo de Impago
#   - 2.6.4. Paso 4: Rentabilidad y Expansión del Modelo
#
# **Capítulo III: Viabilidad del financiamiento en el extranjero**
# - 3.1. Fundamento Teórico: Paridad del Poder Adquisitivo (PPA)
# - 3.2. Fórmula del Diferencial de Inflación Logarítmico
# - 3.5. Resultados
#   - 3.5.1. Impuestos Corporativos Más Bajos
#   - 3.5.2. Fuentes de Préstamo con Tasas Base Más Bajas
#   - 3.5.3. Divisas con Menor Costo de Hedging
#   - 3.5.4. Mayor Ganancia Ajustada por Riesgo e Impuestos
#   - 3.5.5. Conclusiones Clave sobre la Lucratividad Ajustada por Riesgo
#
# **Capítulo IV: Plan de Financiamiento a Camaroneras**
# - 4.1. Introducción al plan de financiamiento
# - 4.2. Justificación del financiamiento a camaroneras
# - 4.3. Selección de países para el financiamiento
# - 4.4. Criterios de elegibilidad para camaroneras
# - 4.5. Mecanismo de financiamiento
# - 4.6. Condiciones del financiamiento
# - 4.7. Riesgos y mitigación
#
# **Capítulo V: Flujos y Proyecciones**
# - 5.1. Análisis de Sensibilidad
# - 5.2. Optimización mediante Simulación Estocástica
#   - 5.2.1. Resultados
#
# **Capítulo VI: Conclusiones y Recomendaciones Finales**
#
# **Referencias**
#
# ## **Resumen Ejecutivo**
#
# El sector camaronero ecuatoriano es un pilar clave de la economía nacional, destacado como el principal exportador no petrolero y generador de divisas. Sin embargo, enfrenta desafíos significativos, como el acceso limitado a financiamiento, que restringe la adopción de tecnologías esenciales como los sistemas de aireación, necesarios para mejorar la productividad y la sostenibilidad. Esta tesis propone la creación de una empresa financiera innovadora que otorgue créditos a camaroneras para adquirir dichos sistemas, promoviendo eficiencia operativa, sostenibilidad ambiental y rentabilidad.
#
# La investigación adopta un enfoque empírico-inductivo con soporte cuantitativo, utilizando datos de actores del sector, especificaciones técnicas y registros aduaneros. El análisis macroeconómico resalta la contribución del sector a la balanza comercial de Ecuador, a pesar de retos como altas tasas de interés y restricciones crediticias para PYMEs. El marco teórico vincula principios de acuicultura (calidad del agua y aireación) con conceptos económicos (economías de escala y costos de oportunidad), justificando la inversión en aireadores de alta gama, que ofrecen mayor eficiencia y menores costos a largo plazo según el análisis técnico-económico.
#
# El modelo de negocio plantea captar capital a bajo costo en mercados internacionales, priorizando Suiza por sus tasas competitivas (3-5%), y otorgar créditos a camaroneras a un 13% anual. Incluye un plan de financiamiento con un pago inicial del 25% por parte de los productores, criterios de elegibilidad estrictos y estrategias de mitigación de riesgos. Las proyecciones financieras, optimizadas mediante simulación estocástica, muestran un Valor Presente Neto (VPN) positivo de $34,156, un Retorno sobre la Inversión (ROI) del 26.57% y un Valor de la Empresa (EV) de $572,688 según el modelo DCF, confirmando su viabilidad y atractivo.
#
# La tesis concluye que el modelo es factible y puede fortalecer el sector camaronero, recomendando su implementación con un enfoque en Suiza como fuente de financiamiento y alianzas estratégicas para maximizar el impacto.
#
#
# **Palabras clave:** **Camarón**, **Acuicultura**, **Ecuador**, **Financiamiento**, **Empresa financiera**, **Aireación**, **Sostenibilidad**, **Macroeconomía**, **Tasas de interés**, **Viabilidad**
# ## **Capítulo I: Introducción y Contexto del Sector Camaronero**
#
#
# ### **1.1. Introducción**
#
#
# El sector camaronero ecuatoriano representa un **pilar fundamental de la economía**, erigiéndose como uno de los principales rubros de **exportación no petrolera** del país.  A lo largo de las últimas décadas, Ecuador se ha consolidado como un **actor clave en el mercado global de camarón**, abasteciendo a consumidores en todo el mundo y generando divisas cruciales para el desarrollo nacional. Sin embargo, a pesar de su importancia y potencial intrínseco, el sector enfrenta **desafíos significativos que limitan su crecimiento y competitividad sostenibles**. Entre estos desafíos, destaca la **limitada disponibilidad de financiamiento adecuado y accesible** para los productores, crucial para la adopción de tecnologías que impulsen la productividad y la sostenibilidad, como los **sistemas de aireación**.
#
#
# La presente tesis aborda esta problemática crítica del financiamiento en el sector camaronero ecuatoriano.  Se propone el desarrollo de un **modelo de negocio para una empresa financiera innovadora**, diseñada específicamente para **proveer soluciones de crédito a las camaroneras**.  Esta empresa se enfocaría en facilitar el acceso a capital para la **adquisición de tecnologías esenciales**, inicialmente los sistemas de aireación. El objetivo primordial es impulsar la **eficiencia operativa, la sostenibilidad ambiental y la rentabilidad** de los productores camaroneros en Ecuador.  A través de un análisis exhaustivo de la viabilidad financiera y operativa de este modelo, esta investigación busca contribuir al **fortalecimiento del sector camaronero ecuatoriano**, impulsando su capacidad para enfrentar los retos del mercado global y consolidar su rol como motor de la economía nacional.
#
#
# ### **1.2. Análisis Macroeconómico de Ecuador**
#
#
# Analizar el **contexto macroeconómico ecuatoriano** reviste gran importancia, particularmente al considerar la **prominencia de la industria camaronera**, principal producto de exportación no petrolero del país.
#
#
# *   Durante el **primer trimestre de 2024**, Ecuador demostró una **balanza comercial positiva**:
#     *   **Superávit:** **$561 millones de dólares**.
#     *   **Exportaciones:** **$8,543 millones**.
#     *   **Importaciones:** **$7,982 millones**.
#     *   Este superávit subraya la **contribución significativa** del sector camaronero a la economía ecuatoriana.
#
#
# *   En **abril de 2024**, las exportaciones de camarón ecuatoriano alcanzaron un **volumen mensual récord de 111,512 toneladas**.
#     *   Sin embargo, en el periodo acumulado de **enero a abril de 2024**, se observó una **disminución del 13%** en el **valor total de las exportaciones** comparado con 2023, totalizando **USD 2,169 millones**.
#     *   Esta **divergencia entre volumen y valor** evidencia **tensiones** en el sector, influenciadas por:
#         *   **Fluctuaciones en precios internacionales**.
#         *   **Condiciones del mercado**.
#     *   A pesar de la disminución en valor, el **volumen de exportación aumentó** un **28% y 32%** en abril de 2024.
#     *   Esta dinámica se mantiene por la **diversificación de mercados**, aunque existen **retos comerciales**.
#
#
# *   A lo largo de **2024**, el sector camaronero ecuatoriano enfrentó **diversos obstáculos**:
#     *   **Investigaciones, aranceles y bloqueos comerciales** en mercados clave como **China y Estados Unidos**, complicando **acceso y rentabilidad**.
#     *   **Suspensión de importaciones de camarón ecuatoriano por Brasil** a partir de diciembre de 2024, añadiendo presión a los exportadores.
#     *   El camarón aporta **más del 20% de las divisas** por exportaciones en Ecuador, siendo un **pilar fundamental de la economía**.
#     *   Entre **enero y mayo de 2024**, el **valor exportado se redujo un 8.4%** comparado con 2023, reflejando:
#         *   **Desafíos internacionales**.
#         *   **Condiciones económicas globales**.
#     *   La **apreciación del dólar estadounidense** frente a monedas de competidores como **India y Vietnam** genera desafíos para la **competitividad**.
#
#
# En este contexto, la **adopción de aireadores de alta eficiencia** surge como una **estrategia mitigadora crucial**, ya que:
#
#
# *   **Reducen costos operativos**.
# *   **Incrementan la productividad**.
#
#
# *   La **demanda creciente de camarón sostenible** en mercados *premium*
# **fortalece a camaroneras ecuatorianas** con **tecnologías avanzadas**.
# *   La **energía eléctrica** es un **costo operativo significativo** para camaroneras.
#
#
# *   Aireadores de Beraqua pueden **reducir este costo entre 10% y 20%**, mejorando la **rentabilidad**.
# *   **Incentivos fiscales y créditos verdes** para proyectos de **optimización de agua y energía** en 2025.
#
#
# *   Se anticipa mayor adopción de **tecnologías para productividad y estándares ambientales**.
# *   Este crecimiento refleja el **potencial del sector para consolidar su liderazgo global**
# mediante **innovación y sostenibilidad**.
#
#
# *   A pesar de retos, el sector camaronero ecuatoriano muestra **adaptación y resiliencia**,
# buscando **nuevos mercados y estrategias comerciales**.
# *   Este análisis enfatiza la **importancia estratégica del camarón**
# y la necesidad de **soluciones innovadoras y colaborativas**
# para asegurar la **sostenibilidad a largo plazo**.
#
#
# Ecuador, con **economía dolarizada**, ha experimentado **fluctuaciones macroeconómicas** por factores **internos y externos**.
#
#
# *   La **estabilidad macroeconómica** es **fundamental** para el sector productivo, especialmente el **camaronero**.
# *   Su **competitividad** depende de **previsibilidad de costos y planificación a largo plazo**.
# *   La **dolarización** aporta **estabilidad cambiaria**, pero implica **menor flexibilidad monetaria y dependencia de capital externo**.
#
#
# Profundizando en el **mercado de crédito ecuatoriano**:
#
#
# *   Es **crucial destacar características y desafíos específicos**.
# *   El **sistema financiero ecuatoriano**, aunque desarrollado, presenta **particularidades** que influyen en el **acceso y costo del financiamiento**, especialmente para el **sector productivo**.
#
#
# En cuanto a las **tasas de interés**, los datos recientes revelan un panorama donde, incluso en dólares, el costo del crédito es considerablemente elevado en comparación con economías desarrolladas como Estados Unidos.  Según información del mercado ecuatoriano, las tasas de interés **mínimas** y **máximas** promedio por categoría de crédito productivo se sitúan en los siguientes rangos:
#
#
# *   **Crédito Productivo Corporativo:**  Entre el 9.33% y el 10.93%.  Este segmento, destinado a grandes empresas, ya refleja tasas relativamente altas.
#
#
# *   **Crédito Productivo Empresarial:**  Aún más elevadas, entre el 11.92% y el 13.89%.  Este tipo de crédito, dirigido a empresas medianas, muestra un incremento en el costo financiero.
#
#
# *   **Crédito Productivo PYMES:**  Similar al empresarial, con tasas entre el 11.04% y el 12.80%.  Las pequeñas y medianas empresas, que conforman la mayoría del tejido empresarial ecuatoriano y del sector camaronero, enfrentan este alto costo de capital.
#
#
# *   **Microcrédito:**  Las tasas para microcrédito
# alcanzan niveles significativamente mayores,
# superando el 20% en todos los segmentos.
#
#
# Aunque no directamente comparable con el crédito productivo, estas tasas reflejan el alto costo general del dinero en la economía ecuatoriana, especialmente para segmentos considerados de mayor riesgo.
#
#
# Estas tasas de interés, comparativamente elevadas, representan un **obstáculo significativo para la inversión y el crecimiento**
# del sector productivo ecuatoriano, incluyendo el camaronero.El alto costo del financiamiento **reduce la rentabilidad de los proyectos**, **limita la capacidad de inversión** en modernización tecnológica y expansión, y puede **afectar la competitividad** de las empresas en mercados internacionales.
#
#
# Adicionalmente, es importante considerar la **morosidad** en diferentes sectores de la economía ecuatoriana. Los datos disponibles indican que, en general, la morosidad se mantiene en niveles controlados en algunos sectores clave:
#
#
# *   **Consumo - Tarjeta de Crédito:**  1.08%.  Este sector presenta una morosidad ligeramente más alta en comparación con otros.
# *   **Comercio al por Mayor y al por Menor:** 0.24%.  Morosidad relativamente baja en un sector importante para la economía.
# *   **Agricultura, Ganadería, Silvicultura y Pesca:** **0.12%**.
#
#
# Este dato es particularmente relevante para esta tesis, ya que muestra una **morosidad muy baja en el sector primario, incluyendo la pesca y la acuicultura**. Esto sugiere que, históricamente, el sector ha demostrado ser cumplido en sus obligaciones financieras, lo cual podría ser un factor positivo para la percepción de  riesgo de crédito en este sector.
#
#
# *   **Industrias Manufactureras:** 0.12%.
# *   **Transporte y Almacenamiento:** 0.05%.
# *   **Actividades Inmobiliarias:** 0.01%.
# *   **Actividades Financieras y de Seguros:** 0.01%.
#
#
# La baja morosidad en el sector de "Agricultura, Ganadería, Silvicultura y Pesca" es un dato alentador y podría interpretarse como un indicador de la **solidez financiera y la capacidad de pago de los productores en este sector**, incluyendo las camaroneras.  Sin embargo, es fundamental analizar en detalle las condiciones específicas de crédito ofrecidas al sector y los factores que contribuyen a esta baja morosidad para comprender plenamente el panorama del riesgo crediticio.
#
# A pesar de la relativamente baja morosidad en el sector primario, las **PYMEs en Ecuador generalmente enfrentan dificultades para acceder al crédito**.  Las exigencias de garantías, la falta de historial crediticio formal, la percepción de mayor riesgo por parte de las instituciones financieras y los costos operativos asociados a la evaluación y gestión de créditos a pequeñas empresas, **limitan significativamente las opciones de financiamiento para las PYMEs camaroneras**.
#
# Finalmente, el marco regulatorio del sistema financiero ecuatoriano [Mencionar brevemente regulaciones relevantes, por ejemplo, la supervisión de la Superintendencia de Bancos, regulaciones sobre tasas de interés, encaje bancario, requerimientos de capital, y cualquier regulación específica para el crédito al sector acuícola o primario, si existe].  Estas regulaciones configuran el contexto operativo para las instituciones financieras y tienen un impacto en la disponibilidad y condiciones del crédito.
#
# En resumen, las condiciones macroeconómicas y financieras de Ecuador, caracterizadas por una economía dolarizada, tasas de interés relativamente elevadas, y un mercado de crédito con desafíos de acceso para las PYMEs, **configuran el entorno en el cual se desarrollará el modelo de negocio propuesto en esta tesis**.  A pesar de los desafíos, la baja morosidad histórica en el sector de agricultura y pesca, junto con la vital importancia del sector camaronero para la economía,  sugieren que existe una **necesidad real y una oportunidad viable** para una empresa financiera que ofrezca soluciones de crédito innovadoras y adaptadas a las necesidades específicas de las camaroneras ecuatorianas, contribuyendo a impulsar su crecimiento sostenible y su competitividad en el mercado global.
#
#
# ### **1.3. Análisis de la Industria Camaronera en Ecuador**
#
#
# La industria camaronera ecuatoriana es un **sector de vital importancia**, representando.  Ecuador se distingue a nivel mundial por la **calidad de su camarón** y por la **adopción de prácticas productivas**.
#
# Sin embargo, el sector enfrenta **desafíos persistentes que amenazan su sostenibilidad y potencial de crecimiento**. Entre los principales desafíos se encuentran:
#
#
# *   **Acceso Limitado a Financiamiento:**  Como se mencionó en la introducción, la falta de acceso a financiamiento adecuado y con condiciones favorables es un **obstáculo crítico** para las camaroneras, especialmente para las pequeñas y medianas empresas (PYMEs).
#
#
# *   **Necesidad de Modernización Tecnológica:**  Para mantener la **competitividad en un mercado global exigente**, las camaroneras ecuatorianas requieren invertir en tecnologías que **incrementen la eficiencia productiva, reduzcan costos, y mejoren la calidad del producto**.  La adopción de **sistemas de aireación** es un ejemplo clave de esta necesidad de modernización.
#
#
# *   **Presión por la Sostenibilidad Ambiental:**  Los mercados internacionales exigen cada vez más productos acuícolas producidos de **manera sostenible y responsable con el medio ambiente**.  Las camaroneras ecuatorianas deben adaptarse a estas demandas implementando prácticas que **minimicen su impacto ambiental y aseguren la sostenibilidad a largo plazo de la industria**.
#
#
# En este contexto, la propuesta de **facilitar el financiamiento para la adopción de tecnologías como los aireadores** se presenta como una **oportunidad estratégica** para impulsar la modernización, la sostenibilidad y la competitividad del sector camaronero ecuatoriano.
#
#
# ### **1.4. Objetivos del Proyecto**
#
#
# El objetivo general de esta tesis es **proponer y analizar la viabilidad de un modelo de negocio para una empresa financiera** que provea financiamiento accesible y adaptado a las necesidades del sector camaronero ecuatoriano, con un enfoque inicial en la adquisición de sistemas de aireación.
#
#
# Los objetivos específicos que se persiguen para alcanzar el objetivo general son:
#
#
# - **Diseñar un modelo de negocio detallado** para una empresa financiera especializada en el otorgamiento de créditos al sector camaronero en Ecuador.
#
#
# * **Analizar la viabilidad de obtener financiamiento inicial en el mercado estrangero**, identificando fuentes potenciales y evaluando las condiciones y requisitos.
#
#
# * **Definir un plan de financiamiento específico para las camaroneras ecuatorianas**, incluyendo criterios de elegibilidad, condiciones de crédito, y estrategias de gestión del riesgo de impago.
#
#
# * **Desarrollar proyecciones financieras para la empresa financiera propuesta**, incluyendo estados de resultados, flujo de caja y balance general proyectados, para evaluar su sostenibilidad y rentabilidad.
#
#
# * **Evaluar la sensibilidad del modelo financiero** ante variaciones en variables clave, como tasas de interés, tasas de morosidad y costos operativos, para identificar los factores críticos para la viabilidad del proyecto.
#
#
# * **Determinar la estructura de capital óptima para la empresa financiera**, maximizando la eficiencia y minimizando el riesgo financiero.
#
#
# ### **1.5. Pregunta Fundamental de la Investigación**
#
#
# La pregunta fundamental que guía esta investigación es:
#
#
# *¿Es viable la creación de una empresa financiera, basada en capital obtenido en el exterior, para proveer créditos a camaroneras ecuatorianas, específicamente para la adquisición de sistemas de aireación, y bajo qué modelo de negocio y condiciones financieras resulta sostenible y rentable esta operación?*
#
#
# ### **1.6. Metodología Empleada**
#
#
# Este estudio adoptó un **enfoque empírico-inductivo con soporte cuantitativo**, fundamentado en la recopilación y análisis de datos provenientes de diversas fuentes dentro del sector camaronero. La metodología empleada combinó **técnicas de investigación cualitativa y cuantitativa** para estructurar un **modelo financiero** que permitiera evaluar la viabilidad de un *startup* de intermediación financiera en la adquisición de aireadores de alta gama.
#
#
# ##### **1.6.1. Fuentes de Información**
#
#
# El análisis se basó en información obtenida de diversas fuentes clave:
#
#
# *   **Actores del sector camaronero:** Se recopilaron parámetros de primera mano mediante entrevistas y datos proporcionados directamente por productores y técnicos del sector.
#
#
# *   **Proveedor de equipos:** Se obtuvieron datos técnicos de los aireadores directamente de Beraqua, de quien se comprarán los recebibles, incluyendo especificaciones sobre eficiencia energética, costos, y durabilidad de los equipos.
#
#
# *   **Marco teórico en calidad del agua y eficiencia en aireación:** Se consultaron referencias y principios fundamentales en acuicultura aportados por un experto en la materia, enriqueciendo el análisis con conocimiento especializado.
#
#
# *   **Datos aduaneros:** Se extrajo información detallada sobre los costos de importación de aireadores en Ecuador desde bases de datos oficiales, proporcionando datos concretos para el modelo financiero.
#
#
# ##### **1.6.2. Procesamiento y Análisis de Datos**
#
#
# Para asegurar la rigurosidad del análisis, se utilizaron diversas herramientas y técnicas especializadas:
#
#
# *   **Uso de Python:** Se desarrollaron *scripts* en Python para la limpieza, procesamiento y análisis exhaustivo de los datos. Esto permitió evaluar con precisión los costos de importación, financiamiento, y la eficiencia operativa de los aireadores.
#
#
# *   **Cálculo del Costo Total de Propiedad (TCO):** Se llevó a cabo un análisis comparativo del CTP entre modelos de aireadores de baja y alta gama. Este análisis consideró los costos iniciales de adquisición, el consumo energético a lo largo del tiempo, y la durabilidad de cada tipo de equipo.
#
#
# *   **Modelado Financiero:** Se diseñaron simulaciones financieras detalladas para evaluar la rentabilidad del *startup*. Estas simulaciones incorporaron el arbitraje de tasas de interés y la estructura de ingresos basada en *factoring*, permitiendo una evaluación robusta de diferentes escenarios.
#
#
# *   **Evaluación de costos de oportunidad:** Se realizó un análisis específico de los costos de oportunidad. Este análisis se centró en evaluar los impactos financieros derivados de la elección entre aireadores de baja gama y la alternativa de financiamiento para acceder a equipos de mayor calidad.
#
#
# ##### **1.6.3. Validación y Justificación**
#
#
# El modelo financiero desarrollado fue sometido a un proceso de validación exhaustivo para asegurar su robustez y aplicabilidad:
#
#
# *   **Comparación con estudios previos:** Los resultados obtenidos fueron contrastados con investigaciones previas existentes en la literatura científica y profesional sobre eficiencia en aireación y su impacto en la rentabilidad de la acuicultura.
# *   **Análisis de sensibilidad:** Se condujo un análisis de sensibilidad, evaluando distintos escenarios económicos y operativos. El objetivo fue determinar la robustez del modelo financiero ante variaciones en tasas de interés y otras condiciones de mercado relevantes.
# *   **Revisión por expertos:** Se realizaron consultas con especialistas en financiamiento y acuicultura. Estos expertos revisaron los supuestos fundamentales y las metodologías empleadas en el estudio, aportando una validación externa y especializada.
#
#
# Esta metodología comprensiva y rigurosa permitió **fundamentar sólidamente los hallazgos** de este proyecto. Se asegura así que las conclusiones derivadas se basen en **datos empíricos verificables, cálculos cuantitativos precisos, y modelos financieros robustos, todos ellos aplicables al contexto real y específico del sector camaronero ecuatoriano.**
#
#
# ### **1.7. Marco Teórico**
#
#
# El presente estudio se sitúa en la intersección de la acuicultura y la economía, fundamentándose en principios teóricos sólidos. Se consideran los **principios de calidad del agua** expuestos por Boyd (1990) y Vinatea y Netto (2005),  conjuntamente con **conceptos económicos fundamentales** como ganancias de escala, curvas de costo y costos de oportunidad, desarrollados clásicamente por Marshall (1890) y Wieser (1889).
#
#
# ##### **1.7.1. Aireación y Calidad del Agua en Acuicultura**
#
#
# La **oxigenación del agua** emerge como un **factor crítico y determinante** en la productividad de la acuicultura. Diversos estudios han demostrado consistentemente que el mantenimiento de **niveles óptimos de oxígeno disuelto** en los estanques destinados al cultivo de camarón se traduce en **mejoras sustanciales en el crecimiento y la supervivencia de los organismos**. Adicionalmente, se ha observado una **reducción significativa en la incidencia de enfermedades** en condiciones óptimas de oxigenación (Boyd, 1990).
#
# En este contexto, los **aireadores** representan **dispositivos tecnológicos diseñados específicamente para incrementar la cantidad de oxígeno disponible en el agua**. Su funcionamiento se basa en la **transferencia eficiente de aire** desde la superficie o mediante la agitación mecánica del agua, facilitando la disolución del oxígeno. La **utilización adecuada y estratégica de aireadores** permite **optimizar las condiciones ambientales del cultivo**, posibilitando alcanzar mayores densidades de producción sin comprometer la calidad del agua, un factor esencial para la salud y el rendimiento de los camarones (Vinatea & Netto, 2005).
#
#
# ##### **1.7.2. Puente hacia la Economía: Ganancias de Escala y Curvas de Costo**
#
#
# Desde una **perspectiva económica**, la integración de aireadores en los sistemas de acuicultura puede ser analizada a través del concepto de **ganancias de escala**. Este principio económico postula que al aumentar la escala de producción, es posible **reducir el costo unitario promedio**, derivado de una optimización en la utilización de los factores de producción. Marshall (1890) estableció que las empresas, en su proceso de crecimiento, pueden **beneficiarse tanto de economías internas**, inherentes a la propia gestión y estructura de la empresa, como de **economías externas**, derivadas del entorno industrial y del mercado.
#
# En el **contexto específico de la acuicultura**, la inversión en aireadores de alta gama se justifica no solo por la **reducción de la mortalidad** de los camarones y la **mejora en la eficiencia de la conversión alimenticia**. Adicionalmente, estas tecnologías permiten **incrementar la densidad de cultivo** en los estanques sin que los costos operativos aumenten de manera proporcional. Este efecto se traduce directamente en una **disminución de los costos medios a largo plazo** para la camaronera. En consecuencia, se generan **ventajas competitivas significativas** para aquellos productores que logran acceder a financiamiento para modernizar y mejorar su infraestructura productiva.
#
#
# ##### **1.7.3. Costos de Oportunidad y la Inversión en Aireadores**
#
#
# El concepto de **costo de oportunidad**, introducido por Wieser (1889), constituye un **elemento analítico fundamental** para comprender la toma de decisiones en contextos de asignación de recursos limitados. De acuerdo con este principio, cada decisión económica implica inherentemente la **renuncia o el sacrificio de la mejor alternativa posible** que no fue seleccionada.
#
# En el **ámbito de la acuicultura**, la inversión en aireadores representa una **decisión de asignación de capital** que implica destinar recursos que, alternativamente, podrían ser utilizados en otras áreas, tales como la alimentación de los camarones, mejoras en infraestructura general de la hacienda, o la expansión de la superficie de cultivo.  Sin embargo, la evidencia indica que la **mejora en la oxigenación del agua**, la consecuente **reducción de la mortalidad de los camarones**, y la **optimización de la eficiencia en la conversión alimenticia**, pueden generar un **retorno económico superior a largo plazo** en comparación con otras posibles alternativas de inversión.
#
# Desde un **enfoque estrictamente financiero**, la **gestión eficiente del costo de oportunidad** permite a los productores realizar una **asignación más estratégica y efectiva de su capital**. Facilitando, de esta manera, que aquellos productores que acceden a financiamiento puedan **maximizar su rentabilidad neta** y, simultáneamente, **minimizar los riesgos operativos** inherentes a la actividad acuícola. En este sentido, el análisis riguroso de los costos de oportunidad se presenta como un **elemento crucial para la toma de decisiones estratégicas informadas y eficientes en el sector de la acuicultura**.
#
# Este marco teórico comprensivo establece una **base sólida para analizar el impacto económico y financiero** derivado de la inversión en aireadores de alta gama en la acuicultura.  Demostrando, en última instancia, que la búsqueda de **eficiencia operativa en la acuicultura puede ser abordada de manera efectiva desde la teoría económica clásica** y aplicada a modelos de financiamiento innovadores y adaptados a las necesidades del sector.
#
#
# ### **1.8. ¿Por Qué Apostar por los Aireadores de Alta Gama?**
#
#
# ##### **1.8.1. Análisis Técnico y Costo Total de Propiedad (CTP)**
#
#
# Fundamentado en un **análisis técnico detallado y una metodología de Costo Total de Propiedad (CTP)**, este estudio robustece la justificación para invertir en aireadores de alta gama en la industria camaronera ecuatoriana. La metodología empleada se basó en especificaciones técnicas de catálogos de proveedores y datos empíricos recopilados directamente de actores del sector, permitiendo una **evaluación cuantitativa y comparativa** entre diferentes modelos de aireadores.
#
#
# El análisis técnico inició con la **conversión de la potencia de los motores** de caballos de fuerza (HP) a kilovatios (kW), facilitando la estimación precisa de los costos energéticos operativos. Asumiendo una **eficiencia estándar del motor del 90%** y un **promedio de operación de 8 horas diarias** en las haciendas camaroneras, se calcularon los costos anuales de energía eléctrica utilizando el precio promedio del kWh en Ecuador. Este cálculo proveyó una **base económica sólida para contrastar el impacto energético de cada modelo de aireador.**
#
#
# El CTP se calculó **sumando los costos iniciales** (precio FOB y aranceles de importación) **y los costos energéticos anuales**, proyectados a lo largo de la vida útil de los equipos.  Este enfoque integral del CTP reveló una **ventaja económica significativa de los modelos de gama alta a largo plazo, a pesar de su mayor costo inicial**.
#
#
# ##### **1.8.2. Vida Útil y Frecuencia de Reemplazo: Un Factor Crítico en el CTP**
#
#
# La recopilación de información directamente de haciendas camaroneras proveyó **datos cruciales sobre la durabilidad de los aireadores**, destacando una **diferencia sustancial entre modelos de gama baja y alta**:
#
#
# **Modelos de gama alta:**
#
#
# *   Exhiben una **vida útil prolongada, alcanzando hasta 6 años**.
# *   Esta mayor durabilidad **reduce significativamente la frecuencia de reemplazos**, minimizando los **costos recurrentes asociados a importación y aranceles** a lo largo del tiempo, tal como se evidencia en el análisis del CTP.
#
#
# **Modelos de gama baja:**
#
#
# *   Presentan una **vida útil significativamente menor, estimada en aproximadamente 2 años**.
# *   Aunque su **costo inicial es inferior**, la **necesidad de reemplazos más frecuentes eleva los gastos operativos acumulados**, anulando la ventaja inicial en el corto plazo al considerar el CTP.
#
#
# Estas disparidades en la **vida útil** tienen un **impacto directo y significativo en los costos operativos a largo plazo**.  La inversión inicial en modelos de gama alta, aunque mayor, se justifica por la **reducción de costos de reemplazo y la optimización del CTP a lo largo de su ciclo de vida**.
#
#
# ##### **1.8.3. Eficiencia Relativa y Consumo Energético: El Impacto de las RPM**
#
#
# El estudio profundizó en la **relación entre las Revoluciones Por Minuto (RPM) de los aireadores y su eficiencia relativa en la saturación de oxígeno**.  Los hallazgos revelaron una **correlación directa**:
#
#
# *   Aireadores operando a **125 RPM** demostraron alcanzar el **50% de saturación de oxígeno con solo 4 unidades por hectárea**.
# *   Modelos de menor RPM, como aquellos a **100 RPM**, requieren **5 aireadores por hectárea para lograr el mismo nivel de saturación**.
#
#
# Esta relación se cuantificó en la **eficiencia relativa**, donde un aireador a **125 RPM** se considera **100% eficiente**, mientras que un modelo a **100 RPM** presenta una **eficiencia relativa del 80%** ($\frac{100}{125} = 80\%$).  Modelos de RPM superiores, como **150 RPM**, alcanzan una **eficiencia relativa del 120%** ($\frac{150}{125} = 120\%$).
#
#
# El análisis del **consumo energético (kWh)** reveló su **dependencia directa de los HP del motor, las horas de operación y, crucialmente, la eficiencia relativa determinada por las RPM**.  **Aireadores menos eficientes (menor RPM) demandan un mayor consumo energético para lograr la misma oxigenación**.
#
#
# ##### **1.8.4. Ventajas Económicas: TIR e Índice de Costo-Efectividad (ICE)**
#
#
# **Costo Total de Propiedad (CTP):** El CTP resultó ser **menor para los aireadores de gama alta (USD 7173.13) en comparación con los de gama baja (USD 8172.29)**, evidenciando la **eficiencia a largo plazo de la inversión inicial más elevada**.
#
#
# **Tasa Interna de Retorno (TIR):** Se obtuvo una **TIR del 81.84%** al invertir en aireadores de gama alta, indicando una **rentabilidad significativamente atractiva y superior** a la de modelos de gama baja.
#
#
# **Índice de Costo-Efectividad (ICE):** El ICE, que mide el costo por kilogramo de camarón producido, fue **menor para la gama alta (0.0008 USD/kg) frente a la gama baja (0.0010 USD/kg)**.
#
# Este indicador refuerza la conclusión de que los aireadores de gama alta ofrecen una **mayor eficiencia en la producción a un menor costo unitario**.
#
#
# ##### **1.8.5. Gestión del Riesgo y Solvencia del Sector Camaronero**
#
#
# El estudio también abordó la **gestión del riesgo mediante un análisis de solvencia del sector camaronero ecuatoriano**.  Basándose en datos de exportaciones de 297 empresas y asumiendo una producción estándar de 9 toneladas de camarón por hectárea, se filtró el análisis para enfocarse en haciendas de aproximadamente 1000 hectáreas, representativas del segmento objetivo del plan de financiamiento.
#
#
# El análisis de riesgo, aplicado a una muestra de empresas exportadoras clave (South Pacific Seafood, Mariscos del Ecuador, Perlas del Pacífico, y Comercial Pesquera Cristiansen),  reveló un **riesgo de incumplimiento bajo para todas las compañías evaluadas**.  La amortización anual estimada de la financiación para aireadores de gama alta representa menos del 30% de sus ingresos brutos anuales estimados.  Este hallazgo sugiere que, a pesar de una tasa de interés del financiamiento aparentemente elevada (13% anual), la **inversión en aireadores de alta gama se mantiene viable y de bajo riesgo crediticio para camaroneras de gran escala**,  considerando el incremento en eficiencia y producción que estos equipos permiten.
#
#
# **En conclusión, el análisis técnico-económico integral, fundamentado en datos empíricos y principios teóricos sólidos,  argumenta de manera convincente a favor de la inversión en aireadores de alta gama.  A pesar de un costo inicial superior, estos equipos demuestran una eficiencia energética superior, mayor durabilidad y un menor Costo Total de Propiedad a largo plazo,  generando una alta rentabilidad y un bajo riesgo de incumplimiento para las camaroneras que adopten esta tecnología.**  Este análisis justifica la estrategia del plan de financiamiento propuesto,  orientado a **facilitar el acceso a aireadores de alta gama y maximizar el valor para las camaroneras y la empresa financiera.**
# ## **Capítulo II: Modelo de Negocio de la Empresa Financiera**
#
#
# ### **2.1. Modelo de Negocio de la Empresa Financiera**
#
# La propuesta central de esta tesis es la **creación de una empresa financiera especializada** en el otorgamiento de créditos al sector camaronero ecuatoriano, con un enfoque inicial en el financiamiento de sistemas de aireación.  Este capítulo detalla el **modelo de negocio de esta empresa**, abordando su estructura, fuentes de ingresos, costos, gestión de riesgos y flujo de financiamiento, basándonos en supuestos clave y parámetros económicos relevantes.
#
#
# ### **2.2. Constitución y Tipo de Sociedad**
#
#
# - Una empresa extranjera pueda ofrecer servicios de factoring en Ecuador bajo acuerdos como el EFTA, tratados con la UE, y el marco de la OMC, dependiendo de su país de origen.
# - Para empresas de EFTA (como Suiza) y la UE, los acuerdos comerciales incluyen servicios financieros, facilitando la operación.
# - Para empresas de EE. UU., el acuerdo TIC parece no cubrir servicios ampliamente, requiriendo cumplir regulaciones locales.
# - Para empresas japonesas, se aplica el marco GATS de la OMC, sujeto a compromisos específicos de Ecuador.
# - Se recomienda establecer una filial en Ecuador para operar, considerando beneficios fiscales y cumplimiento legal.
#
#
# ### **2.3. Análisis Comparativo de Fuentes de Financiamiento Internacional**
#
# Esta sección consolida el análisis de las distintas jurisdicciones para la obtención de financiamiento, evaluando el marco legal, los aspectos fiscales, la viabilidad y un plan de acción para cada una. Se comparan **Estados Unidos, Suiza y la Eurozona**, destacando las ventajas y desventajas de cada opción para la empresa financiera propuesta.
#
#
# ##### **2.3.1. Marco Legal y Operacional por Jurisdicción**
#
# El marco legal bajo el cual puede operar la empresa financiera varía significativamente según el país de origen:
#
#
# *   **EFTA (Suiza):** El Acuerdo de Asociación Económica Integral EFTA-Ecuador facilita la operación de servicios financieros, incluyendo *factoring*, para empresas de la EFTA en Ecuador.
#
#
# *   **Unión Europea:** El Acuerdo Comercial UE-Colombia-Perú-Ecuador también facilita la operación de servicios financieros para empresas de la UE en Ecuador, con un marco legal favorable.
#
#
# *   **Estados Unidos:** El Acuerdo del Consejo de Comercio e Inversión (TIC) entre EE. UU. y Ecuador no se enfoca directamente en servicios financieros, lo que podría requerir que las empresas estadounidenses se adhieran más estrictamente a las regulaciones domésticas ecuatorianas para ofrecer *factoring*.
#
#
# *   **Japón (OMC):** Bajo el marco GATS de la OMC, las empresas japonesas podrían operar, pero la viabilidad depende de los compromisos específicos de Ecuador en el sector financiero bajo GATS.
#
#
# En todos los casos, se recomienda **establecer una filial en Ecuador** como la estructura corporativa más adecuada. Una filial es tratada como entidad local, lo que facilita el cumplimiento regulatorio y puede ofrecer beneficios fiscales.  Las opciones legales en Ecuador incluyen la Sociedad de Responsabilidad Limitada (SRL) y la Sociedad Anónima Simplificada (SAS). Operar como sucursal también es posible, pero puede conllevar diferentes implicaciones fiscales, incluyendo un impuesto de salida de capital.
#
#
# ##### **2.3.2. Contexto y Definición de Factoring**
#
# El *factoring*, como servicio financiero central al modelo de negocio, está regulado en Ecuador desde 1984.  Empresas locales ofrecen este servicio, lo que indica que entidades extranjeras pueden participar, siempre que cumplan con las regulaciones específicas ecuatorianas.
#
#
#
# ##### **2.3.3. Viabilidad y Plan de Acción Detallado por Jurisdicción**
#
# A continuación, se detalla la viabilidad del financiamiento y un plan de acción escalonado para cada jurisdicción, considerando los pros y contras previamente discutidos:
#
#
# **2.3.3.1. Financiamiento en Estados Unidos**
#
# Ventajas:
# *   **Moneda:** Operar en la misma moneda que Ecuador (USD) elimina el riesgo cambiario.
# *   **Mercado Financiero:** Acceso a un mercado financiero profundo y desarrollado.
#
#
# Desventajas:
# *   **Tasas de Interés:**  Potencialmente tasas de interés más altas comparadas con otras jurisdicciones como Suiza.
# *   **Impuesto Corporativo:** Impuesto corporativo relativamente alto en comparación con jurisdicciones como Suiza, impactando la rentabilidad neta.
#
# **Evaluación del Préstamo SBA 7(a):**  El programa SBA 7(a) es atractivo por sus bajas tasas, pero requiere que la empresa esté registrada y opere en EE. UU., con historial crediticio y garantías en EE. UU.  El acceso directo para una empresa extranjera es limitado.
# **Alternativas Viables:** Préstamos comerciales en bancos internacionales, fondos de inversión, *private equity*, *factoring* internacional, y préstamos de bancos de desarrollo como EXIM Bank o BID.
#
#
# | **Fase**                     | **Duración** | **Objetivo**                                      | **Acciones Clave**                                                                 | **Resultado Esperado**                          |
# |------------------------------|--------------|--------------------------------------------------|-----------------------------------------------------------------------------------|-------------------------------------------------|
# | Fase 1: Historial en EE.UU.    | 0-12 meses   | Crear historial bancario y crediticio en EE.UU.     | Abrir cuenta, transacciones frecuentes, tarjetas de crédito empresariales, depósitos. | Credibilidad para préstamos pequeños.           |
# | Fase 2: Financiamiento Inicial | 12-24 meses  | Financiamiento moderado y alianzas estratégicas   | Préstamo pequeño, alianzas (BID, EXIM Bank), *factoring*, *private equity*.         | Financiamiento 10-14%, mayor credibilidad.      |
# | Fase 3: Financiamiento Competitivo | 24-36 meses  | Acceder a tasas competitivas (<10%)                | Préstamo mayor, líneas de crédito, programas de comercio exterior, deuda privada.  | Financiamiento 6-10%, alineado a mercados.    |
#
#
#
# **2.3.3.2. Financiamiento en Suiza**
#
#
# Ventajas
# *   **Tasas de Interés:** Tasas de interés bajas, típicamente entre 3-5% para prestatarios solventes.
# *   **Impuesto Corporativo:** Impuesto corporativo competitivo, mejorando la rentabilidad neta.
#
# Desventajas
# *   **Acceso para Extranjeros:**  Acceso desafiante para empresas sin historial o presencia local.
# *   **Riesgo Cambiario:**  Operar en francos suizos (CHF) introduce riesgo cambiario si los ingresos son en USD. No obstante, muchos bancos suizos ofrecen préstamos en USD.
#
#
# **Evaluación de Programas Gubernamentales:**  Ausencia de programas gubernamentales directos como el SBA 7(a);  apoyo limitado a través de SECO y SERV enfocado en exportaciones, no en financiamiento general.
# **Alternativas Viables:** Préstamos comerciales de bancos suizos (UBS, Credit Suisse), *factoring* internacional, fondos de inversión y *private equity*.
#
#
# | **Fase**                     | **Duración** | **Objetivo**                                      | **Acciones Clave**                                                                 | **Resultado Esperado**                          |
# |------------------------------|--------------|--------------------------------------------------|-----------------------------------------------------------------------------------|-------------------------------------------------|
# | Fase 1: Historial en Suiza   | 0-12 meses   | Crear historial bancario en Suiza                  | Abrir cuenta, transacciones, documentación financiera, asesor local.              | Credibilidad para préstamos pequeños.           |
# | Fase 2: Financiamiento Inicial | 12-24 meses  | Financiamiento moderado y alianzas estratégicas   | Préstamo pequeño, alianzas financieras suizas, *factoring*, *private equity*.      | Financiamiento 5-8%, mayor credibilidad.       |
# | Fase 3: Financiamiento Competitivo | 24-36 meses  | Acceder a tasas bajas (3-5%)                     | Préstamos mayores, negociar tasas, deuda privada.                                 | Financiamiento competitivo, alineado a mercado suizo. |
#
#
# **2.3.3.3. Financiamiento en la Eurozona**
#
#
# Ventajas
# * **Programas de la UE:**  Acceso a programas como COSME y EaSI para PYMES a través de subsidiarias locales.
# * **Mercado Financiero Estable:**  Mercado financiero grande y líquido con tasas de interés comerciales competitivas.
#
#
# Desventajas
# * **Complejidad Regulatoria:**  Navegar regulaciones de la UE y de cada país miembro.
# * **Diversidad de Tasas:**  Variación significativa en tasas de interés entre países de la Eurozona.
# * **Requisitos de Presencia Local:**  Programas de la UE y bancos locales generalmente requieren presencia legal en la Eurozona.
#
#
# **Evaluación de Programas de la UE:** Programas COSME y EaSI facilitan el acceso a financiamiento (garantías, micropréstamos) para
# PYMES establecidas en la Eurozona.  El Banco Europeo de Inversiones (EIB) y el Fondo Europeo de Inversión (EIF) también ofrecen apoyo a través de instituciones financieras locales.
#
#
# **Alternativas Viables:** Préstamos comerciales de bancos europeos (BNP Paribas, Deutsche Bank, Santander), *factoring* internacional, fondos de inversión y *private equity*.
#
#
# | **Fase**                     | **Duración** | **Objetivo**                                      | **Acciones Clave**                                                                 | **Resultado Esperado**                          |
# |------------------------------|--------------|--------------------------------------------------|-----------------------------------------------------------------------------------|-------------------------------------------------|
# | Fase 1: Historial en Eurozona | 0-12 meses   | Crear historial bancario en la Eurozona            | Abrir cuenta, transacciones, documentación, asesor en la Eurozona.              | Credibilidad para préstamos pequeños.           |
# | Fase 2: Financiamiento Inicial | 12-24 meses  | Financiamiento moderado y alianzas estratégicas   | Préstamo pequeño, programas COSME/EaSI, *factoring*, *private equity*.              | Financiamiento 6-8%, mayor credibilidad.       |
# | Fase 3: Financiamiento Competitivo | 24-36 meses  | Acceder a tasas bajas (4-6%)                     | Préstamos mayores, negociar tasas, deuda privada, optimizar ubicación en Eurozona. | Financiamiento competitivo, alineado a mercado. |
#
#
# **2.3.3.4. Financiamiento en Japón**
#
# Ventajas
#
# * **Tasas de Interés Muy Bajas:** Tasas de interés excepcionalmente bajas, alrededor del 0.81% anual.
# * **Mercado Financiero Estable:** Mercado financiero robusto y líquido.
#
#
# Desventajas
#
# * **Barreras Idiomáticas y Culturales:**  Dificultad para empresas extranjeras sin conocimiento del idioma o cultura empresarial japonesa.
#
#
# **Conservadurismo Bancario:** Bancos japoneses tradicionalmente conservadores y aversos al riesgo, especialmente con empresas extranjeras sin historial local.
# **Riesgo Cambiario:**  Operar en yenes japoneses (JPY) introduce riesgo cambiario significativo.
#
#
# **Evaluación de Programas Gubernamentales:**  Información limitada sobre programas gubernamentales japoneses específicos para facilitar financiamiento a PYMES extranjeras. El marco GATS de la OMC aplicaría, pero con posibles limitaciones dependiendo de los compromisos de Ecuador.
#
#
# **Alternativas Viables:**  Préstamos comerciales de bancos japoneses (requiriendo fuerte presencia local y garantías), *factoring* internacional, fondos de inversión y *private equity* enfocados en mercados emergentes.
#
#
# | **Fase**                     | **Duración** | **Objetivo**                                      | **Acciones Clave**                                                                 | **Resultado Esperado**                          |
# |------------------------------|--------------|--------------------------------------------------|-----------------------------------------------------------------------------------|-------------------------------------------------|
# | Fase 1: Historial en Japón    | 0-12 meses   | Establecer presencia y relaciones en Japón        | Abrir oficina de representación, contratar personal local, iniciar networking.   | Primeros contactos y entendimiento del mercado. |
# | Fase 2: Financiamiento Inicial | 12-24 meses  | Acceder a financiamiento inicial                 | Préstamos con garantía parcial, *factoring*, fondos de inversión con foco en Asia. | Financiamiento inicial a tasas moderadas.      |
# | Fase 3: Financiamiento Competitivo | 24-36 meses  | Reducir tasas y ampliar fuentes de financiamiento | Préstamos bancarios con mejores condiciones, deuda privada en JPY, diversificación. | Financiamiento competitivo, acceso a tasas bajas. |
#
#
# ##### **2.3.4. Implicaciones Fiscales y Estructura Corporativa**
#
# En todas las jurisdicciones analizadas, se recomienda constituir una **filial en Ecuador** para operar localmente. Fiscalmente, Ecuador ofrece estabilidad y la posibilidad de acogerse a un régimen tributario con una tasa adicional del 2% sobre el impuesto a la renta.  Al evaluar la jurisdicción para obtener financiamiento, se deben considerar las tasas de impuesto corporativo:
#
# *   **Suiza:** Ofrece tasas de impuesto corporativo bajas (e.g., 12% en Zug, 13-15% en Ginebra), lo cual es una ventaja significativa para la rentabilidad.
# *   **Zona Euro:** Tasas de impuesto varían significativamente entre países (e.g., Irlanda 12.5%, Francia ~25%), permitiendo optimizar la ubicación dentro de la Eurozona para minimizar la carga fiscal.
# *   **Estados Unidos:**  Impuesto corporativo competitivo a nivel global, pero potencialmente más alto que Suiza y algunas jurisdicciones de la Eurozona.
#
#
# | **Jurisdicción**   | **Ventajas Clave para Financiamiento**                               | **Desventajas Clave**                                      | **Tasas de Interés Estimadas (Fase 3)** | **Impuesto Corporativo (Aprox.)** | **Moneda de Fondeo** |
# |--------------------|--------------------------------------------------------------------|-----------------------------------------------------------|------------------------------------------|------------------------------------|----------------------|
# | **Estados Unidos** | Moneda (USD), mercado financiero desarrollado                     | Tasas de interés más altas, impuesto corporativo          | 6-10%                                    | 21%                                | USD                  |
# | **Suiza**          | Tasas de interés bajas, impuesto corporativo bajo                  | Acceso desafiante, riesgo cambiario (CHF)                 | 3-5%                                     | 12-15%                              | CHF (USD posible)    |
# | **Eurozona**       | Programas de la UE, mercado financiero estable                       | Complejidad regulatoria, diversidad de tasas, presencia local | 4-6%                                     | 12.5% - 25% (Varía)                 | EUR                  |
# | **Japón**          | Tasas de interés muy bajas                                        | Barreras culturales, conservadurismo bancario, riesgo cambiario (JPY) | <2%                                     | ~23%                                | JPY (USD posible)    |
#
#
# **Recomendación:**
#
# Considerando las tasas de interés y el impuesto corporativo, **Suiza y la Eurozona (especialmente países con tasas más bajas como Irlanda o Luxemburgo) emergen como jurisdicciones potencialmente más ventajosas** para obtener financiamiento, a pesar de los desafíos de acceso inicial y el riesgo cambiario (en el caso de Suiza, aunque mitigable).  **Estados Unidos ofrece la ventaja de la moneda y la facilidad del idioma inglés, pero con costos de financiamiento y fiscales potencialmente más altos.**  Japón presenta las tasas más bajas, pero con barreras significativas de entrada.
#
# La elección final de la jurisdicción dependerá de una **ponderación cuidadosa de estos factores**, incluyendo la tolerancia al riesgo cambiario, la capacidad de establecer presencia local y construir historial crediticio en cada jurisdicción, y la estrategia fiscal a largo plazo de la empresa financiera.
#
#
# ### **2.4. Estructura de Ingresos de la Empresa**
#
# La principal fuente de ingresos de la empresa financiera provendrá de los **intereses cobrados por los créditos otorgados a las camaroneras ecuatorianas y comisiones de *factoring* captadas del proveedor de aireadores**.  Este modelo de negocio se basa en la **captación de capital a un costo menor en el mercado internacional**, y la **colocación de estos fondos en Ecuador a tasas de interés del 13% anual**.
#
# Además de los ingresos por intereses, la empresa podría considerar **fuentes de ingresos secundarias** como:
#
# *   **Comisiones por Originación de Crédito**
# *   **Comisiones por Gestión de Crédito**
# *   ***Spread* Financiero**
#
#
# ### **2.5. Costos Operativos**
#
# Los costos operativos incluyen:
#
# *   **Costos de Financiamiento**: Tasa de interés del préstamo externo.
# *   **Costos de Gestión**: Salarios, alquiler, marketing, tecnología, gastos legales y administrativos.
# *   **Riesgos de Impago**: Provisiones para pérdidas crediticias.
# *   **Costos Administrativos y Regulatorios**: Cumplimiento normativo, licencias, impuestos locales.
#
#
# ### **2.6. Gestión de Liquidez y Estrategia de Riesgo**
#
# La gestión de liquidez y riesgo es crucial e incluye:
#
# **Gestión de Liquidez**: Flujo de caja proyectado, reservas de liquidez, líneas de crédito contingentes.
#
# **Estrategia de Riesgo**:
#
#
# *   Riesgo de Crédito: *Scoring*, garantías, diversificación, seguimiento, cobranza.
# *   Riesgo de Mercado: Fluctuaciones de tasas de interés y tipo de cambio, condiciones macroeconómicas.
# *   Riesgo Operacional: Fallas internas, errores humanos, fraude, tecnología.
# *   Riesgo Regulatorio y Legal: Cambios regulatorios, incumplimiento, litigios.
#
#
# ### **2.6. Flujo de Financiamiento y Operación**
#
#
#
# ##### **2.6.1. Paso 1: Obtención del Crédito Externo.**
#
#
# *   La empresa financiera buscará obtener un **préstamo en el extranjero**, idealmente bajo un esquema como el **SBA 7(a)** como el que se practica en Estados Unidos o una línea de crédito similar con **tasa de interés base cercana al 4-6% anual**.
# *   Se gestionará la documentación requerida, se cumplirán los requisitos de elegibilidad, y se negociarán las condiciones del préstamo (monto, plazo, garantías, etc.).
# *   Los fondos obtenidos en divisa extranjera serán convertidos al dólar y transferidos a las cuentas de la empresa en Ecuador.
#
#
# ##### **2.6.2. Paso 2: Conversión de Fondos en Créditos a Productores Camaroneros**
#
#
# *   Los fondos convertidos a dólares serán destinados al **otorgamiento de créditos a las camaroneras ecuatorianas**.
# *   Se implementará el **plan de evaluación crediticia** (Capítulo 4) para seleccionar a las camaroneras elegibles y determinar el monto y condiciones de cada crédito.
# *   Los créditos se ofrecerán para la **adquisición de sistemas de aireación**, inicialmente, con el objetivo de expandir a otras tecnologías y necesidades del sector en el futuro.
# *   Los créditos se desembolsarán a las camaroneras en dólares estadounidenses, con una **tasa de interés del 13% anual** (justificada previamente),  plazos de 6 años (según el horizonte definido en el análisis) y un descuento de **10%** por *factoring* del proveedor
#
#
# ##### **2.6.3. Paso 3: Gestión de Pagos y Riesgo de Impago**
#
#
# *   Se implementará un sistema eficiente de **gestión de cobranza** para asegurar la recaudación oportuna de los pagos de las camaroneras.
# *   Se realizará un **seguimiento continuo de la cartera de créditos** y se monitoreará la situación financiera de las camaroneras para identificar señales de alerta temprana de posibles problemas de pago.
# *   En caso de **pagos atrasados o morosidad**, se aplicarán los procedimientos definidos en el plan de gestión de riesgo de crédito (Capítulo 4), que podrían incluir recordatorios, renegociación de plazos,  gestión de garantías,  y acciones legales si fuera necesario.
# *   Se realizarán **provisiones para pérdidas crediticias** de acuerdo con las estimaciones de riesgo y la normativa contable aplicable.
#
#
#
# ##### **2.6.4. Paso 4: Rentabilidad y Expansión del Modelo**
#
#
# *   La **rentabilidad de la empresa** se generará principalmente por el ***spread* financiero**, es decir, la diferencia entre la tasa de interés cobrada a las camaroneras 13% y el costo del financiamiento en el exterior. (aproximadamente 4-6%, incluyendo el margen).
# *   La **eficiencia en la gestión de costos operativos** y la **minimización de las pérdidas por impago** serán factores clave para maximizar la rentabilidad neta.
# *   **Diversificación de la cartera de productos de crédito:**  Ofrecer financiamiento para otras necesidades de las camaroneras, como capital de trabajo,  mejoras de infraestructura,  adopción de otras tecnologías,  etc.
# *   **Expansión a otras regiones o sectores de la acuicultura en Ecuador:**  Ampliar el alcance geográfico y diversificar el riesgo sectorial.
# *   **Desarrollo de servicios financieros complementarios:**  Ofrecer asesoría financiera,  seguros,  productos de inversión para el sector camaronero, etc.
# ## **Capítulo III: Viabilidad del financiamiento en el extranjero**
#
# Este capítulo presenta un análisis detallado de la viabilidad del financiamiento en el extranjero, utilizando un modelo de descuento de flujos de efectivo (DCF) optimizado para evaluar el valor de la equidad, la tasa interna de retorno (TIR), el período de recuperación (payback), y la sensibilidad a diferentes parámetros como la relación deuda/capital, la inversión inicial y las diferencias en tasas de interés. Los resultados se basan en datos de simulaciones financieras para 20 países, ajustados por tasas de interés, costos de cobertura, impuestos corporativos y riesgo país.
#
#
# Los objetivos principales son:
# - Calcular métricas clave como el Valor Actual Neto (VAN), TIR, ROI y período de recuperación.
# - Realizar un análisis de sensibilidad para evaluar el impacto de la inversión inicial, las tasas de descuento y la relación deuda/capital.
#
#
#
# Los parámetros que se utilizan para el analisis son:
#
#
# $$
# \text{Precio del aireador: } \$1,206.00 \\
# \text{Cantidad: } 100 \text{ unidades} \\
# \text{Inversión inicial: } \$108,540.00 \\
# \text{Markup del préstamo: } 6.0\% \\
# \text{Tasa del cliente: } 13.0\% \text{ anual} \\
# \text{Descuento por factoring: } 10.0\% \\
# \text{Horizonte: } 6 \text{ años}
# $$
#
#
# $$
# \text{ Diferencial de Tasas de Interés } (R)
# $$
#
#
# $$
# R = r_c - r_t
# $$
#
#
# $$
# r_t = \text{ tasa total del préstamo extranjero } (r_b + m) \\
# m = \text{ margen aplicada sobre la tasa de interés nacional} \\
# r_c = \text{ tasa que el cliente acepta pagar} \\
# R \gt 0 = \text{ existe oportunidad de arbitraje} \\
# $$
#
#
# $$
# \text{ Beneficio de Arbitraje antes de Impuestos } ( U)
# $$
#
#
# $$
# U = R - C
# $$
#
#
# $$
# \text{U } \gt 0 \text{ la operación es rentable} \\
# \text{U } \lt 0 \text{ no es rentable}
# $$
#
#
# $$
# \text{ Beneficio de Arbitraje después de Impuestos } ( L)
# $$
#
#
# $$
# L = U \cdot \left(1 - T \right)
# $$
#
#
# $$
# \text{ Cálculo del Costo de Cobertura } (Ch)
# $$
#
#
# $$
# Ch = \left(\frac{F}{S} \right)^{\frac{1}{H}} - 1
# $$
#
#
# $$
# F = 0.89392 \text{ (cambio forward USD/CHF)} \\
# S = 0.89419 \text{ (cambio spot USD/CHF)} \\
# H = 6 \text{ (horizonte temporal)}
# $$
#
#
#
# $$
# Ch = \left(0.89392 \times 0.89419 \right)^{\frac{1}{6}} - 1  \approx -0.036\%
# $$
#
#
#
# $ F \cdot S $ representa la relación entre el tipo forward y spot.
# Por ejemplo, si $ S = 0.9 \text{ (USD/EUR)} $ y $ F = 0.95 $,
# el mercado anticipa una depreciación del EUR.
# La elevación a $ \frac{1}{H} $ anualiza el costo para horizontes multi-anuales.
# Si $ \text{Ch } \gt 0 $, la cobertura es costosa; si $ Ch \lt 0 $, es favorable.
#
#
# En el caso específico, el costo calculado de hedging en 6 años es un costo negativo de -0.036%, lo que es usual para divisas estables. Sin embargo, **no todas las divisas tienen mercados *forward* desarrollados y líquidos**. Para muchas economías, especialmente las emergentes o menos desarrolladas, el mercado de contratos *forward* es inexistente, poco líquido o inaccesible para inversores minoristas o ciertas entidades. En estos casos, necesitamos recurrir a **proxies o estimaciones** para aproximar el costo de cobertura. Una proxy comúnmente utilizada se basa en el **diferencial de inflación** entre dos países.
#
#
# ### **3.1. Fundamento Teórico: Paridad del Poder Adquisitivo (PPA)**
#
# La lógica detrás de usar el diferencial de inflación como proxy se basa en la teoría de la **Paridad del Poder Adquisitivo (PPA)**.  En su forma más simple, la PPA sugiere que los tipos de cambio entre divisas deberían ajustarse para reflejar los diferenciales de inflación entre los países. En otras palabras, si un país tiene una inflación significativamente más alta que otro, su moneda debería depreciarse para mantener el mismo poder adquisitivo relativo de los bienes y servicios entre ambos países. **Por lo tanto, el diferencial de inflación puede ser visto como un indicador de la expectativa de depreciación (o apreciación) de una moneda frente a otra, y por ende, como un proxy del costo de cobertura.**
#
#
# ### **3.2. Fórmula del Diferencial de Inflación Logarítmico**
#
#
# $$
# Ch_{proxy} = \ln\left(1 + \frac{Inf_{extranjera}}{100}\right) - \ln\left(1 + \frac{Inf_{EEUU}}{100}\right)
# $$
#
#
#
# Vemos que para Perú (PEN), el costo de cobertura es de **1.85%** indicando que **se espera que mantener soles peruanos (PEN) y protegerse contra la fluctuación cambiaria frente al dólar estadounidense (USD) tenga un costo anual aproximado del 1.85%**. En términos prácticos, esto implica que si una empresa invierte en Perú y espera repatriar ganancias en USD dentro de un año, el uso de una estrategia de cobertura basada en esta proxy indicaría que podría perder aproximadamente el 1.85% de esas ganancias debido a la cobertura cambiaria. Este costo **surge principalmente del diferencial de inflación entre Perú y Estados Unidos**. Si Perú tiene una inflación ligeramente superior a EEUU la PPA sugiere una depreciación esperada del PEN frente al USD, lo que se traduce en un costo de cobertura positivo.
#
#
# ### **3.3. Limitaciones de la Proxy de Inflación**
#
# Es fundamental entender que la proxy de inflación es una **simplificación y una estimación imperfecta** del costo real de cobertura.
#
#
# *   **PPA no se cumple perfectamente en el corto plazo:** La teoría de la PPA es más robusta en horizontes temporales largos. En el corto plazo, los tipos de cambio se ven influenciados por muchos otros factores (tasas de interés relativas, balanza comercial, flujos de capital, sentimiento del mercado, eventos geopolíticos, etc.) que no se reflejan únicamente en los diferenciales de inflación.
#
# *   **No refleja costos de transacción ni primas de riesgo de mercado:** La proxy de inflación no captura los costos de transacción asociados a la implementación de estrategias de cobertura reales en el mercado, ni las primas de riesgo que los participantes del mercado podrían exigir para cubrirse en divisas específicas.
#
# *   **Datos de inflación son retrospectivos:**  Las tasas de inflación que utilizamos son datos históricos, mientras que los mercados *forward* reflejan expectativas futuras.  Aunque el diferencial de inflación histórica puede ser un indicador útil, no es una predicción perfecta de la evolución futura de los tipos de cambio.
#
#
# ### **3.4. Beneficio Ajustado por Riesgo $L_r$: Una Penalización Basada en el Riesgo País**
#
# La fórmula del beneficio ajustado por riesgo $L_r$ se construye para **reducir la rentabilidad potencial $L$ en proporción al riesgo país** asociado a la moneda en la que se realizaría la inversión.  La fórmula es la siguiente:
#
#
# $$
# L_r = \frac{L}{a}, \quad \text{donde } a = 101 - te
# $$
#
#
# ##### **3.4.1. Escala de Riesgo País** $\text{te}$
#
# Utilizamos una calificación de riesgo país, representada por la variable $te$, que se encuentra en una escala numérica de 1 a 100.  Esta escala ha sido diseñada de la siguiente manera:
#
#
# *   **$te = 1$ : Riesgo Máximo o Extremo.**  Una calificación cercana a 1 indica un país con el máximo nivel de riesgo.  Esto podría corresponder a países en situaciones de crisis económica severa, inestabilidad política extrema, o incluso en riesgo inminente de *default* o cese de pagos de su deuda soberana.
#
#
# *   **$te = 100$ : Riesgo Mínimo o Nulo.** Una calificación cercana a 100, en el extremo opuesto, representa el mínimo nivel de riesgo país.  Estos países suelen ser economías altamente desarrolladas, con instituciones sólidas, economías estables y una calificación crediticia AAA (la más alta posible).  Ejemplos típicos podrían ser Suiza, Noruega o Luxemburgo.
#
#
# ##### **3.4.2. Construcción del Factor de Ajuste por Riesgo $a$:**
#
#
# El factor clave de esta fórmula es $a$, que actúa como el **divisor** en el cálculo del beneficio ajustado por riesgo.  Este factor $a$ se deriva directamente de la calificación de riesgo país ($te$) mediante la siguiente relación:
#
#
# $$
# a = 101 - te
# $$
#
#
# **Relación Inversa con el Riesgo:** Existe una relación inversa entre la calificación de riesgo $te$ y el factor de ajuste $a$.
#
#
# **A mayor riesgo país (valor de $te$ más bajo), mayor será el valor del factor $a$, y por lo tanto, mayor será la penalización a   la   rentabilidad ($L_r$ será menor).**
#
#
# Por el contrario, **a menor riesgo país (valor de $te$ más alto), menor será el valor de   $a$, y  menor será la penalización ( $L_r$ se acercará más a $L$).**
#
#
# **Riesgo Máximo ($te = 1$):** Si un país tiene la calificación de riesgo más baja posible ($te = 1$), entonces $ a = 101 - 1 =   100 $.
#
# En este caso, el beneficio ajustado por riesgo sería $ L_r = \frac{L}{100} $, lo que implica una **penalización máxima**,     reduciendo drásticamente la rentabilidad original.
#
#
# **Riesgo Mínimo ($te = 100$):**
#
#
# Si un país tiene la calificación de riesgo más alta posible ($te = 100$),
#
#
# entonces $ a = 101 - 100 = 1 $.
#
#
# En este escenario, el beneficio ajustado por riesgo sería $ L_r = \frac{L}{1} = L $.
#
#
# Esto significa que **no hay penalización por riesgo**, y la rentabilidad ajustada es igual a la rentabilidad post-impuestos     original, reflejando que en países de muy bajo riesgo, el ajuste es mínimo o inexistente.
#
# **Riesgo Moderado-Bajo (Ejemplo: $te = 70$):**
#
#
# Si un país tiene un riesgo moderado-bajo, por ejemplo $te = 70$,
#
#
# entonces $a = 101 - 70 = 31$.
#
#
# En este caso, $ L_r = \frac{L}{31} $
#
#
# La rentabilidad se reduce, pero no de forma tan drástica como en el caso de riesgo máximo.
#
# **Riesgo Alto (Ejemplo: $te = 20$):**
#
#
# Si un país presenta un alto riesgo, con una calificación
#
# $te = 20$,
# entonces $a = 101 - 20 = 81$.
#
#
# Aquí, $ L_r = \frac{L}{81} $
#
#
# La rentabilidad se ve penalizada de manera muy significativa, reflejando el alto nivel de riesgo.
#
#
# En esencia, el factor $a$ actúa como un **multiplicador inverso del riesgo**.  Convierte una calificación de riesgo en un factor de penalización que modula la rentabilidad de la oportunidad de arbitraje.  Cuanto mayor sea el riesgo país, mayor será la penalización aplicada a la rentabilidad, haciendo que las oportunidades en países riesgosos parezcan menos atractivas en términos de *rentabilidad ajustada por riesgo*.
#
#
# ##### **3.4.3. Metodología de Cálculo Aplicada:**
#
# Para ilustrar cómo funciona el ajuste por riesgo en el contexto de nuestro análisis de arbitraje, repasemos paso a paso el cálculo para el ejemplo de Suiza, tal como lo presentaste:
#
#
# ##### **3.4.4. Diferencial de Tasas de Interés $\text{R}$:**
#
# Comenzamos calculando el diferencial entre la tasa de interés que podemos ofrecer a nuestros clientes ($r_c$) y la tasa total del préstamo en el país extranjero ($r_t$).  Recordemos que $r_t$ es la suma de la tasa base de préstamo en el país extranjero ($r_b$) más nuestro *markup* o margen de beneficio deseado ($m$): $r_t = r_b + m$.
#
#
# En el ejemplo de Suiza, asumimos:
#
#
# *   Tasa del cliente: $r_c = 13\%$
# *   Tasa base de préstamo en Suiza: $r_b = 0.5\%$
# *   *Markup* de préstamo: $m = 6\%$
#
#
# Por lo tanto, la tasa total de préstamo en Suiza es:
#
#
# $$
# r_t = r_b + m = 0.5\% + 6\% = 6.5\%
# $$
#
#
# Y el diferencial de tasas de interés $\text{R}$ es:
#
#
# $$
# R = r_c - r_t = 13\% - 6.5\% = 6.5\%
# $$
#
#
# Un diferencial positivo del 6.5% indica, en principio, una oportunidad de arbitraje atractiva: podríamos obtener fondos en Suiza al 6.5% y prestarlos a nuestros clientes al 13%, generando un margen bruto del 6.5%.
#
#
# ##### **3.4.5. Beneficio Antes y Después de Impuestos $\text{U y L}$:**
#
#
# El siguiente paso es considerar el costo de cobertura cambiaria $\text{Ch}$
# y el impuesto corporativo $\text{T}$ para refinar la estimación de la rentabilidad.
#
#
# **Beneficio Antes de Impuestos $\text{U}$:**
#
#
# Restamos el costo de cobertura $\text{Ch}$ al diferencial de tasas de interés $\text{R}$
# para obtener el beneficio antes de impuestos $\text{U}$
#
#
# Para Suiza, se calculó un costo de cobertura negativo de $Ch = -0.036\%$.
#
#
# $$
# U = R - Ch = 6.5\% - (-0.036\%) \approx 6.5\%
# $$
#
#
# Este valor de 6.5% representa la rentabilidad potencial del arbitraje *antes* de considerar los impuestos.
# Se observa que como el costo de hedging es practicamente nulo, el riesgo cambial es mínimo.
#
#
# **Beneficio Después de Impuestos $\text{L}$:**
#
#
# Aplicamos la tasa de impuesto corporativo $\text{T}$ del país extranjero
# Suiza en este caso, con $\text{T} = 14.6\%$
# al beneficio antes de impuestos para obtener el beneficio después de impuestos $\text{L: }$
#
#
# $$
# L = U \cdot (1 - T) = 6.5\% \cdot (1 - 0.146) = 6.5\% \cdot 0.854 \approx 5.55\%
# $$
#
# El beneficio después de impuestos de 5.5% ya es una medida más realista de la rentabilidad neta que podríamos esperar obtener.
#
#
# ##### **3.4.6. Beneficio Ajustado por Riesgo ($L_r$):**
#
# Finalmente, aplicamos el ajuste por riesgo utilizando la calificación de riesgo país ($te$) de Suiza.  Según los datos, Suiza tiene una calificación de riesgo de $te = 100$ (riesgo mínimo). Calculamos el factor de ajuste $a$:
#
#
# $$
# a = 101 - te = 101 - 100 = 1
# $$
#
#
# Y aplicamos la fórmula del beneficio ajustado por riesgo:
#
#
# $$
# L_r = \frac{L}{a} = \frac{5.55\%}{1} = 5.55\%
# $$
#
#
# En este caso, dado que Suiza tiene el riesgo mínimo posible ($te = 100$, $a = 1$), el beneficio ajustado por riesgo es **igual al beneficio después de impuestos**. Esto tiene sentido, ya que en un país de riesgo prácticamente nulo, no se necesita penalizar la rentabilidad por riesgo país.
#
#
# **Observaciones:**
#
# El ajuste por riesgo es una herramienta fundamental para refinar el análisis de oportunidades de arbitraje, especialmente cuando se consideran países con distintos perfiles de riesgo.  Al penalizar la rentabilidad en función del riesgo país, se obtienen estimaciones más realistas y prudentes, que permiten tomar decisiones de inversión más informadas y evitar la sobreestimación de ganancias en mercados potencialmente volátiles o inestables. Este ajuste, combinado con el uso de la proxy de inflación cuando los mercados *forward* no están disponibles, proporciona un marco de análisis más completo y robusto para la evaluación de oportunidades de arbitraje internacional.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# --- File Path ---
file_path = "/home/luisvinatea/Dev/Repos/aquaculture/beraqua/data/datasets/indicators/forex/arbitrage_results.csv"

# --- Load Data ---
try:
    arbitrage_df = pd.read_csv(file_path)
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
    exit()


columns_to_rename = {'country': 'País','currency_code': 'Moneda','interest_rate_diff': 'Margen Interés con Cliente','annual_hedging_cost': 'Costo de Hedging','hedging_type':'Proxy','pre_tax_arbitrage_profit': 'Utilidad antes de Impuestos','post_tax_arbitrage_profit': 'Utilidad Después de Impuestos','risk_adjusted_profit': 'Utilidad Ajustada Riesgo','risk_rating': 'Ranking Credito','corporate_tax': 'Impuesto Corporativo','inflation_rate': 'Tasa de Inflación','loan_interest_rate': 'Tasa Base Préstamo', 'loan_markup_percentage': 'Markup Préstamo','total_loan_rate': 'Tasa Préstamo Total'}

arbitrage_df.rename(columns=columns_to_rename, inplace=True)


# --- Ensure Numeric Conversion ---
arbitrage_df['Impuesto Corporativo'] = pd.to_numeric(arbitrage_df['Impuesto Corporativo'], errors='coerce')
arbitrage_df['Utilidad Ajustada Riesgo'] = pd.to_numeric(arbitrage_df['Utilidad Ajustada Riesgo'], errors='coerce')
arbitrage_df['Tasa Base Préstamo'] = pd.to_numeric(arbitrage_df['Tasa Base Préstamo'], errors='coerce')
arbitrage_df['Costo de Hedging'] = pd.to_numeric(arbitrage_df['Costo de Hedging'], errors='coerce')

# --- País Name Mapping (Spanish) ---
country_name_mapping = { 'afghanistan': 'Afganistán', 'albania': 'Albania', 'algeria': 'Argelia', 'andorra': 'Andorra', 'angola': 'Angola', 'antigua_and_barbuda': 'Antigua y Barbuda', 'argentina': 'Argentina', 'armenia': 'Armenia', 'australia': 'Australia', 'austria': 'Austria', 'azerbaijan': 'Azerbaiyán', 'bahamas': 'Bahamas', 'bahrain': 'Baréin', 'bangladesh': 'Bangladés', 'barbados': 'Barbados', 'belarus': 'Bielorrusia', 'belgium': 'Bélgica', 'belize': 'Belice', 'benin': 'Benín', 'bhutan': 'Bután', 'bolivia': 'Bolivia', 'bosnia_and_herzegovina': 'Bosnia-Herzegovina', 'botswana': 'Botsuana', 'brazil': 'Brasil', 'brunei': 'Brunéi', 'bulgaria': 'Bulgaria', 'burkina faso': 'Burkina Faso', 'burundi': 'Burundi', 'cambodia': 'Camboya', 'cameroon': 'Camerún', 'canada': 'Canadá', 'cape verde': 'Cabo Verde', 'central african republic': 'República Centroafricana', 'chad': 'Chad', 'chile': 'Chile', 'china': 'China', 'colombia': 'Colombia', 'comoros': 'Comoras', 'costa_rica': 'Costa Rica', 'cote_d_ivoire': 'Costa de Marfil', 'croatia': 'Croacia', 'cuba': 'Cuba', 'cyprus': 'Chipre', 'czech_republic': 'República Checa', 'democratic republic of the congo': 'República Democrática del Congo', 'denmark': 'Dinamarca', 'djibouti': 'Yibuti', 'dominica': 'Dominica', 'dominican_republic': 'República Dominicana', 'east_timor': 'Timor Oriental', 'ecuador': 'Ecuador', 'egypt': 'Egipto', 'el_salvador': 'El Salvador', 'equatorial guinea': 'Guinea Ecuatorial', 'eritrea': 'Eritrea', 'estonia': 'Estonia', 'ethiopia': 'Etiopía', 'fiji': 'Fiyi', 'finland': 'Finlandia', 'france': 'Francia', 'gabon': 'Gabón', 'gambia': 'Gambia', 'georgia': 'Georgia', 'germany': 'Alemania', 'ghana': 'Ghana', 'greece': 'Grecia', 'grenada': 'Granada', 'guatemala': 'Guatemala', 'guinea': 'Guinea', 'guinea_bissau': 'Guinea-Bisáu', 'guyana': 'Guyana', 'haiti': 'Haití', 'honduras': 'Honduras', 'hungary': 'Hungría', 'iceland': 'Islandia', 'india': 'India', 'indonesia': 'Indonesia', 'iran': 'Irán', 'iraq': 'Irak', 'ireland': 'Irlanda', 'israel': 'Israel', 'italy': 'Italia', 'jamaica': 'Jamaica', 'japan': 'Japón', 'jordan': 'Jordania', 'kazakhstan': 'Kazajistán', 'kenya': 'Kenia', 'kiribati': 'Kiribati', 'kuwait': 'Kuwait', 'kyrgyzstan': 'Kirguistán', 'laos': 'Laos', 'latvia': 'Letonia', 'lebanon': 'Líbano', 'lesotho': 'Lesoto', 'liberia': 'Liberia', 'libya': 'Libia', 'liechtenstein': 'Liechtenstein', 'lithuania': 'Lituania', 'luxembourg': 'Luxemburgo', 'madagascar': 'Madagascar', 'macau': 'Macao','malawi': 'Malaui', 'malaysia': 'Malasia', 'maldives': 'Maldivas', 'mali': 'Malí', 'malta': 'Malta', 'marshall_islands': 'Islas Marshall', 'mauritania': 'Mauritania', 'mauritius': 'Mauricio', 'mexico': 'México', 'micronesia': 'Micronesia', 'moldova': 'Moldavia', 'monaco': 'Mónaco', 'mongolia': 'Mongolia', 'montenegro': 'Montenegro', 'morocco': 'Marruecos', 'mozambique': 'Mozambique', 'myanmar': 'Birmania', 'namibia': 'Namibia', 'nauru': 'Nauru', 'nepal': 'Nepal', 'netherlands': 'Países Bajos', 'new_zealand': 'Nueva Zelanda', 'nicaragua': 'Nicaragua', 'niger': 'Níger', 'nigeria': 'Nigeria', 'north_korea': 'Corea del Norte', 'norway': 'Noruega', 'oman': 'Omán', 'pakistan': 'Pakistán', 'palau': 'Palaos', 'panama': 'Panamá', 'papua_new_guinea': 'Papúa Nueva Guinea', 'paraguay': 'Paraguay', 'peru': 'Perú', 'philippines': 'Filipinas', 'poland': 'Polonia', 'portugal': 'Portugal', 'qatar': 'Catar', 'republic_of_the_congo': 'República del Congo', 'macedonia': 'Macedonia', 'romania': 'Rumania', 'russia': 'Rusia', 'rwanda': 'Ruanda', 'saint_kitts_and_nevis': 'San Cristóbal y Nieves', 'saint_lucia': 'Santa Lucía', 'saint_vincent_and_the_grenadines': 'San Vicente y las Granadinas', 'samoa': 'Samoa', 'san_marino': 'San Marino', 'sao_tome_and_principe': 'Sao Tomé y Príncipe', 'saudi_arabia': 'Arabia Saudita', 'senegal': 'Senegal', 'serbia': 'Serbia', 'seychelles': 'Seychelles', 'sierra leone': 'Sierra Leona', 'singapore': 'Singapur', 'slovakia': 'Eslovaquia', 'slovenia': 'Eslovenia', 'solomon_islands': 'Islas Salomón', 'somalia': 'Somalia', 'south_africa': 'Sudáfrica', 'south_korea': 'Corea del Sur', 'south_sudan': 'Sudán del Sur', 'spain': 'España', 'sri_lanka': 'Sri Lanka', 'sudan': 'Sudán', 'suriname': 'Surinam', 'swaziland': 'Suazilandia', 'sweden': 'Suecia', 'switzerland': 'Suiza', 'syria': 'Siria', 'tajikistan': 'Tayikistán', 'tanzania': 'Tanzania', 'thailand': 'Tailandia', 'taiwan': 'Taiwan','togo': 'Togo', 'tonga': 'Tonga', 'trinidad_and_tobago': 'Trinidad y Tobago', 'tunisia': 'Túnez', 'turkey': 'Turquía', 'turkmenistan': 'Turkmenistán', 'tuvalu': 'Tuvalu', 'uganda': 'Uganda', 'ukraine': 'Ucrania', 'united_arab_emirates': 'Emiratos Árabes Unidos', 'united_kingdom': 'Reino Unido', 'united_states_of_america': 'Estados Unidos', 'uruguay': 'Uruguay', 'uzbekistan': 'Uzbekistán', 'vanuatu': 'Vanuatu', 'venezuela': 'Venezuela', 'vietnam': 'Vietnam', 'yemen': 'Yemen', 'zambia': 'Zambia', 'zimbabwe': 'Zimbabue' }

arbitrage_df['País'] = arbitrage_df['País'].str.lower().map(country_name_mapping).fillna(arbitrage_df['País'])

# --- Get Top for Plotting ---
top_tax_df = arbitrage_df[arbitrage_df['Impuesto Corporativo'] > 0].sort_values(by='Impuesto Corporativo', ascending=True).head(10) # Exclude 0% tax and sort lowest
top_profit_df = arbitrage_df.sort_values(by='Utilidad Ajustada Riesgo', ascending=False).head(10)
top_borrow_df = arbitrage_df.sort_values(by='Tasa Base Préstamo', ascending=True).head(10) # Already sorted by lowest
top_hedge_df = arbitrage_df.sort_values(by='Costo de Hedging', ascending=True).head(10) # Sort by lowest hedging cost


# --- Plot 1: Top by Lowest Corporate Tax (Excluding 0%) ---
plt.figure(figsize=(11.7, 8.3)) # A4 page size in inches (horizontal)
plt.bar(top_tax_df['País'], top_tax_df['Impuesto Corporativo'], color='skyblue')
plt.title('Impuestos Corporativos Más Bajos', fontsize=12) # Clarified title
plt.ylabel('', fontsize=10)
plt.tick_params(axis='x', rotation=45, labelsize=10)
plt.tick_params(axis='y', labelsize=10)
plt.tight_layout()
plt.show()


# --- Plot 2: Top Profit ---
plt.figure(figsize=(11.7, 8.3)) # A4 page size in inches (horizontal)
plt.bar(top_profit_df['País'], top_profit_df['Utilidad Ajustada Riesgo'], color='lightgreen')
plt.title('Mayor Ganancia Ajustada por Riesgo e Impuestos', fontsize=12) # Clarified title
plt.ylabel('', fontsize=10)
plt.tick_params(axis='x', rotation=45, labelsize=10)
plt.tick_params(axis='y', labelsize=10)
plt.tight_layout()
plt.show()

# --- Plot 3: Top Borrowing ---
plt.figure(figsize=(11.7, 8.3)) # A4 page size in inches (horizontal)
plt.bar(top_borrow_df['País'], top_borrow_df['Tasa Base Préstamo'], color='salmon')
plt.title('Fuentes de Préstamo con Tasas Base Más Bajas', fontsize=12) # Clarified title
plt.ylabel('', fontsize=10)
plt.tick_params(axis='x', rotation=45, labelsize=10)
plt.tick_params(axis='y', labelsize=10)
plt.tight_layout()
plt.show()

# --- Plot 4: Top Hedging (Lowest Cost) ---
plt.figure(figsize=(11.7, 8.3)) # A4 page size in inches (horizontal)
plt.bar(top_hedge_df['País'], top_hedge_df['Costo de Hedging'], color='purple')
plt.title('Divisas con Menor Costo de Hedging', fontsize=12) # Clarified title
plt.ylabel('', fontsize=10)
plt.tick_params(axis='x', rotation=45, labelsize=10)
plt.tick_params(axis='y', labelsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **3.5. Resultados**
# ##### **3.5.1. Impuestos Corporativos Más Bajos (Gráfica Superior Izquierda):**
#
# * **Enfoque Limitado:** Esta gráfica se centra exclusivamente en los países con las tasas de impuesto corporativo más bajas. Si bien un impuesto bajo incrementa la rentabilidad *después* de impuestos, **ignora por completo otros factores cruciales** para el arbitraje, como el costo de financiamiento (tasas de interés de préstamo), el costo de cobertura cambiaria y el riesgo país.
#
# * **Países Destacados:** Barbados, Emiratos Árabes Unidos y Hungría se encuentran entre los países con los impuestos corporativos más bajos. Estos países podrían parecer atractivos si solo consideramos este factor. **Perspectiva de la Lucratividad Ajustada por Riesgo:** Al observar la gráfica de "Mayor Ganancia Ajustada por Riesgo e Impuestos" (gráfica superior derecha), **Barbados desaparece del top 10**, y aunque Emiratos Árabes Unidos e Hungría permanecen, su posición relativa cambia significativamente. Esto indica que, si bien tienen impuestos bajos, otros factores (como riesgo o costos de hedging) disminuyen su atractivo general en un análisis ajustado por riesgo.
#
# ##### **3.5.2. Fuentes de Préstamo con Tasas Base Más Bajas (Gráfica Inferior Izquierda):**
#
# * **Enfoque Limitado:** Esta gráfica destaca los países con las tasas base de préstamo más bajas. Tasas bajas de préstamo son esenciales para reducir el costo del financiamiento, pero **no consideran el costo de cobertura, los impuestos, o el riesgo asociado al país de préstamo.**
#
# * **Países Destacados:** Japón, Suiza, Camboya y Dinamarca se presentan como las mejores fuentes de préstamo por sus bajas tasas base. **Perspectiva de la Lucratividad Ajustada por Riesgo:** Suiza y Dinamarca se mantienen en el top 10 de la "Mayor Ganancia Ajustada por Riesgo e Impuestos", pero Japón y Camboya no figuran tan prominentemente. Esto sugiere que aunque Japón y Camboya ofrecen financiamiento barato, otros factores (como menor diferencial de tasas de interés con la tasa del cliente, mayores costos de cobertura en algunos casos, o un ajuste por riesgo más desfavorable) hacen que su lucratividad ajustada por riesgo sea menor en comparación con Suiza o Dinamarca.
#
# ##### **3.5.3. Divisas con Menor Costo de Hedging (Gráfica Inferior Derecha):**
#
# * **Enfoque Limitado:** Esta gráfica se centra en las divisas con el menor costo de hedging. Un bajo costo de hedging es favorable, pero **no es el único determinante de la rentabilidad del arbitraje.** Ignora el diferencial de tasas de interés bruto, los impuestos y el riesgo país. Un hedging barato en una divisa de un país con tasas de interés muy bajas y alto riesgo podría no ser una buena oportunidad.
#
# *  **Países Destacados:** Suiza, Dinamarca, Suecia, Noruega y Canadá aparecen entre las divisas con menor costo de hedging (incluso costos negativos, que implican ganancias al cubrir). Estos suelen ser países con economías estables y mercados financieros desarrollados. **Perspectiva de la Lucratividad Ajustada por Riesgo:** Observamos una **fuerte correlación** entre los países con menor costo de hedging (Suiza, Dinamarca, Suecia, Noruega, Canadá) y los países que aparecen en el top de "Mayor Ganancia Ajustada por Riesgo e Impuestos". Esto es lógico porque un menor costo de hedging contribuye directamente a una mayor rentabilidad neta del arbitraje. Sin embargo, la posición relativa de los países puede cambiar ligeramente al incorporar otros factores.
#
# ##### **3.5.4. Mayor Ganancia Ajustada por Riesgo e Impuestos (Gráfica Superior Derecha):**
#
# *  **Enfoque Integral:** Esta gráfica presenta la **lucratividad ajustada por riesgo ($L_r$) como métrica principal**. $L_r$ **integra** el diferencial de tasas de interés bruto, el costo de cobertura, los impuestos corporativos y, crucialmente, el riesgo país.  Al penalizar la rentabilidad según el riesgo, esta métrica nos ofrece una **visión más realista y prudente** de las oportunidades de arbitraje.
#
# *  **Países Destacados:** Suiza, Dinamarca, Luxemburgo, Países Bajos, Canadá y Alemania se destacan en esta gráfica como las oportunidades más lucrativas *ajustadas por riesgo*. Estos países tienden a ser economías desarrolladas con un bajo riesgo país, costos de hedging bajos o incluso negativos, y tasas de interés de préstamo relativamente bajas (aunque no necesariamente las más bajas absolutas).
#
# ##### **3.5.5. Conclusiones Clave sobre la Lucratividad Ajustada por Riesgo:**
#
# * **Visión Holística:** La lucratividad ajustada por riesgo ($L_r$) proporciona una **visión más holística y equilibrada** de las oportunidades de arbitraje al considerar múltiples factores interrelacionados:  diferencial de tasas de interés, costo de cobertura, impuestos y riesgo país.
#
# * **Priorización de la Rentabilidad Real y Sostenible:** $L_r$ ayuda a priorizar oportunidades que no solo ofrecen alta rentabilidad nominal, sino también una rentabilidad robusta y sostenible al tener en cuenta el riesgo. Evita la sobreestimación de ganancias en países con alto riesgo, donde la volatilidad cambiaria o la inestabilidad económica podrían erosionar rápidamente las ganancias aparentes.
#
# * **Identificación de Oportunidades de Alta Calidad:** Los países que se destacan consistentemente en la gráfica de $L_r$ (Suiza, Dinamarca, etc.)  representan **oportunidades de arbitraje de mayor calidad**, donde la rentabilidad se equilibra mejor con el riesgo. Estos países suelen ser más predecibles y menos propensos a eventos imprevistos que podrían impactar negativamente la operación de arbitraje.
#
# * **Más Allá de los Indicadores Aislados:**  Al comparar las gráficas, vemos que confiar en un solo indicador (como impuestos bajos o tasas de préstamo bajas) puede ser engañoso. La lucratividad ajustada por riesgo nos lleva más allá de la visión parcial de los indicadores aislados y nos ofrece una métrica más completa y útil para la toma de decisiones en el arbitraje internacional. En resumen, la lucratividad ajustada por riesgo no solo nos dice dónde podríamos obtener teóricamente la mayor ganancia *bruta*, sino que nos indica **dónde podemos obtener la mejor ganancia en relación al nivel de riesgo que estamos asumiendo**. Esto es crucial para una estrategia de arbitraje exitosa y sostenible a largo plazo.
# ## **Capítulo IV: Plan de Financiamiento a Camaroneras**
#
# ### **4.1. Introducción al plan de financiamiento**
#
# Este capítulo desarrolla el plan de financiamiento dirigido a las camaroneras, fundamentado en el análisis de viabilidad del financiamiento en el extranjero presentado en el Capítulo 3. La empresa financiera, descrita en el Capítulo 2, propone un modelo de negocio que facilita el acceso a capital para las camaroneras bajo condiciones favorables, mitigando riesgos y promoviendo la rentabilidad del sector. El plan incluye la selección de países óptimos para obtener financiamiento, los criterios de elegibilidad para las camaroneras, las condiciones específicas del financiamiento y las proyecciones financieras que respaldan su viabilidad. En esta versión actualizada, el plan de financiamiento incorpora un elemento clave optimizado mediante simulación: **un pago inicial del 25% del principal** por parte de la camaronera, lo cual se refleja en las condiciones y proyecciones financieras presentadas a continuación.
#
# ### **4.2. Justificación del financiamiento a camaroneras**
#
# El sector camaronero, como se expuso en el Capítulo 1, enfrenta limitaciones significativas en el acceso a financiamiento debido a su alta volatilidad y riesgos asociados. No obstante, su relevancia económica y potencial de crecimiento lo convierten en un área de oportunidad para la inversión. Este plan busca superar dichas barreras ofreciendo una alternativa de capital que permita a las camaroneras optimizar sus operaciones, aumentar su competitividad y contribuir al desarrollo sostenible del sector.
#
# ### **4.3. Selección de países para el financiamiento**
#
# Con base en los datos analizados y presentados en los gráficos de métricas financieras, se seleccionó **Suiza** como el país de financiación.
#
# ### **4.4. Criterios de elegibilidad para camaroneras**
#
# Las camaroneras interesadas en acceder al financiamiento deberán cumplir los siguientes requisitos:
#
# *   **Solvencia financiera**: Demostrar un historial crediticio sólido y flujos de caja estables.
# *   **Escala operativa**: Producir al menos 10.000 toneladas de camarón al año, garantizando economías de escala.
# *   **Sostenibilidad**: Adoptar prácticas de acuicultura certificadas por organismos internacionales.
# *   **Transparencia**: Presentar estados financieros auditados y un plan de negocio con proyecciones a 5 años.
#
# Estos criterios aseguran la selección de camaroneras con alto potencial y bajo riesgo, alineándose con los objetivos estratégicos de la empresa financiera.
#
# ### **4.5. Mecanismo de financiamiento**
#
# El financiamiento se estructurará como una **deuda senior** con las siguientes características clave, **incorporando de manera óptima el pago inicial del principal por parte de la camaronera**:
#
# *   **Pago del Principal Inicial:** Se establece un pago inicial obligatorio del **25% del principal del financiamiento**, el cual deberá ser reintegrado por la camaronera al inicio del mismo.
#
# **Este componente, determinado a través de modelos de optimización financiera, es fundamental para la estructura del plan de financiamiento.** Este pago inicial reduce significativamente el monto total financiado desde el inicio del crédito y, consecuentemente, **disminuye los intereses acumulados a lo largo del plazo, optimizando la estructura financiera para ambas partes.**
#
# **Para la camaronera, representa un menor costo financiero total y una mayor eficiencia en el uso del capital.**
# Para la empresa financiera, este pago inicial reduce la exposición al riesgo desde el comienzo de la operación.
#
# *   **Plazo**: 6 años (72 meses), acorde con el horizonte del proyecto y el ciclo productivo del camarón.
# *   **Tasa de interés**: Fija, basada en el porte de la hacienda y las condiciones del mercado ecuatoriano.
#
# Se consideran tasas que oscilan entre el 12% y el 16% anual, ajustándose al perfil de riesgo y capacidad de pago de cada camaronera.
#
# *   **Descuento de Factoring**: Se aplicará un descuento de Factoring comisionado del proveedor que variará entre el 10% y el 15%, dependiendo del valor de la venta de las cuentas por cobrar (receivables).
#
# Este mecanismo permite a la empresa financiera obtener un retorno por la gestión del riesgo de crédito y la liquidez proporcionada.
#
# *   **Garantías**: Se requerirán garantías que podrán incluir activos de la camaronera y/o una cobertura cambiaria para mitigar el riesgo de fluctuaciones en el tipo de cambio entre el dólar estadounidense y el franco suizo.
#
# Este esquema, que **óptimamente** incluye el pago inicial del principal, reduce la presión financiera inicial para la camaronera al disminuir el monto total de la deuda y distribuye los pagos de manera sostenible a lo largo del tiempo, **optimizando significativamente el flujo de caja y la rentabilidad del proyecto para las camaroneras.**
#
# ### **4.6. Condiciones del financiamiento**
#
# Criterios estrictos de elegibilidad: Se profundiza en la evaluación de elegibilidad, basándose en un análisis exhaustivo de:
#
# *   Historial crediticio: Se realizará una revisión minuciosa en burós de crédito nacionales e internacionales para detectar incidencias de morosidad o litigios previos.
# *   Ingresos operativos y flujos de caja: Se analizarán los estados financieros de los últimos 3 años para evaluar la estabilidad y suficiencia de los ingresos y flujos de caja operativos.
# *   Endeudamiento: Se establecerá un umbral máximo de endeudamiento, limitando la deuda total a un porcentaje prudente de los ingresos brutos anuales (ej. máximo 40%).
# *   Garantías o avales: Se priorizarán clientes que puedan ofrecer activos líquidos o inmuebles como garantías adicionales al valor exportado y a la propiedad.
#
# Modelo de *Scoring* Financiero: Se implementará un modelo de *scoring* financiero para clientes potenciales, utilizando una escala de 1 a 100. Este modelo integrará los criterios de elegibilidad mencionados y otros factores relevantes para obtener una calificación de riesgo crediticio para cada camaronera.
#
# Simulador de Flujo de Caja y Matrices de Riesgo: Se utilizarán herramientas de análisis de riesgo avanzadas:
#
# *   Simulador de flujo de caja: Para proyectar la capacidad de pago de cada cliente en diversos escenarios económicos y productivos (ej. variaciones en precios del camarón, costos de producción, fenómenos climáticos).
# *   Matrices de riesgo: Para identificar y ponderar factores de riesgo críticos específicos para cada camaronera (ej. ubicación geográfica, tecnología utilizada, diversificación de mercados).
#
# Medidas de Mitigación Personalizadas:  Para clientes que presenten un riesgo crediticio elevado según el *scoring* y las matrices de riesgo, se aplicarán medidas de mitigación personalizadas, tales como:
#
# *   Plazos de financiamiento más cortos: Reducción del plazo de pago para acelerar el retorno de la inversión.
# *   Pagos escalonados: Estructuración de un calendario de pagos que se alinee con los ciclos de producción y venta del camarón, ajustando los montos a los flujos de caja proyectados.
# *   Garantías adicionales: Requerimiento de garantías adicionales a las ya establecidas (valor exportado y propiedad), como avales personales o de otras empresas del grupo.
# *   Pago inicial mayor: Considerar, en casos de mayor riesgo, un pago inicial superior al 25% del principal.
#
# ### **4.7. Riesgos y mitigación**
#
# **Requerimiento de garantías**:  Además de las garantías generales previamente mencionadas, se implementarán **garantías específicas y más directas para asegurar aún más la recuperación de la inversión en caso de impago**:
#
# 1. **Garantía sobre Valor Exportado de Camarón por Hectárea:** **Como medida reparativa prioritaria, se exigirá una garantía sobre el valor del camarón exportado por hectárea** de la hacienda que se beneficia directamente de los aireadores financiados. En caso de que la camaronera incurra en impago, **la empresa financiera tendrá el derecho contractual de obtener los pagos directamente de los importadores internacionales** que adquieran el camarón de dicha hacienda. **Este mecanismo asegura una fuente de repago tangible y directamente vinculada a la actividad financiada**, facilitando la recuperación de los fondos. El monto de esta garantía se calculará en función del valor promedio de exportación por hectárea en la región y se ajustará periódicamente.
#
# 2. **Derechos sobre la Propiedad por m² en Caso de Quiebra:** En escenarios de quiebra de la camaronera, **se establecerán derechos de garantía para la empresa financiera sobre una porción específica de la propiedad de la hacienda**, proporcional a los metros cuadrados (m²) de la misma. Dado el tamaño considerable de las haciendas camaroneras (entre 1000 y 9000 hectáreas), **esta garantía representa un activo de respaldo significativo y tangible en caso de liquidación judicial**. Los detalles de esta garantía se especificarán claramente en los contratos de financiamiento, asegurando la protección de los intereses de la empresa financiera ante escenarios extremos.
# ## **Capítulo V: Flujos y Proyecciones**
#
#
#
# $$
# \text{Valoración de la Empresa (sin WACC)}
# $$
#
#
# $$
# \begin{array}{lr}
# \text{Cambio:} & 1 \, \text{CHF} = 1.11 \, \text{USD} \\
# \text{Tasa de Préstamo:} & 6.5\% \\
# \text{Retorno:} & 13\% \\
# \text{Inversión:} & \$108,000 \\
# \text{Impuestos:} & 14.6\% \\
# \text{Deuda - Impuestos} & 6.5\% \times (1 - 14.6\%) = 5.55\% \\
# \text{Ingresos} & \$108,000 \times 13\% = \$14,040 \\
# \text{Financiación} & \$108,000 \times 6.5\% = \$7,020 \\
# \text{Utilidad} & \$14,040 - \$7,020 = \$7,020 \\
# \text{Utilidad - Impuestos} & \$7,020 \times (1 - 14.6\%) = \$5,997 \\
# \end{array}
# $$
#
#
# $$
# \text{VPN} = \sum_{t=1}^{6} \frac{\$5,997}{(1 + 0.0555)^t}
# $$
#
#
#
# $$
# \begin{align*}
# VP_1 = \frac{\$5,997}{(1.0555)^1} = \frac{\$5,997}{1.0555}  \approx \$5,680.72 \\
# VP_2 = \frac{\$5,997}{(1.0555)^2} = \frac{\$5,997}{1.1141}  \approx \$5,382.47 \\
# VP_3 = \frac{\$5,997}{(1.0555)^3} = \frac{\$5,997}{1.1759}  \approx \$5,099.92 \\
# VP_4 = \frac{\$5,997}{(1.0555)^4} = \frac{\$5,997}{1.2409}  \approx \$4,832.07 \\
# VP_5 = \frac{\$5,997}{(1.0555)^5} = \frac{\$5,997}{1.3098}  \approx \$4,578.00 \\
# VP_6 = \frac{\$5,997}{(1.0555)^6} = \frac{\$5,997}{1.3825}  \approx \$4,336.82
# \end{align*}
# $$
#
#
#
# $$
# \begin{array}{cc}
# \text{VPN} = \$5,680.72 \,+\, \$5,382.47 \\
# +\,\$5,099.92 \,+ \,\$4,832.07 \\
# +\,\$4,578.00 + \$4,336.82 \\
# = \$29,910
# \end{array}
# $$
#
#
#
#
#
# $$
# \text{Índice } \text{ de} \text{ Rentabilidad} \text{( IR)}
# $$
#
#
# $$
# \text{IR} = \frac{\text{VPN} + \text{Inversión Inicial}}{\text{Inversión Inicial}}
# $$
#
#
#
# $$
# \text{IR} = \frac{\$29,910 + \$108,000}{\$108,000} \approx 1.28
# $$
#
#
# $$
# \text{Por cada \$1 invertido, el proyecto genera \$1.28 en valor presente}
# $$
#
#
# $$
# \text{Valor Terminal (TV)}
# $$
#
#
# $$
# \text{Supongamos que los flujos de caja crecen a una tasa del 2\%} \\
# \text{anual de manera perpetua después del año 6} \\
# \text{El valor terminal se calcula como:}
# $$
#
#
# $$
# \text{TV} = \frac{\$5,997 \times (1 + 2\%)}{5.55\% - 2\%} = \frac{\$6,116.94}{0.0355} \approx \$172,308
# $$
#
#
# $$
# \text{Valor Presente del Valor Terminal}
# $$
#
#
# $$
# \text{VP del TV} = \frac{\$172,308}{(1.0555)^6} \approx \$125,000
# $$
#
#
# $$
# \text{Valor de la Empresa (EV)}
# $$
#
#
# $$
# \text{EV} = \text{VPN} + \text{VP del TV} = \$29,910 + \$125,000 = \$154,910
# $$
#
#
# $$
# \text{Capacidad de Deuda (Conservadora)}
# $$
#
#
# $$
# \text{Deuda Máxima} = 70\% \times \$108,000 = \$75,600
# $$
#
#
# $$
# \text{Valor del Capital (Equidad)}
# $$
#
#
# $$
# \text{Equidad} = \text{EV} - \text{Deuda} = \$154,910 - \$75,600 = \$79,310
# $$
#
#
# $$
# \text{Estructura de Capital Conservadora}
# $$
#
#
# $$
# \begin{array}{cc}
# \text{Deuda} & \$75,600 \\
# \text{Equidad} & \$79,310 \\
# \end{array}
# $$
#
#
# $$
# \text{Valoración de la Empresa (con WACC)}
# $$
#
#
# $$
# \begin{array}{lr}
# \text{Inversión Inicial} & \$108,000 \\
# \text{Ratio de Deuda/Capital} & 50\text{-}50 \\
# \text{Deuda} &  \, \$54,000 \\
# \text{Capital Propio} & \, \$54,000 \\
# \text{Costo de la Deuda} & 6.5\% \\
# \text{Tasa de Impuestos} & 14.6\% \\
# \text{Flujo de Caja Anual} & \$5,997 \, \\
# \text{Crecimiento Perpetuo} & 2\% \\
# \end{array}
# $$
#
#
# $$
# \text{Costo del Capital Propio } \text{(}r_e\text{)}
# $$
#
#
# $$
# r_e = r_f + \beta \times (r_m - r_f)
# $$
#
#
#
# $$
# r_e = 1.5\% + 1.2 \times (8\% - 1.5\%) \\
# = 1.5\% + 1.2 \times 6.5\% \\
# = 1.5\% + 7.8\% \\
# = 9.3\%
# $$
#
#
# $$
# \text{WACC}
# $$
#
#
# $$
# \text{WACC} = \left(\frac{DL}{I} \times r_d \times (1 - T)\right) + \left(\frac{VE}{I} \times r_e\right)
# $$
#
#
# $$
# \text{Componente de la Deuda}
# $$
#
#
# $$
# \frac{DL}{I} = \frac{\$54,000}{\$108,000} = 0.50
# $$
#
#
#
# $$
# r_d \times (1 - T) \\
# $$
#
#
#
# $$
# = 6.5\% \times (1 - 0.146) \\
# = 6.5\% \times 0.854 \\
# = 5.55\%
# $$
#
#
#
# $$
# = 0.50 \times 5.55\% \\
# = 2.775\%
# $$
#
#
# $$
# \text{Componente del Capital Propio}
# $$
#
#
# $$
# \frac{VE}{I} = \frac{\$54,000}{\$108,000} = 0.50
# $$
#
#
#
# $$
# = 0.50 \times 9.3\% = 4.65\%
# $$
#
#
#
# $$
# \text{WACC} = 2.775\% + 4.65\% = 7.425\%
# $$
#
#
#
# $$
# \text{VPN} = \sum_{t=1}^{6} \frac{\$5,997}{(1 + 0.07425)^t}
# $$
#
#
# $$
# \begin{align*}
# VP_1 &= \frac{\$5,997}{(1.07425)^1} = \frac{\$5,997}{1.07425} \approx \$5,580.10 \\
# VP_2 &= \frac{\$5,997}{(1.07425)^2} = \frac{\$5,997}{1.1540} \approx \$5,196.20 \\
# VP_3 &= \frac{\$5,997}{(1.07425)^3} = \frac{\$5,997}{1.2397} \approx \$4,837.50 \\
# VP_4 &= \frac{\$5,997}{(1.07425)^4} = \frac{\$5,997}{1.3318} \approx \$4,502.70 \\
# VP_5 &= \frac{\$5,997}{(1.07425)^5} = \frac{\$5,997}{1.4307} \approx \$4,190.80 \\
# VP_6 &= \frac{\$5,997}{(1.07425)^6} = \frac{\$5,997}{1.5368} \approx \$3,900.30 \\
# \end{align*}
# $$
#
#
# $$
# \text{VPN} = \$5,580.10 + \$5,196.20 \\
# + \$4,837.50 + \$4,502.70 \\
# + \$4,190.80 + \$3,900.30 \\
# = \$28,207.60 \\
# $$
#
#
# $$
# \text{TV} = \frac{\$5,997 \times (1 + 2\%)}{7.425\% - 2\%} = \frac{\$6,116.94}{0.05425} \approx \$112,700
# $$
#
#
# $$
# \text{VP del TV} = \frac{\$112,700}{(1.07425)^6} \approx \$73,000
# $$
#
#
# $$
# \text{EV} = \text{VPN} + \text{VP del TV} \\
# = \$28,207.60 + \$73,000 \\
# = \$101,207.60 \\
# $$
#
#
# $$
# \text{Equidad} = \text{EV} - \text{Deuda} \\
# = \$101,207.60 - \$54,000 \\
# = \$47,207.60
# $$
#
#
# $$
# \text{IR} = \frac{\text{VPN} + \text{Inversión Inicial}}{\text{Inversión Inicial}}
# $$
#
#
# $$
# \text{IR} = \frac{\$28,207.60 + \$108,000}{\$108,000} \approx 1.26
# $$
# ### 5.1. Análisis de Sensibilidad
# Exploramos ahora como nuestros **indicadores cambian**
# al modificar los **parametros del proyecto**
# en una simulación estocástica programática:

# %%
import numpy as np
from scipy.optimize import differential_evolution
import numpy_financial as npf

def calcular_metricas_parametros_fijos(variables):
    """
    Calcula las métricas financieras del proyecto con parámetros de descuento de factoring
    y porcentaje principal del camaronero fijos.

    Args:
        variables (tuple): Tupla que contiene el markup (en porcentaje) y la tasa de interés al camaronero (en porcentaje).
                           - variables[0]: Markup para la tasa de financiamiento suiza (%).
                           - variables[1]: Tasa de interés anual cobrada a los camaroneros (%).

    Returns:
        dict: Un diccionario que contiene las métricas financieras calculadas:
              - 'roi': Retorno sobre la Inversión (ROI).
              - 'roe': Retorno sobre el Capital Propio (ROE).
              - 'payback': Tiempo de recuperacion de la inversion (en años).
              - 'irr': Tasa Interna de Retorno (TIR).
              - 'npv': Valor Presente Neto (VPN).
              - 'pi': Índice de Rentabilidad (IR).
              - 'rate_difference': Diferencia absoluta entre la tasa de interés al camaronero y la tasa suiza.
              - 'valid': Booleano que indica si el conjunto de parámetros es válido (True) o no (False).
              - 'utilidad_despues_de_impuestos': Utilidad después de impuestos calculada.
              - 'capital_propio': Capital propio invertido.
              - 'monto_financiado': Monto total financiado.
              - 'tasa_suiza_anual': Tasa de interés suiza anual utilizada en el cálculo.
              - 'costo_inicial': Costo inicial de la inversión.
    """
    markup, tasa_camaronero = variables
    descuento_factoring = 0.10  # Fijo en 10%
    porcentaje_principal = 0.25   # Fijo en 25%
    periodo_pago_camaronero_meses = 72 # Periodo de pago del camaronero en meses
    TASA_BASE_SUIZA_ANUAL = 0.005 # Tasa base anual en Suiza
    COSTO_HEDGING_ANUAL = -0.00036 # Costo anual de cobertura (hedging)
    TASA_IMPUESTOS = 0.146 # Tasa de impuestos
    RECEBIBLES_INICIALES = 120_000 # Monto inicial de cuentas por cobrar

    markup /= 100 # Convertir markup de porcentaje a decimal
    tasa_camaronero_anual = tasa_camaronero / 100 # Convertir tasa camaronero de porcentaje a decimal

    # Validar rangos de parámetros de entrada
    if not (0.04 <= markup <= 0.06 and 0.12 <= tasa_camaronero_anual <= 0.14):
        return {
            'roi': -np.inf, 'roe': -np.inf, 'payback': np.inf, 'irr': -np.inf, 'npv': -np.inf, 'pi': -np.inf,
            'rate_difference': np.inf, 'valid': False, 'utilidad_despues_de_impuestos': 0, 'capital_propio': 0, 'monto_financiado': 0, 'tasa_suiza_anual': 0, 'costo_inicial': 0
        }

    periodo_años = periodo_pago_camaronero_meses / 12 # Periodo de pago en años
    costo_inicial = RECEBIBLES_INICIALES * (1 - descuento_factoring) # Costo inicial de la inversión
    principal = costo_inicial * porcentaje_principal # Monto del principal
    capital_propio = costo_inicial - principal # Capital propio invertido
    if capital_propio <= 0:
        return {
            'roi': -np.inf, 'roe': -np.inf, 'payback': np.inf, 'irr': -np.inf, 'npv': -np.inf, 'pi': -np.inf,
            'rate_difference': np.inf, 'valid': False, 'utilidad_despues_de_impuestos': 0, 'capital_propio': 0, 'monto_financiado': 0, 'tasa_suiza_anual': 0, 'costo_inicial': 0
        }

    monto_financiado = costo_inicial - principal # Monto financiado externamente
    tasa_suiza_anual = TASA_BASE_SUIZA_ANUAL + markup + COSTO_HEDGING_ANUAL # Tasa de financiamiento suiza anual
    costo_financiamiento_total = monto_financiado * tasa_suiza_anual * periodo_años # Costo total de financiamiento
    ingreso_intereses_totales = monto_financiado * tasa_camaronero_anual * periodo_años # Ingreso total por intereses cobrados
    utilidad_antes_de_impuestos = ingreso_intereses_totales - costo_financiamiento_total # Utilidad antes de impuestos

    if utilidad_antes_de_impuestos <= 0:
        return {
            'roi': -np.inf, 'roe': -np.inf, 'payback': np.inf, 'irr': -np.inf, 'npv': -np.inf, 'pi': -np.inf,
            'rate_difference': np.inf, 'valid': False, 'utilidad_despues_de_impuestos': 0, 'capital_propio': 0, 'monto_financiado': 0, 'tasa_suiza_anual': 0, 'costo_inicial': 0
        }

    impuestos = utilidad_antes_de_impuestos * TASA_IMPUESTOS # Calculo de impuestos
    utilidad_despues_de_impuestos = utilidad_antes_de_impuestos - impuestos # Utilidad despues de impuestos

    # Cálculo de métricas financieras
    roi = utilidad_despues_de_impuestos / costo_inicial if costo_inicial != 0 else 0 # ROI
    roe = utilidad_despues_de_impuestos / capital_propio if capital_propio != 0 else np.inf # ROE
    payback = costo_inicial / utilidad_despues_de_impuestos if utilidad_despues_de_impuestos != 0 else np.inf # Payback

    inversion_inicial = costo_inicial # Inversión inicial
    flujos_caja = [utilidad_despues_de_impuestos] * 6 # Flujos de caja
    flujo_caja_array = np.insert(flujos_caja, 0, -inversion_inicial) # Array de flujos de caja incluyendo la inversión inicial
    irr_value = npf.irr(flujo_caja_array) # TIR
    npv_value = npf.npv(tasa_suiza_anual, flujo_caja_array) # VPN

    pv_flujos_caja_entrantes = np.sum([flujos_caja[t] / (1 + tasa_suiza_anual)**(t+1) for t in range(len(flujos_caja))]) # Valor presente de flujos de caja entrantes
    pi_value = (pv_flujos_caja_entrantes + inversion_inicial) / inversion_inicial if inversion_inicial != 0 else np.inf # IR

    rate_difference = abs(tasa_camaronero_anual - tasa_suiza_anual) # Diferencia de tasas

    metricas = {
        'roi': roi,
        'roe': roe,
        'payback': payback,
        'irr': irr_value,
        'npv': npv_value,
        'pi': pi_value,
        'rate_difference': rate_difference,
        'valid': True,
        'utilidad_despues_de_impuestos': utilidad_despues_de_impuestos,
        'capital_propio': capital_propio,
        'monto_financiado': monto_financiado,
        'tasa_suiza_anual': tasa_suiza_anual,
        'costo_inicial': costo_inicial
    }
    return metricas

def objetivo_combinado_parametros_fijos(variables):
    """
    Función objetivo combinada para la optimización, penaliza soluciones inválidas
    y aquellas que no cumplen con los rangos objetivo de las métricas financieras.
    Minimiza la diferencia entre la tasa de interés al camaronero y la tasa suiza.

    Args:
        variables (tuple): Tupla que contiene el markup y la tasa de interés al camaronero.

    Returns:
        float: Valor de la función objetivo. Retorna np.inf si la solución no es válida o no cumple las restricciones.
               Retorna la diferencia de tasas si la solución es válida y cumple las restricciones.
    """
    markup, tasa_camaronero = variables
    metricas_objetivo = calcular_metricas_parametros_fijos(variables)

    if not metricas_objetivo['valid']:
        return np.inf  # Penalización alta para conjuntos de parámetros inválidos

    penalizacion = 0 # Inicializar penalización

    # Penalizar soluciones que no cumplen con los rangos objetivo
    if not 0.20 <= metricas_objetivo['irr'] <= 0.30:
        penalizacion += 100  # Penalización sustancial por TIR fuera de rango
    if metricas_objetivo['pi'] <= 1:
        penalizacion += 100  # Penalización sustancial por IR menor o igual a 1
    if metricas_objetivo['npv'] <= 0:
        penalizacion += 100  # Penalización sustancial por VPN menor o igual a 0
    if not 0.10 <= metricas_objetivo['roe'] <= 0.15:
        penalizacion += 100  # Penalización sustancial por ROE fuera de rango
    if not 0.20 <= metricas_objetivo['roi'] <= 0.30:
        penalizacion += 100  # Penalización sustancial por ROI fuera de rango
    if metricas_objetivo['payback'] > 6:
        penalizacion += 100 # Penalización sustancial por Payback mayor a 6 años

    if penalizacion > 0:
        return penalizacion # Retornar la penalización combinada si alguna restricción no se cumple

    return metricas_objetivo['rate_difference'] # Minimizar la diferencia de tasas si se cumplen todos los objetivos


# Definir límites (bounds) para la optimización de markup y tasa_camaronero
limites_parametros_fijos = [(4, 6), (12, 14)] # Límites para markup y tasa_camaronero (rangos en porcentaje)

# Optimización utilizando el algoritmo de evolución diferencial
resultado_fijo = differential_evolution(
    objetivo_combinado_parametros_fijos, # Función objetivo a minimizar
    limites_parametros_fijos,           # Límites de los parámetros
    strategy='best1bin',                # Estrategia de evolución diferencial
    maxiter=1000,                       # Número máximo de iteraciones
    popsize=15,                         # Tamaño de la población en cada iteración
    tol=0.001,                          # Tolerancia para la convergencia
    mutation=(0.5, 1),                  # Rango de mutación
    recombination=0.7,                  # Probabilidad de recombinación
    seed=42                             # Semilla para la reproducibilidad
)

# Extraer resultados de la optimización
variables_optimas_fijas = resultado_fijo.x # Valores óptimos de markup y tasa_camaronero
diferencia_tasas_minimizada = resultado_fijo.fun # Valor mínimo de la diferencia de tasas alcanzado
metricas_optimas_fijas = calcular_metricas_parametros_fijos(variables_optimas_fijas) # Métricas financieras con parámetros óptimos

# Imprimir resultados de la optimización
print(f"""
Parámetros Óptimos para Minimizar la Diferencia de Tasas (con Descuento de Factoring y Principal del Camaronero Fijos) para cumplir con los Objetivos:
- Markup: {variables_optimas_fijas[0]:.2f}%
- Tasa de Interés al Camaronero (Anual): {variables_optimas_fijas[1]:.2f}%
- Descuento de Factoring (Fijo): 10.00%
- Principal del Camaronero (Fijo): 25.00%

Diferencia de Tasas Minimizada: {diferencia_tasas_minimizada:.4f}

Métricas Alcanzadas:
- ROI: {metricas_optimas_fijas['roi']:.2%}
- ROE: {metricas_optimas_fijas['roe']:.2%}
- Payback Time: {metricas_optimas_fijas['payback']:.2f} años
- TIR: {metricas_optimas_fijas['irr']:.2%}
- VPN: ${metricas_optimas_fijas['npv']:,.2f}
- IR: {metricas_optimas_fijas['pi']:.2f}

Rangos Objetivo de las Métricas:
- TIR: 20% - 30%
- IR: > 1
- VPN: > 0
- ROE: 10% - 15%
- ROI: 20% - 30%
- Payback Time: <= 6 años
""")

# --- Cálculo del Modelo de Flujo de Caja Descontado (DCF) ---

# Parámetros asumidos para el DCF
TASA_CRECIMIENTO_PERPETUIDAD = 0.02 # Tasa de crecimiento a perpetuidad
TASA_LIBRE_DE_RIESGO = 0.015 # Tasa libre de riesgo
RETORNO_MERCADO = 0.08 # Retorno esperado del mercado
BETA_APALANCADO = 1.2 # Beta apalancado

# Extraer valores relevantes de las métricas óptimas
utilidad_despues_de_impuestos_anio1 = metricas_optimas_fijas['utilidad_despues_de_impuestos'] # Utilidad después de impuestos del primer año (proxy para FCF)
capital_propio_optimizado = metricas_optimas_fijas['capital_propio'] # Capital propio óptimo
monto_financiado_optimizado = metricas_optimas_fijas['monto_financiado'] # Monto financiado óptimo
tasa_suiza_anual_optima = metricas_optimas_fijas['tasa_suiza_anual'] # Tasa suiza óptima
TASA_IMPUESTOS_DEF = 0.146 # Tasa de impuestos

# Calcular el Costo del Capital Propio (Ke) utilizando CAPM
costo_capital_propio = TASA_LIBRE_DE_RIESGO + BETA_APALANCADO * (RETORNO_MERCADO - TASA_LIBRE_DE_RIESGO)

# Calcular el Costo de la Deuda (Kd) después de impuestos
costo_deuda_antes_de_impuestos = tasa_suiza_anual_optima # Costo de la deuda antes de impuestos es la tasa suiza
costo_deuda_despues_de_impuestos = costo_deuda_antes_de_impuestos * (1 - TASA_IMPUESTOS_DEF) # Costo de la deuda después de impuestos

# Calcular las Ponderaciones de la Estructura de Capital
capital_total = capital_propio_optimizado + monto_financiado_optimizado # Capital total
ponderacion_capital_propio = capital_propio_optimizado / capital_total if capital_total != 0 else 0 # Ponderación del capital propio
ponderacion_deuda = monto_financiado_optimizado / capital_total if capital_total != 0 else 0 # Ponderación de la deuda

# Calcular el WACC (Costo Promedio Ponderado de Capital)
WACC = (ponderacion_capital_propio * costo_capital_propio) + (ponderacion_deuda * costo_deuda_despues_de_impuestos)

# Calcular el Valor de la Empresa (Enterprise Value - EV) utilizando el modelo de crecimiento perpetuo
if WACC <= TASA_CRECIMIENTO_PERPETUIDAD:
    valor_empresa = np.inf # Evitar división por cero o denominador negativo
else:
    valor_empresa = utilidad_despues_de_impuestos_anio1 * (1 + TASA_CRECIMIENTO_PERPETUIDAD) / (WACC - TASA_CRECIMIENTO_PERPETUIDAD)

# Calcular el Valor del Capital Propio (Equity Value)
valor_capital_propio = valor_empresa - monto_financiado_optimizado

# Imprimir resultados del modelo DCF
print(f"""

--- Modelo de Flujo de Caja Descontado (DCF) ---

Supuestos:
- Tasa de Crecimiento a Perpetuidad: {TASA_CRECIMIENTO_PERPETUIDAD:.2%}
- Tasa Libre de Riesgo: {TASA_LIBRE_DE_RIESGO:.2%}
- Retorno del Mercado: {RETORNO_MERCADO:.2%}
- Beta Apalancado: {BETA_APALANCADO:.1f}

Valores Calculados:
- Utilidad Después de Impuestos Año 1 (Proxy FCF): ${utilidad_despues_de_impuestos_anio1:,.2f}
- Costo del Capital Propio (Ke): {costo_capital_propio:.2%}
- Costo de la Deuda (Después de Impuestos) (Kd): {costo_deuda_despues_de_impuestos:.2%}
- Ponderación del Capital Propio: {ponderacion_capital_propio:.2%}
- Ponderación de la Deuda: {ponderacion_deuda:.2%}
- WACC: {WACC:.2%}

Valoración:
- Valor de la Empresa (EV): ${valor_empresa:,.2f}
- Valor del Capital Propio: ${valor_capital_propio:,.2f}
""")
# Out:
# Parámetros Óptimos para Minimizar la Diferencia de Tasas (con Descuento de Factoring y Principal del Camaronero Fijos) para cumplir con los Objetivos:
# - Markup: 5.30%
# - Tasa de Interés al Camaronero (Anual): 12.68%
# - Descuento de Factoring (Fijo): 10.00%
# - Principal del Camaronero (Fijo): 25.00%
#
# Diferencia de Tasas Minimizada: 200.0000
#
# Métricas Alcanzadas:
# - ROI: 26.57%
# - ROE: 35.42%
# - Payback Time: 3.76 años
# - TIR: 15.20%
# - VPN: $34,156.11
# - IR: 2.32
#
# Rangos Objetivo de las Métricas:
# - TIR: 20% - 30%
# - IR: > 1
# - VPN: > 0
# - ROE: 10% - 15%
# - ROI: 20% - 30%
# - Payback Time: <= 6 años
#
#
#
# --- Modelo de Flujo de Caja Descontado (DCF) ---
#
# Supuestos:
# - Tasa de Crecimiento a Perpetuidad: 2.00%
# - Tasa Libre de Riesgo: 1.50%
# - Retorno del Mercado: 8.00%
# - Beta Apalancado: 1.2
#
# Valores Calculados:
# - Utilidad Después de Impuestos Año 1 (Proxy FCF): $28,693.88
# - Costo del Capital Propio (Ke): 9.30%
# ...

# %% [markdown]
# ### 5.2. **Optimización mediante Simulación Estocástica**
#
# Para abordar la complejidad del modelo financiero y encontrar la combinación óptima de markup y tasa de interés, se empleó el algoritmo de **Evolución Diferencial**. Esta técnica de **optimización global** es especialmente adecuada para problemas con múltiples variables y funciones objetivo complejas, como el modelo financiero en cuestión.
#
# El algoritmo de Evolución Diferencial opera de manera similar a la evolución biológica. Comienza con una **población inicial de soluciones candidatas** (combinaciones de markup y tasa de interés) y, a través de procesos iterativos de **mutación, recombinación y selección**, busca mejorar progresivamente las soluciones hacia el óptimo.
#
# En este contexto, el **objetivo principal** del algoritmo fue **minimizar la diferencia entre la tasa de interés cobrada a los  camaroneros y la tasa de financiamiento suiza**, siempre y cuando se cumplieran las restricciones de rentabilidad definidas previamente.  La **función objetivo** del algoritmo fue diseñada para:
#
#
# 1.  **Penalizar fuertemente** las soluciones que no cumplían con las restricciones (TIR, PI, VPN, ROE, ROI, Payback). Esto aseguró que el algoritmo priorizara la búsqueda de soluciones viables y rentables.
#
# 2.  **Minimizar la diferencia de tasas** entre las soluciones que sí cumplían con las restricciones. Esto buscó encontrar la configuración más eficiente en términos de costos de financiamiento y generación de ingresos.
#
# La **simulación estocástica**, inherente al algoritmo de Evolución Diferencial, permitió **explorar de manera eficiente el espacio de soluciones**, evitando quedar atrapado en óptimos locales y aumentando la probabilidad de encontrar el óptimo global o una solución muy cercana a él.
#
#
# Se revisaron estratégicamente los parámetros clave:
#
#
# 1.  **Markup del Préstamo Suizo (4% - 6%):**  Control del costo de financiamiento, con rangos realistas basados en el mercado.
#
# 2.  **Tasa de Interés para Camaroneras (12% - 14% anual):** Equilibrio entre rentabilidad y capacidad de pago del  camaronero, con rangos viables de mercado.
#
# 3.  **Parámetros Fijos:** Descuento de factoring (10%) y porcentaje de principal (25%) se mantuvieron fijos para simplificar la optimización.
#
#
# Las **restricciones** reflejaron estándares de la industria y objetivos financieros, estableciendo rangos objetivo para TIR (20%-30%), IR (>1), VPN (>0), ROE (10%-15%), ROI (20%-30%) y Payback (≤ 6 años).
#
#
# Se realizó un análisis de sensibilidad para establecer rangos de seguridad y minimizar el impacto de desviaciones.
#
#
# ##### 5.2.1. **Resultados**
#
#
# La optimización realizada, con el objetivo de minimizar la diferencia de tasas y cumpliendo con las restricciones financieras,  permitió identificar una **configuración de parámetros óptimos**: **Markup de 5.30% y Tasa de Interés al Camaronero de 12.68% anual**. Esta configuración, manteniendo fijos el descuento de factoring en 10% y el principal del camaronero en 25%,  **minimiza la diferencia de tasas a $200,000.00** y  alcanza las siguientes métricas:
#
#
# -   **ROI: 26.57%** (dentro del rango objetivo de 20%-30%)
# -   **ROE: 35.42%** (superior al rango objetivo de 10%-15%)
# -   **Payback Time: 3.76 años** (dentro del rango objetivo de ≤ 6 años)
# -   **TIR: 15.20%** (inferior al rango objetivo de 20%-30%)
# -   **VPN: $34,156.11** (superior al rango objetivo de > 0)
# -   **IR: 2.32** (superior al rango objetivo de > 1)
#
#
# Si bien la optimización identificó esta configuración como la que minimiza la diferencia de tasas cumpliendo la mayoría de restricciones, es importante considerar las siguientes observaciones:
#
#
# 1.  **Flexibilidad en las Restricciones:**   En la práctica, **la rigidez en el cumplimiento estricto de todos los rangos objetivo puede ser contraproducente**.  En este caso, se observa que el ROE supera significativamente el rango objetivo, mientras que la TIR se sitúa por debajo del mismo.  **Priorizar el valor global del proyecto podría implicar aceptar ciertas desviaciones** en indicadores individuales.  Por ejemplo, el **alto ROE podría compensar una TIR ligeramente inferior al rango meta**, especialmente si el VPN y el IR se mantienen sólidos, como es el caso.
#
#
# 2.  **Análisis de Sensibilidad Adicional:**  Si bien se optimizaron el markup y la tasa de interés, se mantuvieron fijos el descuento de factoring y el porcentaje de principal.  Para un análisis más completo, sería **fundamental realizar un análisis de sensibilidad** que explore cómo **variaciones en estos parámetros fijos** (y en otros supuestos del modelo) **afectan los resultados financieros**.  Este análisis permitiría identificar los **factores de mayor riesgo e incertidumbre** y desarrollar **estrategias de mitigación** adecuadas.
#
#
# 3.  **Estrategia de Implementación:**  Para la implementación exitosa del proyecto, se sugiere desarrollar un plan de monitoreo periódico de las métricas financieras clave y de las condiciones del mercado.  Este plan permitirá ajustar estratégias de manera proactiva en función de cambios en el entorno financiero, asegurando la adaptabilidad y sostenibilidad del negocio a largo plazo.  Adicionalmente, se recomendó una estrategia de mitigación de riesgos basada en la diversificación de fuentes de financiamiento y en la implementación de coberturas contra fluctuaciones cambiarias, fortaleciendo aún más la estabilidad financiera del proyecto.
#
#
# En conclusión, el análisis y la optimización realizada han permitido encontrar una configuración financiera viable y atractiva, asegurando la rentabilidad del proyecto y la generación de valor para los inversionistas. La configuración óptima identificada (Markup 5.30% y Tasa de Interés 12.68%)  proporciona un **Valor de la Empresa de $572,688.27 y un Valor del Capital Propio de $491,688.27**, **confirmado por la valoración DCF**.  El detallado análisis financiero presentado en este capítulo robustece las conclusiones y recomendaciones que se expondrán en el capítulo final.
# ## **Capítulo VI: Conclusiones y Recomendaciones Finales**
#
#
# Este capítulo final tiene como objetivo principal presentar las conclusiones generales derivadas de la investigación y ofrecer recomendaciones prácticas y estratégicas basadas en los hallazgos.  Retomando la pregunta fundamental de la investigación:
#
#
# **¿Es viable la creación de una empresa financiera, basada en capital obtenido en el exterior, para proveer créditos a camaroneras ecuatorianas, específicamente para la adquisición de sistemas de aireación, y bajo qué modelo de negocio y condiciones financieras resulta sostenible y rentable esta operación?**
#
#
# Las conclusiones que se presentan a continuación responden directamente a esta interrogante, sustentadas en el análisis exhaustivo y los resultados obtenidos a lo largo de esta tesis, incluyendo la reciente valoración mediante el Modelo de Flujo de Caja Descontado (DCF).
#
#
# ### **Conclusiones Generales**
#
#
# 1.  **Viabilidad del Modelo Financiero:**  La respuesta a la pregunta fundamental de investigación es **afirmativa**.  El análisis detallado, la optimización del modelo financiero propuesto, y la **valoración mediante el Modelo de Flujo de Caja Descontado (DCF) demuestran consistentemente que es viable y rentable la creación de una empresa financiera** con capital obtenido en el exterior para otorgar créditos a camaroneras ecuatorianas, específicamente para la adquisición de sistemas de aireación.  Bajo las condiciones optimizadas, el modelo presenta métricas financieras atractivas que superan los umbrales de rentabilidad y viabilidad definidos. La valoración DCF, con un **Valor de la Empresa (EV) estimado en \$572,688.27 y un Valor del Capital Propio de \$491,688.27**,  refuerza de manera significativa esta conclusión, indicando un potencial sustancial de creación de valor.
#
#
# 2.  **Rentabilidad Atractiva bajo Parámetros Óptimos:** La simulación estocástica y el algoritmo de Evolución Diferencial permitieron identificar una configuración de parámetros óptima (markup de 5.3% y tasa de interés al  camaronero de 12.68%).  Con estos parámetros, el modelo financiero alcanza un **ROI del 26.57%, un ROE del 35.42%, un Payback de 3.76 años, un VPN positivo de \$34,156.11 y un IR de 2.32**.  Estas métricas, en conjunto, indican una **rentabilidad sólida y un retorno atractivo para los inversores**, confirmando la viabilidad económica del proyecto.  Si bien la TIR (15.20%) no alcanzó el rango objetivo más ambicioso, se considera aceptable y competitiva, especialmente en el contexto de las tasas de interés actuales y el perfil de riesgo del sector.  **Adicionalmente, la valoración DCF respalda esta rentabilidad atractiva, proyectando un valor significativo para la empresa y sus accionistas.**
#
#
# 3.  **Suiza como Fuente de Financiamiento Preferente:**  El análisis comparativo de diferentes países como fuentes de financiamiento externo, basado en métricas como el Índice de Rentabilidad (IR), impuestos corporativos (T %), utilidad ajustada por riesgo ($L_r$) y Valor Actual Neto (VAN),  **identifica a Suiza como la opción más atractiva**.  Suiza destaca por su alto IR, bajo costo de cobertura, baja penalización por riesgo país y VAN elevado, ofreciendo un entorno financiero favorable para la obtención de capital y la maximización de la rentabilidad del proyecto.
#
#
# 4.  **Optimización como Herramienta Clave:**  La **optimización mediante simulación estocástica y el algoritmo de Evolución Diferencial resultó fundamental** para refinar el modelo financiero y encontrar una configuración de parámetros que maximizara el valor del proyecto.  La optimización permitió **equilibrar la rentabilidad para la empresa financiera con la sostenibilidad del crédito para las camaroneras**, minimizando la diferencia entre la tasa de financiamiento y la tasa cobrada a los  camaroneroes, sin comprometer la viabilidad del negocio.
#
#
# 5.  **Potencial para Impulsar la Modernización del Sector Camaronero:**  La implementación del modelo de negocio propuesto tiene el potencial de **facilitar el acceso a financiamiento para las camaroneras ecuatorianas**, especialmente para las PYMEs, y **promover la adopción de tecnologías clave como los sistemas de aireación**.  Al mejorar la disponibilidad de crédito para la modernización tecnológica, la empresa financiera propuesta puede **contribuir significativamente al aumento de la eficiencia productiva, la sostenibilidad ambiental y la competitividad del sector camaronero ecuatoriano** en el mercado global.
#
#
# ### **Recomendaciones**
#
#
# Basadas en las conclusiones de esta investigación, incluyendo la robusta valoración DCF, se presentan las siguientes recomendaciones finales, divididas en áreas clave:
#
#
# ##### **1.  Implementación y Desarrollo del Modelo de Negocio**
#
# *   **Estudio de Mercado Detallado en Ecuador:**  Se recomienda realizar un estudio de mercado exhaustivo y específico en el sector camaronero ecuatoriano para **validar la demanda real de financiamiento para sistemas de aireación**, **afinar la segmentación de clientes**, **adaptar las condiciones de crédito** a las necesidades específicas de las camaroneras y **establecer estrategias de comercialización y distribución** efectivas.
#
# *   **Desarrollo de Plan Operativo y de Riesgos Detallado:**  Es crucial **desarrollar un plan operativo integral** que defina los procesos internos de la empresa financiera, la estructura organizacional, los recursos humanos necesarios y la infraestructura tecnológica.  Adicionalmente, se debe **diseñar un plan de gestión de riesgos robusto** que identifique, evalúe y mitigue los riesgos asociados al negocio, incluyendo el riesgo crediticio, el riesgo operativo, el riesgo de mercado y el riesgo regulatorio.
#
# *   **Búsqueda de Financiamiento Inicial en Suiza (u Otras Jurisdicciones Atractivas):**  Con base en el análisis comparativo y **respaldado por la valoración DCF que proyecta un alto Valor del Capital Propio**, se recomienda **priorizar la búsqueda de financiamiento inicial en Suiza**, aprovechando las condiciones financieras favorables y el entorno estable.  Se deben **explorar diversas fuentes de financiamiento** (inversores institucionales, fondos de inversión, banca privada, etc.) y **preparar una propuesta de valor sólida** que destaque el potencial de rentabilidad, **el valor proyectado por el DCF**, y el impacto positivo del proyecto en el sector camaronero ecuatoriano. **La valoración DCF puede ser un elemento clave para presentar a potenciales inversores, demostrando cuantitativamente el atractivo financiero de la empresa.**
#
# *   **Alianzas Estratégicas con Actores Clave:**  Se sugiere establecer **alianzas estratégicas con actores clave del sector camaronero ecuatoriano**, como asociaciones de productores, proveedores de tecnología de aireación, empresas de consultoría y entidades gubernamentales.  Estas alianzas pueden **facilitar el acceso al mercado**, **reducir los riesgos operativos** y **fortalecer la propuesta de valor** de la empresa financiera.
#
#
# ##### **2.  Recomendaciones para Futuras Investigaciones**
#
# *   **Análisis de Sensibilidad Extendido:**  Se recomienda realizar un **análisis de sensibilidad más profundo** que explore el impacto de variaciones en otros parámetros clave del modelo financiero, más allá del markup y la tasa de interés.  Esto incluye analizar la sensibilidad ante cambios en el descuento de factoring, el porcentaje de principal, las tasas de morosidad, los costos operativos, el precio del camarón en el mercado internacional y otros factores relevantes.
#
# *   **Incorporación de Factores Ambientales y Sociales:**  Futuras investigaciones podrían **ampliar el modelo financiero para incorporar factores ambientales y sociales**, tales como los beneficios de la adopción de sistemas de aireación en términos de sostenibilidad ambiental (reducción del consumo de energía, disminución de emisiones, mejora de la calidad del agua) y el impacto social del proyecto en las comunidades camaroneras (generación de empleo, mejora de ingresos, desarrollo local).  La cuantificación y monetización de estos beneficios podría fortalecer aún más la propuesta de valor del modelo, **e incluso ser incorporados en una valoración DCF más exhaustiva en el futuro.**
#
# *   **Exploración de Modelos de Financiamiento Alternativos:**  Se podría explorar la viabilidad de **modelos de financiamiento alternativos o complementarios**, como el *crowdfunding*, el financiamiento de impacto, la titularización de activos o la emisión de bonos verdes.  Estos modelos podrían diversificar las fuentes de financiamiento, reducir la dependencia del capital externo y atraer inversores con perfiles específicos (ej. inversores de impacto).
#
# *   **Comparación con Otros Países y Sectores:**  Sería valioso **comparar el modelo de negocio propuesto con experiencias similares en otros países productores de camarón o en otros sectores agrícolas** que enfrentan desafíos de financiamiento y requieren la adopción de tecnologías para mejorar la productividad y la sostenibilidad.  Este análisis comparativo podría identificar mejores prácticas, lecciones aprendidas y oportunidades de adaptación e innovación.
#
#
# ##### 3.  **Recomendaciones para Políticas Públicas**
#
# *   **Promoción de Mecanismos de Financiamiento Innovadores:**  Se recomienda que el gobierno ecuatoriano **promueva políticas públicas que faciliten el desarrollo y la implementación de mecanismos de financiamiento innovadores para el sector acuícola**, incluyendo incentivos fiscales, garantías estatales, programas de capacitación y asistencia técnica para empresas financieras especializadas y productores acuícolas.
#
# *   **Fomento de la Adopción de Tecnologías Sostenibles:**  Es importante que el gobierno ecuatoriano **establezca políticas que fomenten la adopción de tecnologías sostenibles en el sector acuícola**, como los sistemas de aireación, a través de subsidios, líneas de crédito preferenciales, programas de transferencia tecnológica y regulaciones ambientales que incentiven las prácticas productivas responsables.
#
# *   **Fortalecimiento del Marco Regulatorio:**  Se recomienda **revisar y fortalecer el marco regulatorio del sistema financiero ecuatoriano** para facilitar el acceso al crédito a las PYMEs del sector acuícola, simplificando los trámites, reduciendo los costos de cumplimiento, promoviendo la transparencia y la competencia en el mercado de crédito y creando un entorno favorable para la inversión y el crecimiento del sector.
#
#
# ### **Consideraciones Finales**
#
# En conclusión, esta investigación ha demostrado la viabilidad y el potencial de un modelo de negocio innovador para una empresa financiera que provea créditos a las camaroneras ecuatorianas para la adquisición de sistemas de aireación.  La optimización del modelo financiero, el análisis comparativo de fuentes de financiamiento, la **robusta valoración DCF que respalda el valor económico del proyecto**, y las recomendaciones presentadas en este capítulo final ofrecen una hoja de ruta sólida para la implementación exitosa de este proyecto y para contribuir al fortalecimiento y la sostenibilidad del sector camaronero ecuatoriano.
#
# Es importante destacar que, si bien los resultados son prometedores y **la valoración DCF proporciona una perspectiva financiera sólida**, la implementación real del modelo de negocio requerirá un análisis continuo y una adaptación flexible a las condiciones del mercado y a los desafíos operativos.  El monitoreo constante de las métricas financieras, la gestión proactiva de los riesgos y la capacidad de innovación serán factores clave para el éxito a largo plazo de la empresa financiera propuesta y para su impacto positivo en el sector camaronero ecuatoriano.
# ## **Referencias**
#
#
# **Banco Central del Ecuador**. (s.f.). *Estadísticas económicas*. Recuperado el 23 de noviembre de 2024, de [https://contenido.bce.fin.ec/home1/estadisticas/](https://contenido.bce.fin.ec/home1/estadisticas/)
#
# **Banco Central del Ecuador**. (s.f.). *Boletín estadístico mensual N° 2047, Sección Sector Externo*. Recuperado el 23 de noviembre de 2024, de [https://contenido.bce.fin.ec/home1/estadisticas/bolmensual/IEMensual.jsp](https://contenido.bce.fin.ec/home1/estadisticas/bolmensual/IEMensual.jsp)
#
# **Cámara Nacional de Acuacultura**. (s.f.). *Estadísticas del sector camaronero*. Recuperado el 23 de noviembre de 2024, de [https://www.cna-ecuador.com/estadisticas/](https://www.cna-ecuador.com/estadisticas/)
#
# **Ministerio de Producción, Comercio Exterior, Inversiones y Pesca**. (s.f.). *Comercio exterior*. Recuperado el 23 de noviembre de 2024, de [https://produccion.gob.ec/comercio-exterior/](https://produccion.gob.ec/comercio-exterior/)
#
# **Ministerio de Producción**. (2024). *Dashboard Sector Camaronero 2024*. Recuperado el 23 de noviembre de 2024, de [https://produccion.gob.ec/comercio-exterior/](https://produccion.gob.ec/comercio-exterior/)
#
# **Organización de las Naciones Unidas para la Alimentación y la Agricultura (FAO)**. (s.f.). *Desarrollo de la acuicultura en China*. Recuperado el 23 de noviembre de 2024, de [https://www.fao.org/4/y4762s/y4762s07.htm](https://www.fao.org/4/y4762s/y4762s07.htm)
#
# **Organización de las Naciones Unidas para la Alimentación y la Agricultura (FAO)**. (s.f.). *Globefish: Market reports*. Recuperado el 23 de noviembre de 2024, de [https://www.fao.org/in-action/globefish/market-reports](https://www.fao.org/in-action/globefish/market-reports)
#
# **Organización de las Naciones Unidas para la Alimentación y la Agricultura (FAO)**. (s.f.). *Importancia del financiamiento en la acuicultura sostenible*. Recuperado el 23 de noviembre de 2024, de [https://www.fao.org/4/x5823s/X5823s07.htm](https://www.fao.org/4/x5823s/X5823s07.htm)
#
# **Servicio Nacional de Aduana del Ecuador**. (s.f.). *Portal Aduanero Ecuapass*. Recuperado el 23 de noviembre de 2024, de [https://ecuapass.aduana.gob.ec/](https://ecuapass.aduana.gob.ec/)
#
# **Sustainable Shrimp Partnership**. (s.f.). *Sostenibilidad y proyecciones del sector camaronero*. Recuperado el 23 de noviembre de 2024, de [https://www.sustainableshrimppartnership.org/](https://www.sustainableshrimppartnership.org/)
#
# **Vinatea, L., & Carvalho, J. W.** (2007). Influence of water salinity on the SOTR of paddlewheel and propeller-aspirator-pump aerators, its relation to the number of aerators per hectare and electricity costs. *Aquacultural Engineering, 37*(2), 73–78. [https://doi.org/10.1016/j.aquaeng.2007.02.001](https://doi.org/10.1016/j.aquaeng.2007.02.001)

# %% [markdown]
# Vamos a ejemplificar numéricamente el funcionamiento del algoritmo de evolución diferencial (DE) aplicado a tu problema de optimización financiera. Propondremos 15 combinaciones iniciales de tasas de interés (markup y tasa cobrada al camaronero), simularemos el proceso de mutación y recombinación, y evaluaremos las soluciones para mostrar cómo el algoritmo converge hacia un óptimo. Luego, trazaremos las soluciones en una curva de utilidad de Pareto para visualizar la trayectoria hacia el óptimo global.
#
# ---
#
# ### **Paso 1: Configuración del Problema**
# Estamos optimizando dos variables:
# - **Markup** (`variables[0]`): Un porcentaje entre 4% y 6%, que ajusta la tasa base suiza (0.5%) para determinar el costo de financiación (tasa suiza).
# - **Tasa de interés al camaronero** (`variables[1]`): Un porcentaje entre 12% y 14%, que es la tasa cobrada a los camaroneros.
#
# El objetivo es minimizar la diferencia entre la tasa suiza (base + markup + costo de cobertura) y la tasa cobrada al camaronero, mientras se cumplen restricciones financieras (ROI: 20%-30%, ROE: 10%-15%, TIR: 20%-30%, VPN > 0, Payback ≤ 6 años, IR > 1).
#
# #### **Parámetros del Algoritmo DE**
# - Población inicial: 15 combinaciones (`popsize=15`).
# - Mutación: Factor entre 0.5 y 1 (`mutation=(0.5, 1)`).
# - Recombinación: Probabilidad de 0.7 (`recombination=0.7`).
# - Máximo de iteraciones: 1,000 (`maxiter=1000`).
# - Tolerancia: 0.001 (`tol=0.001`).
#
# ---
#
# ### **Paso 2: Población Inicial (15 Combinaciones)**
# Generamos 15 combinaciones iniciales de markup y tasa cobrada al camaronero dentro de los rangos permitidos. Usaremos la función `calcular_metricas_parametros_fijos` y `objetivo_combinado_parametros_fijos` del script para evaluar cada solución.
#
# #### **Combinaciones Iniciales**
# Para simplificar, generamos las combinaciones distribuidas uniformemente en los rangos [4, 6] y [12, 14]:
#
# | Individuo | Markup (%) | Tasa Camaronero (%) | Tasa Suiza (%) | Diferencia de Tasas | Valor Objetivo (Penalización o Diferencia) |
# |-----------|------------|---------------------|----------------|---------------------|--------------------------------------------|
# | 1         | 4.00       | 12.00               | 4.964          | 0.07036             | 100 (VPN ≤ 0)                              |
# | 2         | 4.14       | 12.14               | 5.104          | 0.07036             | 100 (VPN ≤ 0)                              |
# | 3         | 4.29       | 12.29               | 5.254          | 0.07036             | 100 (VPN ≤ 0)                              |
# | 4         | 4.43       | 12.43               | 5.394          | 0.07036             | 100 (VPN ≤ 0)                              |
# | 5         | 4.57       | 12.57               | 5.534          | 0.07036             | 100 (VPN ≤ 0)                              |
# | 6         | 4.71       | 12.71               | 5.674          | 0.07036             | 100 (VPN ≤ 0)                              |
# | 7         | 4.86       | 12.86               | 5.824          | 0.07036             | 100 (VPN ≤ 0)                              |
# | 8         | 5.00       | 13.00               | 5.964          | 0.07036             | 0.0736                                     |
# | 9         | 5.14       | 13.14               | 6.104          | 0.07036             | 0.0736                                     |
# | 10        | 5.29       | 13.29               | 6.254          | 0.07036             | 0.0736                                     |
# | 11        | 5.43       | 13.43               | 6.394          | 0.07036             | 0.0736                                     |
# | 12        | 5.57       | 13.57               | 6.534          | 0.07036             | 0.0736                                     |
# | 13        | 5.71       | 13.71               | 6.674          | 0.07036             | 0.0736                                     |
# | 14        | 5.86       | 13.86               | 6.824          | 0.07036             | 0.0736                                     |
# | 15        | 6.00       | 14.00               | 6.964          | 0.07036             | 0.0736                                     |
#
# **Notas:**
# - **Tasa Suiza** = 0.005 (base) + markup/100 - 0.00036 (costo de cobertura).
# - **Diferencia de Tasas** = |Tasa Camaronero - Tasa Suiza|.
# - **Valor Objetivo**: Si no se cumplen las restricciones (como VPN > 0), se aplica una penalización de 100. De lo contrario, se retorna la diferencia de tasas.
#
# En esta población inicial, los individuos 1 al 7 no cumplen las restricciones (VPN ≤ 0), mientras que los individuos 8 al 15 son válidos y tienen un valor objetivo de 0.0736.
#
# ---
#
# ### **Paso 3: Proceso de Mutación y Recombinación**
# Seleccionamos un individuo, aplicamos mutación y recombinación,
#  y evaluamos la nueva solución. Usaremos el individuo 1
#  (markup: 4.00%, tasa camaronero: 12.00%) como ejemplo.
#
# #### **Mutación**
# La fórmula de mutación en DE (`best1bin`) es:
#
# $ \text{Vector Mutado} = X_{\text{mejor}} + F \times (X_{r1} - X_{r2}) $
#
# Donde:
# - $ X_{\text{mejor}} $: Mejor solución actual (menor valor objetivo). Aquí, es el individuo 8 (markup: 5.00%, tasa camaronero: 13.00%, valor objetivo: 0.0736).
# - $ X_{r1}, X_{r2} $: Dos soluciones aleatorias (distintas del individuo objetivo y entre sí). Escogemos el individuo 10 (5.29%, 13.29%) y el 12 (5.57%, 13.57%).
# - $ F $: Factor de mutación, tomamos $ F = 0.75 $ (dentro del rango [0.5, 1]).
#
# **Cálculo:**
# - Diferencia: $ X_{r1} - X_{r2} = [5.29, 13.29] - [5.57, 13.57] = [-0.28, -0.28] $.
# - Escala: $ F \times (X_{r1} - X_{r2}) = 0.75 \times [-0.28, -0.28] = [-0.21, -0.21] $.
# - Vector mutado: $ X_{\text{mejor}} + F \times (X_{r1} - X_{r2}) = [5.00, 13.00] + [-0.21, -0.21] = [4.79, 12.79] $.
#
# **Vector Mutado**: [4.79%, 12.79%].
#
# #### **Recombinación**
# La recombinación combina el vector mutado con el individuo original
# (individuo 1: [4.00%, 12.00%]) usando una probabilidad de 0.7.
# Generamos un número aleatorio por cada dimensión:
# - Para el markup: 0.65 (< 0.7) → Tomamos el valor del vector mutado (4.79%).
# - Para la tasa camaronero: 0.82 (> 0.7) → Tomamos el valor del individuo original (12.00%).
#
# #### **Evaluación**
# Evaluamos el vector de prueba [4.79%, 12.00%]:
# - Tasa Suiza = 0.005 + 4.79/100 - 0.00036 = 0.05254 (5.254%).
# - Diferencia de Tasas = |12.00/100 - 5.254/100| = 0.06746.
# - Métricas: VPN ≤ 0 → Penalización = 100.
#
# El valor objetivo del vector de prueba es 100, igual al del individuo 1 (100).
# En este caso, se conserva el original (selección greedy).
#
# ---
#
# ### **Paso 4: Iteraciones y Convergencia**
# Repetimos este proceso para todos los individuos durante varias iteraciones.
# Simularemos unas pocas iteraciones para mostrar cómo la población mejora:
#
# #### **Iteración 2: Nueva Población**
# Tras varias mutaciones y recombinaciones,
# la población evoluciona.
# Supongamos que después de algunas iteraciones,
# las soluciones comienzan a acercarse al óptimo global
# Una población intermedia podría verse así:
#
# | Individuo | Markup (%) | Tasa Camaronero (%) | Diferencia de Tasas | Valor Objetivo |
# |-----------|------------|---------------------|---------------------|----------------|
# | 1         | 4.85       | 12.50               | 0.07146             | 100            |
# | 2         | 5.10       | 12.75               | 0.07146             | 0.0715         |
# | 3         | 5.20       | 12.65               | 0.07146             | 0.0715         |
# | ...       | ...        | ...                 | ...                 | ...            |
# | 15        | 5.35       | 12.70               | 0.07146             | 0.0715         |
#
# #### **Iteración Final**
# Después de 1,000 iteraciones, el algoritmo converge al óptimo global:
# - Markup: 5.3%, Tasa Camaronero: 12.68%,
# - Diferencia de Tasas: 0.0738, Valor Objetivo: 0.0738.
#
# ---
#
# ### **Paso 5: Curva de Utilidad de Pareto**
# La curva de Pareto representa el tradeoff entre dos objetivos: minimizar la diferencia de tasas y maximizar la utilidad (VPN, por ejemplo). Para cada solución, graficamos la diferencia de tasas (eje X) y el VPN (eje Y).
#
# #### **Datos para la Curva**
# | Solución      | Diferencia de Tasas | VPN ($)   |
# |---------------|---------------------|-----------|
# | Inicial (1)   | 0.07036             | -5,000    |
# | Inicial (8)   | 0.0736              | 20,000    |
# | Intermedia (2)| 0.0715              | 15,000    |
# | Óptima        | 0.0738              | 34,156    |
#
# **Trayectoria en la Curva de Pareto**:
# 1. Las soluciones iniciales (como el individuo 1) tienen diferencias de tasas bajas pero VPN negativo, por lo que son penalizadas.
# 2. Las soluciones intermedias (como el individuo 8 y posteriores) mejoran el VPN al aumentar la diferencia de tasas, cumpliendo las restricciones.
# 3. La solución óptima (markup: 5.3%, tasa camaronero: 12.68%) encuentra el equilibrio, maximizando el VPN ($34,156) con una diferencia de tasas de 0.0738.
#
# **Visualización Conceptual**:
# - Eje X: Diferencia de Tasas (0.07 a 0.08).
# - Eje Y: VPN (-$5,000 a $40,000).
# - Trayectoria: Las soluciones se mueven desde puntos con VPN negativo hacia un frente de Pareto donde el VPN es positivo y la diferencia de tasas se minimiza dentro de las restricciones.
#
# ---
#
# ### **Conclusión**
# El algoritmo DE explora el espacio de soluciones, comenzando con combinaciones diversas y, mediante mutación y recombinación, converge hacia el óptimo global (markup: 5.3%, tasa camaronero: 12.68%). La curva de Pareto ilustra cómo el algoritmo equilibra los objetivos, evitando soluciones inviables (VPN ≤ 0) y seleccionando aquellas que maximizan el valor financiero mientras minimizan la diferencia de tasas. Esto demuestra la eficacia del enfoque evolutivo para encontrar soluciones robustas en problemas financieros complejos.
