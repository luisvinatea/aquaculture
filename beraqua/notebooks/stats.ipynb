# %%
import json
from collections import Counter

# Load the JSON data
with open('/home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/product_data.json', 'r') as json_file:
    data = json.load(json_file)

# Function to remove 'desconocido' from all values in the dictionary
def remove_desconocido(data):
    for field, importers in data.items():
        for importer, values in importers.items():
            # Filter out 'desconocido' from the list of values
            data[field][importer] = [value for value in values if value != 'desconocido']
    return data

# Remove 'desconocido' values
cleaned_data = remove_desconocido(data)

# Function to remove duplicates and keep the counts for each value
def remove_duplicates_and_count(data):
    for field, importers in data.items():
        for importer, values in importers.items():
            # Use Counter to count occurrences of each value
            value_counts = Counter(values)
            # Get only the unique values (no duplicates) by using the keys of the Counter
            data[field][importer] = list(value_counts.keys())  # Keep unique values
    return data

# Remove duplicates and keep only unique values
unique_data = remove_duplicates_and_count(cleaned_data)

# Print sample output to check
for field, importers in unique_data.items():
    print(f"Field: {field}")
    for importer, values in importers.items():
        print(f"Importer: {importer} -> {values}")
    print("\n")
# Out:
# Field: telefono
# Importer: acuarios_del_mar_s.a._acdelmar -> []
# Importer: allamericancorp_s.a. -> []
# Importer: aquagroup_cia._ltda. -> ['02485789-413']
# Importer: arboleda_faini_juan_xavier -> []
# Importer: automotores_de_francia_compañia_anonima_autofranci -> ['02_2482002']
# Importer: automotores_y_anexos_s.a._ayasa -> ['02_2222740_ext_202']
# Importer: camaronera_agromarina -> []
# Importer: camarosursa_sa -> []
# Importer: campoverde_palacios_marco_vinicio -> []
# Importer: comercial_kywi_s.a. -> ['02_2501713__ext_2239_/_501722_/_501716']
# Importer: consorcio_generacion_ecuador -> []
# Importer: corpiecam_cia_ltda -> []
# Importer: crustaceos_&_peces_de_sudamerica_s.a._crupesa -> []
# Importer: crustaceos_&_peces_de_sudamerica_s_a_crupesa -> []
# Importer: dolca_s.a. -> ['593_(4)_2240300']
# Importer: dreu_sa -> ['099427930']
# Importer: ecuacobre_fv.s.a -> ['02_2332233']
# Importer: ecuayamata_s.a -> ['04_2323940']
# Importer: ecuayamata_s.a. -> ['04_2323940']
# Importer: edesa_sa -> ['02_2671717']
# Importer: electro_ecuatoriana_s.a_c.i -> ['04_2285744']
# Importer: empresa_publica_de_hidrocarburos_del_ecuador_ep_petroecuador -> []
# Importer: espinosa_valverde_jorge_fabricio -> []
# Importer: f.v_-_area_andina_s.a. -> ['02_2332233']
# Importer: faraecu_s.a. -> []
# Importer: futurcorp_s.a. -> ['04_2206967_/_206966']
# Importer: hidromax_s.a. -> []
# Importer: importadora_ecuasino_s.a. -> []
# Importer: importadora_y_distribuidora_comercial_inducomicc_s.a. -> []
# Importer: industrial_y_comercial_bohtri_s.a. -> []
# Importer: industrias_reunidas_cia._ltda._indunidas_laboratorios_indunidas -> ['593_(4)_2324444']
# Importer: industrias_unidas_cia._ltda. -> ['593_(4)_2324444']
# Importer: inmocori_s.a. -> []
# Importer: interandi_de_construcciones_ca -> ['288380-280476']
# Importer: junta_de_beneficencia_de_guayaquil -> ['04_2324060_/_512761']
# Importer: keramikos_s.a. -> ['07_836171']
# Importer: la_fabril_s.a. -> ['2920091']
# Importer: maquinarias_y_vehiculos_s.a._mavesa -> ['04_2272600']
# Importer: medina_naranjo_elvis_genaro -> []
# Importer: negocios_industriales_real_n.i.r.s.a._s.a. -> ['04_280024']
# Importer: nutrifeed_s_a -> []
# Importer: oceanmarket_s.a. -> []
# Importer: oslinger_turf_equipment_s.a. -> []
# Importer: piedra_bravo_bedy_elizabeth -> []
# Importer: produmar_s.a. -> []
# Importer: promarisco_s.a. -> ['04_2800052_ext_151']
# Importer: quemco_cia._ltda. -> ['02_2446348_/_258541_/_258334']
# Importer: samlit_c_a -> []
# Importer: solo_del_ecuador_secial_cia._ltda. -> ['2443828']
# Importer: sumliec_s.a._suministros_del_litoral -> ['382019_24631']
# Importer: tecnandina_s_a -> ['459912']
# Importer: tecnandina_sa_tensa -> ['459912']
# Importer: tedex_s.a. -> []
# Importer: track_engine/mafla_guerra_jhon_alexander -> ['n']
# Importer: trecx_cia._ltda. -> []
# Importer: velastegui_lasso_bolivar_alejandro -> ['n']
# Importer: viprencar_s.a. -> []
# Importer: wartsila__del_ecuador_s.a -> ['593_(2)_2524998_/_526303_/_526342_/_526867']
# Importer: wartsila_ecuador_s.a. -> ['593_(2)_2524998_/_526303_/_526342_/_526867']
#
#
# Field: agencia_de_transporte
# Importer: acuarios_del_mar_s.a._acdelmar -> ['veco_logistics_ecuador_s.a.', 'air_&_ocean_cargo_speedair_s.a.', 'siatilogistics_s.a.']
# Importer: allamericancorp_s.a. -> ['multimodal_maritima_modalmar']
# Importer: aquagroup_cia._ltda. -> ['siatilogistics_s.a.']
# Importer: arboleda_faini_juan_xavier -> ['siatilogistics_s.a.']
# Importer: automotores_de_francia_compañia_anonima_autofranci -> ['iberia']
# Importer: automotores_y_anexos_s.a._ayasa -> ['samisa', 'iberia']
# Importer: camaronera_agromarina -> ['transocean_del_ecuador_s.a.']
# Importer: camarosursa_sa -> ['transoceanica_cia._ltda.']
# Importer: campoverde_palacios_marco_vinicio -> ['gypset_s.a.']
# Importer: comercial_kywi_s.a. -> ['transportes_vigia_s.a.']
# Importer: consorcio_generacion_ecuador -> ['copa_-_compañia_panameña_de_aviacion']
# Importer: corpiecam_cia_ltda -> ['maersk_del_ecuador']
# Importer: crustaceos_&_peces_de_sudamerica_s.a._crupesa -> ['maersk_del_ecuador', 'transoceanica_cia._ltda.']
# Importer: crustaceos_&_peces_de_sudamerica_s_a_crupesa -> ['maersk_del_ecuador', 'tolemar', 'terminaves_s.a.', 'marglobal_s.a._(agencia_maritima_global)']
# Importer: dolca_s.a. -> ['universalcargo_s.a.', 'pacifilink', 'greenandes_ecuador_s.a.']
# Importer: dreu_sa -> ['transoceanica_cia._ltda.']
# Importer: ecuacobre_fv.s.a -> ['surtax', 'saco_shipping_line_s.a.', 'panalpina']
# Importer: ecuayamata_s.a -> ['marglobal_s.a._(agencia_maritima_global)']
# Importer: ecuayamata_s.a. -> ['transoceanica_cia._ltda.', 'maersk_del_ecuador']
# Importer: edesa_sa -> ['aero_express_del_ecuador_transam_c._ltda.']
# Importer: electro_ecuatoriana_s.a_c.i -> ['klm']
# Importer: empresa_publica_de_hidrocarburos_del_ecuador_ep_petroecuador -> ['navisur_naviera_del_sur_s._a.']
# Importer: espinosa_valverde_jorge_fabricio -> ['greenandes_ecuador_s.a.']
# Importer: f.v_-_area_andina_s.a. -> ['panalpina', 'tampa', 'maersk_del_ecuador', 'bluepac_shipping_agency_s.a.', 'saco_shipping_line_s.a.', 'inca_lines_del_ecuador_incalines_s.a.']
# Importer: faraecu_s.a. -> ['copa_-_compañia_panameña_de_aviacion']
# Importer: futurcorp_s.a. -> ['krystal_logitcs_ecuador_s.a.']
# Importer: hidromax_s.a. -> ['veco_logistics_ecuador_s.a.']
# Importer: importadora_ecuasino_s.a. -> ['ctk_logitic_s.a', 'tolemar']
# Importer: importadora_y_distribuidora_comercial_inducomicc_s.a. -> ['logistic_network_servicios_de_carga_s.a.']
# Importer: industrial_y_comercial_bohtri_s.a. -> ['iberia']
# Importer: industrias_reunidas_cia._ltda._indunidas_laboratorios_indunidas -> ['transporte_y_comercio_internacional_transcomerint']
# Importer: industrias_unidas_cia._ltda. -> ['transporte_y_comercio_internacional__transcomerint']
# Importer: inmocori_s.a. -> ['transoceanica_cia._ltda.', 'marglobal_s.a._(agencia_maritima_global)']
# Importer: interandi_de_construcciones_ca -> ['universalcargo_s.a.']
# Importer: junta_de_beneficencia_de_guayaquil -> ['lan_chile']
# Importer: keramikos_s.a. -> ['maersk_del_ecuador']
# Importer: la_fabril_s.a. -> ['agencia_maritima_europacifico']
# Importer: maquinarias_y_vehiculos_s.a._mavesa -> ['iberia', 'lan_chile']
# Importer: medina_naranjo_elvis_genaro -> ['cma_cgm_ecuador_s.a.']
# Importer: negocios_industriales_real_n.i.r.s.a._s.a. -> ['andinamar']
# Importer: nutrifeed_s_a -> ['maersk_del_ecuador']
# Importer: oceanmarket_s.a. -> ['maersk_del_ecuador']
# Importer: oslinger_turf_equipment_s.a. -> ['kuehne_&_nagel', 'pacific_anchor_line_s.a.', 'universalcargo_s.a.']
# Importer: piedra_bravo_bedy_elizabeth -> ['maersk_del_ecuador']
# Importer: produmar_s.a. -> ['transocean_del_ecuador_s.a.', 'navesmar', 'inca_lines_del_ecuador_incalines_s.a.']
# Importer: promarisco_s.a. -> ['maersk_del_ecuador', 'crowley_american_transport__inc__ecuador_s.a.', 'greenandes_ecuador_s.a.', 'terminaves_s.a.', 'marglobal_s.a._(agencia_maritima_global)']
# Importer: quemco_cia._ltda. -> ['otros']
# Importer: samlit_c_a -> ['maersk_del_ecuador']
# Importer: solo_del_ecuador_secial_cia._ltda. -> ['schryver_del_ecuador']
# Importer: sumliec_s.a._suministros_del_litoral -> ['american_airlines']
# Importer: tecnandina_s_a -> ['contraine_cia._ltda.', 'traintercol_ltda._trans._int._carga_colombiana_ltd']
# Importer: tecnandina_sa_tensa -> ['traintercol_ltda._trans._int._carga_colombiana_ltd']
# Importer: tedex_s.a. -> ['pacifilink']
# Importer: track_engine/mafla_guerra_jhon_alexander -> ['otros']
# Importer: trecx_cia._ltda. -> ['transoceanica_cia._ltda.']
# Importer: velastegui_lasso_bolivar_alejandro -> ['crowley_american_transport,_inc,_ecuador_s.a.']
# Importer: viprencar_s.a. -> ['navisur_naviera_del_sur_s._a.']
# Importer: wartsila__del_ecuador_s.a -> ['klm', 'schryver_del_ecuador']
# Importer: wartsila_ecuador_s.a. -> ['schryver_del_ecuador']
#
#
# Field: email
# Importer: acuarios_del_mar_s.a._acdelmar -> []
# Importer: allamericancorp_s.a. -> []
# Importer: aquagroup_cia._ltda. -> []
# Importer: arboleda_faini_juan_xavier -> []
# Importer: automotores_de_francia_compañia_anonima_autofranci -> ['autofrancia.imp2@access.net']
# Importer: automotores_y_anexos_s.a._ayasa -> ['marialenaderomero@ayasa.com.ec']
# Importer: camaronera_agromarina -> []
# Importer: camarosursa_sa -> []
# Importer: campoverde_palacios_marco_vinicio -> []
# Importer: comercial_kywi_s.a. -> ['rtapia@kywi.com.ec']
# Importer: consorcio_generacion_ecuador -> []
# Importer: corpiecam_cia_ltda -> []
# Importer: crustaceos_&_peces_de_sudamerica_s.a._crupesa -> []
# Importer: crustaceos_&_peces_de_sudamerica_s_a_crupesa -> []
# Importer: dolca_s.a. -> ['presidencia@codemet.com']
# Importer: dreu_sa -> []
# Importer: ecuacobre_fv.s.a -> ['lourdesll@cranzviegener.com']
# Importer: ecuayamata_s.a -> []
# Importer: ecuayamata_s.a. -> []
# Importer: edesa_sa -> ['ialtamirano@edesa.com.ec']
# Importer: electro_ecuatoriana_s.a_c.i -> ['jsanchez@gye.eesaci.com']
# Importer: empresa_publica_de_hidrocarburos_del_ecuador_ep_petroecuador -> []
# Importer: espinosa_valverde_jorge_fabricio -> []
# Importer: f.v_-_area_andina_s.a. -> ['lourdesll@cranzviegener.com']
# Importer: faraecu_s.a. -> []
# Importer: futurcorp_s.a. -> ['marcelad@futurcorp.com']
# Importer: hidromax_s.a. -> []
# Importer: importadora_ecuasino_s.a. -> []
# Importer: importadora_y_distribuidora_comercial_inducomicc_s.a. -> []
# Importer: industrial_y_comercial_bohtri_s.a. -> []
# Importer: industrias_reunidas_cia._ltda._indunidas_laboratorios_indunidas -> ['ideal@interactive.net.ec']
# Importer: industrias_unidas_cia._ltda. -> ['ideal@interactive.net.ec']
# Importer: inmocori_s.a. -> []
# Importer: interandi_de_construcciones_ca -> []
# Importer: junta_de_beneficencia_de_guayaquil -> ['jbgye4@jbye.org.ec']
# Importer: keramikos_s.a. -> ['enrique.talbot@cermosa.com.ec']
# Importer: la_fabril_s.a. -> ['mchacon@lafabril.com.ec']
# Importer: maquinarias_y_vehiculos_s.a._mavesa -> ['gtecontabilidad@mavesaec.com.ec']
# Importer: medina_naranjo_elvis_genaro -> []
# Importer: negocios_industriales_real_n.i.r.s.a._s.a. -> ['nirsa@nirsa.com']
# Importer: nutrifeed_s_a -> []
# Importer: oceanmarket_s.a. -> []
# Importer: oslinger_turf_equipment_s.a. -> []
# Importer: piedra_bravo_bedy_elizabeth -> []
# Importer: produmar_s.a. -> []
# Importer: promarisco_s.a. -> ['ibenalcazar@promarisco.com']
# Importer: quemco_cia._ltda. -> ['quemco@quemco.com']
# Importer: samlit_c_a -> []
# Importer: solo_del_ecuador_secial_cia._ltda. -> []
# Importer: sumliec_s.a._suministros_del_litoral -> []
# Importer: tecnandina_s_a -> []
# Importer: tecnandina_sa_tensa -> []
# Importer: tedex_s.a. -> []
# Importer: track_engine/mafla_guerra_jhon_alexander -> []
# Importer: trecx_cia._ltda. -> []
# Importer: velastegui_lasso_bolivar_alejandro -> []
# Importer: viprencar_s.a. -> []
# Importer: wartsila__del_ecuador_s.a -> ['saskya.andrade@wartsila.com']
# Importer: wartsila_ecuador_s.a. -> ['saskya.andrade@wartsila.com']
#
#
# Field: direccion
# Importer: acuarios_del_mar_s.a._acdelmar -> ['urdesa_central_calle_1ra_#_821_e_higueras', 'primera_821_y_guayacanes_y_ficus']
# Importer: allamericancorp_s.a. -> ['av._pampite_s/n_y_chimborazo']
# Importer: aquagroup_cia._ltda. -> ['luis_cordero_e12-182_y_valladolidc']
# Importer: arboleda_faini_juan_xavier -> ['bermejo_s/n_y_shushufindi']
# Importer: automotores_de_francia_compañia_anonima_autofranci -> ['av_10_de_agosto__n63-269_y_17_01_4044']
# Importer: automotores_y_anexos_s.a._ayasa -> ['sd']
# Importer: camaronera_agromarina -> ['guasmo_y_la_ria']
# Importer: camarosursa_sa -> ['avenida_del_ejercito_s/n_y_24_de_mayo']
# Importer: campoverde_palacios_marco_vinicio -> ['estero_chupadores_s/n_santa_rosa']
# Importer: comercial_kywi_s.a. -> ['cordero_1641_y_10_de_agosto', 'av.10_de_agosto_n24-59_y_luis_cordero']
# Importer: consorcio_generacion_ecuador -> ['av_12_de_octubre_10-35_y_carrion']
# Importer: corpiecam_cia_ltda -> []
# Importer: crustaceos_&_peces_de_sudamerica_s.a._crupesa -> ['guayasn212_y_9_de_octubre']
# Importer: crustaceos_&_peces_de_sudamerica_s_a_crupesa -> ['av._25_de_junio_106_y_esmeraldas']
# Importer: dolca_s.a. -> ['av._juan_tanca_marengo_km._3.5', 'av._cdla._kennedy_calle_nahin_isaias_2002_y_calle', 'av._juan_tanca_marengo_km._3']
# Importer: dreu_sa -> ['km11.5_via__daule']
# Importer: ecuacobre_fv.s.a -> ['av._diego_de_almagro_722_y_baquerizo_moreno']
# Importer: ecuayamata_s.a -> ['aguirre_606_y_boyacá']
# Importer: ecuayamata_s.a. -> ['colon_#_322_y_chile']
# Importer: edesa_sa -> ['av_moran_valverde_y_teniente_hugo_ortiz']
# Importer: electro_ecuatoriana_s.a_c.i -> ['av._juan_tanca_marengo_km._0.5_diagonal_a_la_gasolinera__de_las_américas']
# Importer: empresa_publica_de_hidrocarburos_del_ecuador_ep_petroecuador -> []
# Importer: espinosa_valverde_jorge_fabricio -> ['cdla_alborada_sexta_etapa_solar_11_mz_535']
# Importer: f.v_-_area_andina_s.a. -> ['via_amaguaña_km_25_principal_s/n']
# Importer: faraecu_s.a. -> ['km._2.5_via_mar_bravo-salinas']
# Importer: futurcorp_s.a. -> ['km_1_via_san_juan_-puebloviejo']
# Importer: hidromax_s.a. -> ['av._de_las_americas_y_av.plaza_dañin']
# Importer: importadora_ecuasino_s.a. -> ['aguirre_616_y_boyaca']
# Importer: importadora_y_distribuidora_comercial_inducomicc_s.a. -> ['km_8_1/2_via_daule']
# Importer: industrial_y_comercial_bohtri_s.a. -> ['albatro_calle_flamingo_211y_miguel_h._alcivar']
# Importer: industrias_reunidas_cia._ltda._indunidas_laboratorios_indunidas -> ['via_a_daule_km.diez_s/n']
# Importer: industrias_unidas_cia._ltda. -> ['km._10_vía_daule']
# Importer: inmocori_s.a. -> ['via_a_daule_km_7.5']
# Importer: interandi_de_construcciones_ca -> ['quisquis_502_y_tulcan_p.2_ofic._201']
# Importer: junta_de_beneficencia_de_guayaquil -> ['vélez_109_y_pedro_carbo']
# Importer: keramikos_s.a. -> ['av._heroes_de_verdeloma_922_y_fco._tamariz_-']
# Importer: la_fabril_s.a. -> []
# Importer: maquinarias_y_vehiculos_s.a._mavesa -> ['av._juan_tanca_marengo_km._3.5', 'km_tres_y_medio_av._juan_tanca_marengo_s/n']
# Importer: medina_naranjo_elvis_genaro -> ['ciudadela_el_rosal,_arturo_cisneros_y_julio_vinueza_2-24']
# Importer: negocios_industriales_real_n.i.r.s.a._s.a. -> ['av._carlos_luis_plaza_dañin_s/n_y_av._democracia']
# Importer: nutrifeed_s_a -> []
# Importer: oceanmarket_s.a. -> []
# Importer: oslinger_turf_equipment_s.a. -> ['urdenor_dos_calle_16-a_villa7', '16-a_villa_7_y_primer_pasaje_23']
# Importer: piedra_bravo_bedy_elizabeth -> []
# Importer: produmar_s.a. -> ['km_8_via_duran-tambo', 'via_guayaquil-daule_km._5.5_s/n.']
# Importer: promarisco_s.a. -> ['km._6.5_vía_durán_tambo', 'km_6,5_via_duran_tambo', 'km__6,5__via__duran__tambo']
# Importer: quemco_cia._ltda. -> ['indanza_140_y_av._de_la_prensa']
# Importer: samlit_c_a -> []
# Importer: solo_del_ecuador_secial_cia._ltda. -> ['km_6._1/2_panamericana_norte_c_110']
# Importer: sumliec_s.a._suministros_del_litoral -> ['urdenor_1_mz_136_v.3']
# Importer: tecnandina_s_a -> ['av_manuel_cordova_galarza_km_7']
# Importer: tecnandina_sa_tensa -> ['av._manuel_cordova_galarza_km._6_1/2']
# Importer: tedex_s.a. -> ['av._nahim_isaias_202_y_calle_2da.']
# Importer: track_engine/mafla_guerra_jhon_alexander -> ['av_de_la_prensa_3139_y_gonzalo_gallo']
# Importer: trecx_cia._ltda. -> ['pichincha_/_quito_/_rumiurco_oe4-365_y_pedro_freile']
# Importer: velastegui_lasso_bolivar_alejandro -> ['av._gaspar_de_villarroel_952_y_av._de_los_shyris']
# Importer: viprencar_s.a. -> ['6_de_marzo_no._1009_y_10_de_agosto']
# Importer: wartsila__del_ecuador_s.a -> ['av._12_de_octubre_n24-593_y_cordero']
# Importer: wartsila_ecuador_s.a. -> ['los_floripondios_n57-120_y_leonardo_murialdo']
#
#
# Field: descripcion_arancelaria
# Importer: a.w.t._sa -> [nan]
# Importer: acosta_gonzalez_elver_armando -> ['los_demas']
# Importer: acuarios_del_mar_s.a._acdelmar -> ['bombas_de_vacio', 'bombas_de_vac\xado', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', 'los_demás']
# Importer: acuarios_del_mar_s_a_acdelmar -> ['bombas_de_vacio']
# Importer: acuicultura_ber_aqua_aquiber_s_a -> ['los_demas', 'de_potencia_inferior_a_30_kw_(40_hp)', 'partes', 'de_compresores', 'los_demás', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', nan]
# Importer: advancecorp_s.a. -> ['parachoques_(paragolpes,_defensas)_y_sus_partes']
# Importer: agenkacom_s.a. -> [nan]
# Importer: agrota_cia._ltda. -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: agrovalencia_c.a. -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: aguayo_macas_darwin_jefferson -> []
# Importer: airec_s.a.s. -> [nan]
# Importer: alderete_rendon_eber_jair -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: alessa_s.a. -> ['los_demas', 'los_demás', nan]
# Importer: alfaguyca_s.a. -> ['las_demás', 'engranajes_y_ruedas_de_fricción,_excepto_las_ruedas_dentadas_y_demás_órganos_elementales_de_transmisión_presentados_aisladamente', 'los_demás', 'camisas_de_cilindros', 'de_potencia_inferior_o_igual_a_130_kw_(174_hp)', '"excepto_remanufacturadas_para_motores_84071000;_84072900;_84081000;_84089010;_y_84089020."', 'partes', 'cajas_de_cojinetes_con_rodamientos_incorporados', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: almacenes_boyaca_s.a. -> ['los_demás', nan]
# Importer: almacenes_juan_eljuri_cia._ltda. -> ['los_demás']
# Importer: altidat_s_a -> []
# Importer: alvarado_ceferino_melody_paulette -> []
# Importer: andes_petroleum_ecuador_ltd. -> ['las_demás']
# Importer: apracom_s.a. -> ['los_demás', 'de_corriente_alterna,_polifasicos', nan]
# Importer: aquagroup_cia._ltda. -> ['los_demás']
# Importer: aquanatura_s.a. -> [nan]
# Importer: aquavance_cia_ltda -> ['las_demas']
# Importer: aquavi_sa -> ['los_demás', 'partes', 'las_demás', 'los_demas_(solo_para_aquellas_mercancías_diferentes_a__pernos_de_cabeza_de_botón_oval_y_sus_tuercas__no_inen)', 'engranajes_y_ruedas_de_fricción,_excepto_las_ruedas_dentadas_y_demás_órganos_elementales_de_transmisión_presentados_aisladamente', 'de_potencia_inferior_a_30_kw_(40_hp)', 'ruedas_dentadas_y_demás_órganos_elementales_de_transmisión_presentados_aisladamente', 'los_demas', 'los_demÿs', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', 'reductores,_multiplicadores_y_variadores_de_velocidad', nan]
# Importer: arellano_valdiviezo_carlos_david -> [nan]
# Importer: arevalo_moscoso_pablo_wilson -> [nan]
# Importer: arias_quinatoa_gustavo_ranulfo -> [nan]
# Importer: arkrem_s.a. -> ['los_demás', nan]
# Importer: arteriego_s.a. -> ['los_demás']
# Importer: aurelian_ecuador_s.a. -> [nan]
# Importer: autolider_ecuador_s.a. -> ['silenciadores_y_tubos_(caños)_de_escape_sus_partes']
# Importer: autolider_ecuador_s.a.s. -> ['partes', nan]
# Importer: automotores_y_anexos_s.a._ayasa -> ['los_demµs', 'los_demas', '"silenciadores_y_tubos_(caños)_de_escape;_sus_partes"', 'silenciadores_y_tubos_(caños)_de_escape;_sus_partes', 'rejillas_delanteras_(persianas,_parrillas)', nan]
# Importer: automotores_y_anexos_s.a_ayasa -> ['los_demµs', 'los_demas', 'los_demás']
# Importer: automotriz_abtolada_rodrigo_espinosa_cia._ltda. -> ['los_demás']
# Importer: banariego_cia._ltda. -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: barrezueta_palacios_angel_damian -> ['los_demás']
# Importer: basantes_torres_henrry_napoleon -> []
# Importer: bautista_diaz_marieta_esther -> ['canillas_o_grifos_para_uso_doméstico', 'cubos_(vasos)_de_ajuste_intercambiables,_incluso_con_mango']
# Importer: beaglelogistics_cia_ltda -> [nan]
# Importer: benavides_revelo_silvia_patricia -> ['los_demàs', 'los_dem·s', 'los_demás']
# Importer: bermeo_hermanos_cia_ltda -> ['los_demás']
# Importer: bermudez_veliz_otto_jaime -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: biofeeder_s.a.s. -> [nan]
# Importer: biumar_s.a. -> [nan]
# Importer: blacio_espinoza_jose_baltazar -> [nan]
# Importer: blaunsa_s.a. -> ['los_demas']
# Importer: borja_claudia -> [nan]
# Importer: briceño_maldonado_richard_manuel -> ['los_demás']
# Importer: buele_becerra_jonathan_andres -> ['los_demás']
# Importer: cadena_palacios_paola_janeth -> ['los_demás']
# Importer: calderon_barrientos_juan_diego -> [nan]
# Importer: calle_astudillo_jorge_miguel -> [nan]
# Importer: camacho_jonathan -> [nan]
# Importer: camaronera_camanmor_s_a -> [nan]
# Importer: camaronera_lebama_s.a. -> [nan]
# Importer: camaronera_supracamaron_ecuador_ecuasupra_s.a. -> ['de_potencia_inferior_a_30_kw_(40_hp)']
# Importer: camaronera_vancosta_s.a. -> ['los_demás']
# Importer: camarones_y_langostinos_del_mar_calademar_s.a. -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', nan]
# Importer: canodros_c.l. -> [nan]
# Importer: carranza_ponce_jose_carlos -> ['los_demás']
# Importer: castilla_fassio_maria_isabel_del_carmen -> [nan]
# Importer: cecuamaq,_corporacion_ecuatoriana_industrial_de_maquinaria_c.a. -> [nan]
# Importer: celleri_bonilla_isabella -> [nan]
# Importer: ceron_carrera_francisco_xavier -> ['de_potencia_inferior_o_igual_a_130_kw_(174_hp)']
# Importer: cevallos_alava_marlon_ricardo -> []
# Importer: cevallos_suarez_camilo_jose -> [nan]
# Importer: chavez_rios_benjamin_belisario -> [nan]
# Importer: cidicsa_s.a. -> [nan]
# Importer: cinthia_garcia -> [nan]
# Importer: cipeq_cia._ltda. -> ['los_demás']
# Importer: clydent_s.a. -> [nan]
# Importer: codemet_s.a. -> ['máquinas_para_tratamiento_de_aguas_residuales', 'de_compresores']
# Importer: coldchain_cia._ltda. -> ['partes_y_accesorios']
# Importer: colineal_corporation_cia._ltda. -> [nan]
# Importer: comercial_el_sur_comercialelsur_s_a -> ['partes']
# Importer: comercial_kywi_s.a. -> ['los_demás', nan]
# Importer: comercial_pesquera_cristiansen_s.a. -> [nan]
# Importer: comercializadora_gnimport_s.a. -> ['partes', 'canillas_o_grifos_para_uso_doméstico']
# Importer: comercializadora_visual_technology_vistechsa_s.a. -> ['los_demás']
# Importer: compania_beagle_trade_kapav_s.a. -> ['aparatos_y_dispositivos_para_licuefaccion_de_aire_u_otros_gases']
# Importer: compania_tecnohidro_s.c.c. -> ['m\xa0quinas_para_tratamiento_de_aguas_residuales']
# Importer: compañia_anonima_practicasa -> ['canillas_o_grifos_para_uso_doméstico', 'las_demás']
# Importer: compañia_camaronera_ferasa_s.a. -> ['los_demas']
# Importer: compañia_de_equipamiento_electrico_industrial_eein_s.a. -> ['de_silicona']
# Importer: compañia_importadora_&_comercial_la_constanza_impcomtanza_s.a. -> ['los_demás']
# Importer: conauto_c.a. -> ['partes', 'los_demás', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', nan]
# Importer: constructora_daobang_s.a._condao -> [nan]
# Importer: consultcommerce_s.a. -> [nan]
# Importer: controlenergy_s.a. -> ['las_demas_maquinas_y_aparatos']
# Importer: coral_ramos_henry_javier -> ['los_demás']
# Importer: corporacion_favorita_c.a. -> ['unicamente_para_materiales_y_artículos_plásticos_destinados_a_estar_en_contacto_con_alimentos']
# Importer: corporacion_lanec_s.a. -> ['los_demas', 'de_potencia_inferior_o_igual_a_130_kw_(174_hp)']
# Importer: corporacion_nexum_nexumcorp_s.a. -> ['rejillas_delanteras_(persianas,_parrillas)', nan]
# Importer: correa_rojas_gabriela_alejandra -> ['los_demás']
# Importer: cosumisa_s.a. -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', nan]
# Importer: crustaceos_&_peces_de_sud_america_s_a_crupesa -> ['los_demas', 'las_demµs:', 'partes', 'los_demÿs', 'los_demás', 'las_demás', 'reductores,_multiplicadores_y_variadores_de_velocidad', 'cajas_de_cojinetes_con_rodamientos_incorporados', nan]
# Importer: cruz_garces_pablo_vinicio -> [nan]
# Importer: cunas_leon_dario_xavier -> ['radiadores_y_sus_partes']
# Importer: dahik_ayoub_mario_alejandro -> ['bombas_de_vacío']
# Importer: darsacom_s.a. -> ['los_demas']
# Importer: delanan_desarrollo_langostinero_s_a -> [nan]
# Importer: delicamaronera_s.a -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: desconocido -> ['los_demás', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: dieselmotores_s.a. -> ['los_demás', nan]
# Importer: dimpofer_cia._ltda. -> ['los_demás', nan]
# Importer: disibis_s.a. -> [nan]
# Importer: distribuidora_acuicola_megasupplydelecuador_sociedad_anonima. -> ['los_demÿs', 'los_demás']
# Importer: disupplier_s.a. -> [nan]
# Importer: diteca_s.a. -> ['las_demas']
# Importer: dolca_s.a. -> ['sin_accesorios', 'de_compresores', 'arandelas_(incluidas_las_arandelas_de_muelle_[resorte])', 'de_potencia_inferior_a_30_kw_(40_hp)', nan]
# Importer: drake_raymond_cecil -> [nan]
# Importer: ecoltec_s.a. -> ['muestras_sin_valor_comercial']
# Importer: ecuatoriana_de_motores_motorec_cia._ltda. -> [nan]
# Importer: ecubel_latinoamerica -> ['los_demás']
# Importer: ecugrow_representaciones_s.a.s -> ['cuya_subpartida_especifica_tenga_un_ad-valorem_menor_o_igual_a_20%']
# Importer: ecumix_s.a. -> ['humectadores_y_deshumectadores_(excepto_los_aparatos_de_las_partidas_84.15_u_84.24)']
# Importer: edesa_s._a. -> [nan]
# Importer: edesa_s.a -> ['arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_comp']
# Importer: edesa_s.a. -> ['arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_comp']
# Importer: edesa_sa -> ['arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cer\xa0mico', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_comp', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cer\xa0mico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_art¡culos_de_grifer¡a_picos_de_grifer¡a_rosetas_(set_compuesto', '"arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_com', '#¡valor!', '"arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería_picos_de_grifería_rosetas_(set_compues', '"arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas,_volantes_y_botones_para_apertura_y_cierre', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería_picos_de_grifería_rosetas_(set_compuest', 'arancel_0%_para_pistones_(del_cuerpo_de_la_válvula),_asientos_(obturador),_y_cartuchos_(bloque,_formado_por_un_pistón_del_cuerpo_de_válvula,_resorte_y_tapa)_para_las_válvulas_en_general_y_todas_las_partes_clasificables_en_esta_subpartida_de_válvulas_de_am', 'muestras_sin_valor_comercial', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería_picos_de_grifería_rosetas_(set_compuesto', nan]
# Importer: eductrade_s.a. -> [nan]
# Importer: el_morro_s.a._morrocal -> ['los_demás']
# Importer: electro_diesel_ecuatoriana_dieselectro_s.a. -> [nan]
# Importer: electrofaype_s.a. -> ['los_demás']
# Importer: elicrom_cia._ltda. -> [nan]
# Importer: emcamex_s_a -> ['los_demás', nan]
# Importer: empacadora_del_pacifico_sociedad_anonima_(edpacif_s.a.) -> ['los_demas', 'los_demás']
# Importer: empacadora_grupo_granmar_s.a._empagran -> []
# Importer: empresa_aquashrimps_s_a -> ['los_demás', nan]
# Importer: empresa_publica_correos_del_ecuador_cde_e.p. -> ['paquetes_postales_en_trafico_postal_internacional']
# Importer: empresa_publica_municipal_de_telecomunicaciones,_agua_potable,_alcantarillado_y_saneamiento_de_cuenca_-_etapa_ep -> ['los_demás']
# Importer: empresa_p‚blica_correos_del_ecuador_e.p. -> ['paquetes_postales_en_trafico_postal_internacional']
# Importer: energy_&_palma_energypalma_s.a. -> [nan]
# Importer: escobar_brayan -> [nan]
# Importer: escobar_robles_juan_hipolito -> [nan]
# Importer: eslive_s.a. -> ['partes', 'maquinas_cosechadoras_automáticas_para_el_sector_acuicola', 'los_demás', nan]
# Importer: espindola_estrada_roberto_arturo -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)']
# Importer: espinosa_aguirre_jose_fernando -> ['bombas_de_vacío']
# Importer: espinosa_valverde_jorge_fabricio -> [nan]
# Importer: espinoza_guillermo -> [nan]
# Importer: estefan_cid_rodrigo_elias -> ['los_demas']
# Importer: euro_dealer_s.c.c.i. -> [nan]
# Importer: eurogress_s.a. -> ['"arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_com']
# Importer: expresito_carga_s.a._exca -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)._0%_y_$0,00_solamente_para_paquetes_en_los_que_el_consignante_sea_un_ecuatoriano_residente_en_el_exterior,_hasta_un_máximo_de_12_paquetes_por_año_o_usd_2,400.00,_lo_que_suceda_primero.']
# Importer: f.v._-_area_andina_s.a. -> ['arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_comp', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cer\xa0mico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas._volantes_y_botones_para_apertura_y_cierre_de_caudal_en_art¡culos_de_grifer¡a_picos_de_grifer¡a_rosetas_(set_compuest', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cer\xa0mico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_art¡culos_de_grifer¡a;_picos_de_grifer¡a;_rosetas_(set_comp', nan]
# Importer: f.v._area_andina_s.a -> ['arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cer˜mico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artðculos_de_griferða_picos_de_griferða_rosetas_(set_compuesto']
# Importer: f.v._area_andina_s.a. -> [nan]
# Importer: f.v_-_area_andina_s.a. -> ['arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_comp', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas._volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_comp', 'muestras_sin_valor_comercial', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cer\xa0mico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_art¡culos_de_grifer¡a_picos_de_grifer¡a_rosetas_(set_compuesto', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cer\xa0mico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_art¡culos_de_grifer¡a;_picos_de_grifer¡a;_rosetas_(set_comp', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerÿmico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_art\xadculos_de_grifer\xada_picos_de_grifer\xada_rosetas_(set_compuesto', '"arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_com', '#¡valor!', 'arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería_picos_de_grifería_rosetas_(set_compuest', '"arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería_picos_de_grifería_rosetas_(set_compues', 'juntas_o_empaquetaduras', '"arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas,_volantes_y_botones_para_apertura_y_cierre', 'las_demás', 'no_ajustables', nan]
# Importer: ferremundo_s.a. -> ['arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico;_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente);_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería;_picos_de_grifería;_rosetas_(set_comp', nan]
# Importer: ferromaqyimport_s.a. -> ['los_demás']
# Importer: fizamaq_cia._ltda. -> ['los_demás', nan]
# Importer: flyexpress_s.a. -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)', nan]
# Importer: franco_maria -> [nan]
# Importer: freire_hernandez_nixon_fabian -> [nan]
# Importer: fuentes_espinoza_pablo_gustavo -> [nan]
# Importer: galarraga_vinueza_jorge_eduardo -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)']
# Importer: galvez_fernando -> [nan]
# Importer: geomil_george_mileni_s.a. -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)._0%_y_$0,00_solamente_para_paquetes_en_los_que_el_consignante_sea_un_ecuatoriano_residente_en_el_exterior,_hasta_un_máximo_de_12_paquetes_por_año_o_usd_2,400.00,_lo_que_suceda_primero.', nan]
# Importer: global_interprice_courier_intercourier_s.a. -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)._0%_y_$0,00_solamente_para_paquetes_en_los_que_el_consignante_sea_un_ecuatoriano_residente_en_el_exterior,_hasta_un_máximo_de_12_paquetes_por_año_o_usd_2,400.00,_lo_que_suceda_primero.', 'paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)', nan]
# Importer: godproex_productora_y_exportadora_s.a. -> ['muestras_sin_valor_comercial', nan]
# Importer: goldenshrimp_s_a -> [nan]
# Importer: gonzaga_bustamante_ramiro_alexander -> [nan]
# Importer: granjas_marinas_doble_a_gramada_s.a. -> ['de_potencia_inferior_o_igual_a_130_kw_(174_hp)']
# Importer: grifec_griferias_del_ecuador_s.a. -> ['arancel_0%_para_cabezas_y/o_cartucho_de_cierre_cerámico_otros_elementos_de_cierre_(valvulitas_o_cabezas_con_tornillos_ascendente)_manijas,_volantes_y_botones_para_apertura_y_cierre_de_caudal_en_artículos_de_grifería_picos_de_grifería_rosetas_(set_compuest']
# Importer: grupo_degfer_cia._ltda. -> ['de_potencia_inferior_a_30_kw_(40_hp)']
# Importer: grupocamaron_s.a.s. -> [nan]
# Importer: guevara_vargas_cristina_alexandra -> [nan]
# Importer: guzman_bustamante_juan_carlos -> [nan]
# Importer: haro_ochoa_jenny_del_carmen -> ['de_ordeñadoras']
# Importer: he_jinsheng -> ['los_demás']
# Importer: hestia-g_s.a. -> [nan]
# Importer: hidalgo_salguero_david_ivan -> [nan]
# Importer: hidmol_s.a. -> [nan]
# Importer: hidroinstalaciones_y_servicios_afines_hidrosa_s.a. -> ['los_dem·s']
# Importer: hormigonera_equinoccial,_equihormigonera_cia._ltda. -> ['los_demás']
# Importer: hormigones_del_valle_s.a._hormivalle -> ['partes']
# Importer: horticoop_andina_s.a. -> ['los_demás']
# Importer: hydroazul -> ['con_diámetro_de_salida_inferior_o_igual_a_100_mm']
# Importer: imnac_importadora_nacional_cia._ltda. -> ['los_demás', 'unicamente_para_materiales_y_artículos_plásticos_destinados_a_estar_en_contacto_con_alimentos']
# Importer: imporparis_s.a. -> [nan]
# Importer: import_green_power_technology,_equipment_&_machinery_item_s.a -> [nan]
# Importer: importacion_y_comercializacion_de_envases,_empaques_y_quimicos_soñarimport_s.a. -> ['los_demás']
# Importer: importadora_aguilar,_garzon_imagga_s.a. -> ['los_demás']
# Importer: importadora_ecuasino_s.a. -> ['partes', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', nan]
# Importer: importadora_formosa_s.a._informo -> [nan]
# Importer: importadora_golden_bird_s.a._imporbird -> [nan]
# Importer: importadora_lino_gamboa_cia._ltda._ilga -> ['los_demas', 'los_demás', 'las_demás', 'no_requiere_inen_productos_distintos_de_perfiles_corrugados_y_postes_de_acero_guardavias', 'engranajes_y_ruedas_de_fricción,_excepto_las_ruedas_dentadas_y_demás_órganos_elementales_de_transmisión_presentados_aisladamente', 'las_demas', 'forjados_de_acero_inoxidable_para_presión_igual_o_superior_a_150_psi', 'excepto_para_repuestos_para_m¿quinas_de_alambre,_no_requiere_inen_prod._distintos_de_concal_014', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', 'partes', nan]
# Importer: importadora_murgueytio_yepez_cia._ltda. -> [nan]
# Importer: importadora_proqualia_improqualia_s.a. -> [nan]
# Importer: importadora_qaba_s.a. -> ['los_demás', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: importadora_qaba_s_a -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', 'los_demás', nan]
# Importer: importadora_quitio_s.a.s. -> [nan]
# Importer: importadora_vega_s.a. -> ['las_demás']
# Importer: imsuin_cia._ltda._importadora_de_suministros_industriales -> [nan]
# Importer: industria_acuicola_vikas_cia_ltda -> ['los_demás', 'hélices_para_barcos_y_sus_paletas']
# Importer: industria_arrocera_portilla_s.a._portiarroz -> ['los_demás']
# Importer: industrial_pesquera_santa_priscila_s.a. -> ['de_potencia_inferior_a_30_kw_(40_hp)', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: industrial_y_comercial_bohtri_s.a. -> ['los_demás']
# Importer: industrias_biosem_indbiosem_s.a. -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: industrias_reunidas_cia._ltda._indunidas_laboratorios_indunidas -> ['los_demas', 'los_demás', 'los_demÿs', nan]
# Importer: ingemedica_del_ecuador_s.a. -> ['partes_y_accesorios,_no_expresados_ni_comprendidos_en_otra_parte_de_este_capitulo,_para_maquinas,_aparatos,_instrumentos_o_articulos_90']
# Importer: ingenieria_de_seguridad_e_incendios_levo_cia._ltda. -> [nan]
# Importer: ingenieria_y_servicios_ambientales_s.a._isasa -> ['los_dem\xa0s', 'los_demás', 'máquinas_para_tratamiento_de_aguas_residuales']
# Importer: inmuebles_motores_&_equipos_inmeq_s._c._c. -> ['las_demás_gradas_(rastras),_escarificadores_y_extirpadores']
# Importer: intedecam_s.a. -> [nan]
# Importer: interandi_de_construcciones_ca -> ['las_demµs']
# Importer: intertubep_s.a. -> ['los_demás']
# Importer: islas_galapagos_turismo_y_vapores_ca -> [nan]
# Importer: japosa_s.a. -> ['aparatos_auxiliares_para_las_calderas_de_las_partidas_84.02_u_84.03']
# Importer: jaramillo_jaramillo_max_yoner -> ['los_demás']
# Importer: jarcelmar_cia_ltda -> ['los_demas', 'maquinas_cosechadoras_automÿticas_para_el_sector_acuicola']
# Importer: karaste_s.a. -> ['los_demás', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: la_birreria_bar_restaurante_brlb_c.a. -> ['muestras_sin_valor_comercial']
# Importer: la_llave_s.a._de_comercio -> [nan]
# Importer: laar_courier_express_s.a. -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)']
# Importer: laarcourier_express_s.a. -> ['paquetes_por_correos_rµpidos_(mensajeröa_acelerada_o_courier)', 'paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)', nan]
# Importer: lacasaconalma_s.a. -> ['los_demás_(aplica_para_vajillas_en_vidrio_y_en_vitrocerámica,_y_recipientes_de_vidrio_destinados_a_estar_en_contacto_con_alimentos._rte_inen_200_(1r)_vigencia_19/10/2015.)']
# Importer: lagos_lake_alejandro_andre -> ['articulos']
# Importer: larvanorte_s.a. -> ['los_demás']
# Importer: latin_travel_cia._ltda. -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)._0%_y_$0,00_solamente_para_paquetes_en_los_que_el_consignante_sea_un_ecuatoriano_residente_en_el_exterior,_hasta_un_máximo_de_12_paquetes_por_año_o_usd_2,400.00,_lo_que_suceda_primero.']
# Importer: lavilista_s.a. -> ['bombas_de_vacío', 'los_demás', nan]
# Importer: legatorie_s.a. -> [nan]
# Importer: li_hui -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: limbomar_s.a. -> ['los_demas', 'las_demas']
# Importer: lin_xiaoyong -> ['partes']
# Importer: loffredo_allan -> [nan]
# Importer: lopez_villavicencio_alexander_antonio -> ['cuya_subpartida_especifica_tenga_un_ad-valorem_menor_o_igual_a_20%']
# Importer: luthorcorp_s.a. -> [nan]
# Importer: macromoda_s.a. -> [nan]
# Importer: maldonado_gamboa_henrry_marcelo -> [nan]
# Importer: mamut-equip_cia.ltda. -> ['las_demas', 'las_demás']
# Importer: maquinarias_y_vehiculos_s.a._mavesa -> ['los_demas', 'solamente_para_pisos_para_autos', 'los_demás', 'las_demás', nan]
# Importer: martrus_didimo -> [nan]
# Importer: maxiriego_s.a. -> [nan]
# Importer: mejia_alcivar_jose_fernando -> ['los_demas', 'los_demás']
# Importer: menier_s_a -> ['los_demas']
# Importer: mexichem_ecuador_s.a. -> [nan]
# Importer: milplast_cia._ltda -> [nan]
# Importer: monegal_cia._ltda. -> ['canillas_o_grifos_para_uso_doméstico']
# Importer: moreno_melo_patricio_ivan -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)']
# Importer: morera_s.a. -> ['los_demás']
# Importer: mundigroup_s.a. -> [nan]
# Importer: muñoz_bonilla_carlos_mauricio -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: nadeu_s.a. -> [nan]
# Importer: nandesa_s.a. -> ['canillas_o_grifos_para_uso_doméstico']
# Importer: naturisa_s._a. -> [nan]
# Importer: negocios_automotrices_neohyundai_s.a. -> [nan]
# Importer: negocios_cesch_cia._ltda. -> [nan]
# Importer: nieto_montoya_gabriel_fernando -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)']
# Importer: nivicela_gonzalez_wilson_jonathan -> [nan]
# Importer: nortverde_s.a. -> ['los_demás']
# Importer: ochoa_guevara_oscar_santiago -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)']
# Importer: oleas_rosales_fabio_fernando -> ['los_demás']
# Importer: operadora_y_procesadora_de_productos_marinos_omarsa_s.a. -> [nan]
# Importer: ordoñez_raul -> [nan]
# Importer: ortiz_gallardo_brian_anthony -> ['maquinas_cosechadoras_automáticas_para_el_sector_acuicola', 'partes', nan]
# Importer: oslinger_turf_equipment_s.a. -> ['las_demas_maquinas_aparatos_y_artefactos', 'las_demás', 'las_demás_máquinas,_aparatos_y_artefactos', 'los_demás', 'cortatubos,_cortapernos,_sacabocados_y_herramientas_similares']
# Importer: pacetol_s.a. -> ['los_demás']
# Importer: paez_meza_rossana_del_carmen -> ['los_demas']
# Importer: palacios_silva_karen_alicia -> ['los_demás']
# Importer: palacios_solorzano_marcelo_geovanny -> [nan]
# Importer: pedidos_express_pedidosexpress_cia.ltda. -> [nan]
# Importer: pesquera_ugavi_s.a. -> [nan]
# Importer: pinto_esparza_becker_edmundo -> []
# Importer: plasticaucho_industrial_s.a. -> ['partes']
# Importer: polanco_polania_harry_stewaet -> ['elevadores_de_líquidos']
# Importer: ponce_aray_alejandro_humberto -> ['las_demás']
# Importer: pressionmax_s.a. -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: prodigytrading_importaciones_&_exportaciones_s.a. -> [nan]
# Importer: producargo_s.a._productora_de_alcoholes -> []
# Importer: producsol_s.a. -> ['los_demás']
# Importer: productos_metalurgicos_s.a._promesa -> ['los_demÿs', 'los_demás']
# Importer: productos_y_servicios_integrales_tresvicor_s.a. -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar', nan]
# Importer: produmar_s.a. -> ['los_demÿs', 'los_demás', 'partes', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: proveedora_de_maquinaria_varzut_s.a._provamaq -> ['los_demas', 'los_demÿs', 'los_demás', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: provefrut_s.a. -> [nan]
# Importer: qualitymedico_s.a. -> ['los\xa0_demás']
# Importer: quito_castillo_pedro_santiago -> [nan]
# Importer: raidenpower_ecuador_s.a. -> [nan]
# Importer: reboch_network_marketing_cia._ltda. -> ['cuya_subpartida_especifica_tenga_un_ad-valorem_menor_o_igual_a_20%', 'los_demás', nan]
# Importer: recalde_carvajal_juan_carlos -> ['partes']
# Importer: representaciones_tecnicas_y_mantenimiento_retena_sa -> ['las_demás']
# Importer: representaciones_volta_labs_voltalabsecuador_cia.ltda. -> ['las_demás']
# Importer: rey_del_mar_reymar_s_a -> ['los_demas']
# Importer: riocargo_express_s.a. -> [nan]
# Importer: rios_vivar_jaime_gustavo -> [nan]
# Importer: rodas_zamora_jimmy_paul -> []
# Importer: rodriguez_borja_mario_ramiro -> [nan]
# Importer: ron_jarrin_maria_del_carmen -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)']
# Importer: rooster_s.a. -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: ruiz_abarca_angy_melissa -> ['para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: salcedo_rojas_mirian_guadalupe -> [nan]
# Importer: santechasist_s.a. -> [nan]
# Importer: satukin_s.a. -> ['los_demás', nan]
# Importer: seatec_s.a._servicios_tecnologicos_para_acuacultura_s.a. -> ['bombas_de_vacio', 'bombas_de_vacío', 'las_demás', 'los_demás']
# Importer: segarra_aguilar_luis_antonio -> ['los_demas']
# Importer: semillas_e_insumos_agropecuarios_semagro_s.a. -> [nan]
# Importer: servicios_integrados_nannan_petroleo_nannanservicios_s.a. -> [nan]
# Importer: sesingaqua_s.a. -> ['los_demás']
# Importer: silva_morales_ulises_fernando -> ['paquetes_por_correos_rápidos_(mensajería_acelerada_o_courier)']
# Importer: sociedad_civil_proaqua_y_cia -> ['los_demás']
# Importer: sociedad_de_hecho_simexpo -> ['los_demás']
# Importer: soluciones_aquicolas_s.a._soluaqua -> ['máquinas_para_tratamiento_de_aguas_residuales']
# Importer: soluciones_globales_&_representaciones_alpheratz_cia._ltda. -> ['los_demas']
# Importer: soluciones_integrales_de_gerencia_de_riesgos_c.a._soinger -> ['los_demás']
# Importer: soluciones_tecnologicas_electricas_e_industriales_soltecelind_s.a. -> ['de_potencia_inferior_a_30_kw_(40_hp)', 'para_mezclar,_amasar_o_sobar,_quebrantar,_triturar,_pulverizar,_cribar,_tamizar,_homogeneizar,_emulsionar_o_agitar']
# Importer: soluinmaq_soluciones,_insumos_y_maquinarias_s.a. -> ['los_demás', 'partes', '"los_demas_(solo_para_aquellas_mercancías_diferentes_a_""pernos_de_cabeza_de_botón_oval_y_sus_tuercas""_no_inen)"', nan]
# Importer: south_florida_farming_floridafram_s.a. -> [nan]
# Importer: storemachines_cia._ltda. -> ['los_demás']
# ...
# Importer: comercializadora_gnimport_s.a. -> ['wamgroup', 'export_wamgroup', 'wam']
# Importer: comercializadora_visual_technology_vistechsa_s.a. -> ['zhengzhou', 'generico']
# Importer: compania_beagle_trade_kapav_s.a. -> ['generico']
# Importer: compania_tecnohidro_s.c.c. -> ['generico']
# Importer: compañia_anonima_practicasa -> ['hansgrohe']
# Importer: compañia_camaronera_ferasa_s.a. -> ['generico']
# Importer: compañia_de_equipamiento_electrico_industrial_eein_s.a. -> ['plastim']
# Importer: compañia_importadora_&_comercial_la_constanza_impcomtanza_s.a. -> ['generico']
# Importer: conauto_c.a. -> ['walker-aireadores', 'walker', 'annex']
# Importer: constructora_daobang_s.a._condao -> ['generico']
# Importer: consultcommerce_s.a. -> ['generico']
# Importer: controlenergy_s.a. -> ['matest']
# Importer: coral_ramos_henry_javier -> ['generico']
# Importer: corporacion_favorita_c.a. -> ['vacu_vin']
# Importer: corporacion_lanec_s.a. -> ['generico']
# Importer: corporacion_nexum_nexumcorp_s.a. -> ['peugeot']
# Importer: correa_rojas_gabriela_alejandra -> ['generico']
# Importer: cosumisa_s.a. -> ['generico']
# Importer: crustaceos_&_peces_de_sud_america_s_a_crupesa -> ['generico', 'nanrong']
# Importer: cruz_garces_pablo_vinicio -> ['zhejiang']
# Importer: cunas_leon_dario_xavier -> ['generico']
# Importer: dahik_ayoub_mario_alejandro -> ['generico']
# Importer: darsacom_s.a. -> ['generico']
# Importer: delanan_desarrollo_langostinero_s_a -> ['generico']
# Importer: delicamaronera_s.a -> ['beraqua', 'generico']
# Importer: desconocido -> ['yiwu_deming_import_and_export_co_ltd', 'generico']
# Importer: dieselmotores_s.a. -> ['generico']
# Importer: dimpofer_cia._ltda. -> ['yetka']
# Importer: disibis_s.a. -> ['feng_min']
# Importer: distribuidora_acuicola_megasupplydelecuador_sociedad_anonima. -> ['generico', 'weemag']
# Importer: disupplier_s.a. -> ['dglobal']
# Importer: diteca_s.a. -> ['bomag']
# Importer: dolca_s.a. -> ['swan', 'generico', 'aire-o2', 'sun_asia_aeration', 'hp', 'newterra']
# Importer: drake_raymond_cecil -> ['generico']
# Importer: ecoltec_s.a. -> ['generico']
# Importer: ecuatoriana_de_motores_motorec_cia._ltda. -> ['dongfeng']
# Importer: ecubel_latinoamerica -> ['generico']
# Importer: ecugrow_representaciones_s.a.s -> ['generico']
# Importer: ecumix_s.a. -> ['wamgroup']
# Importer: edesa_s._a. -> ['generico']
# Importer: edesa_s.a -> ['generico']
# Importer: edesa_s.a. -> ['generico']
# Importer: edesa_sa -> ['_uniones_articuladas)"', 'generico']
# Importer: eductrade_s.a. -> ['generico']
# Importer: el_morro_s.a._morrocal -> ['generico']
# Importer: electro_diesel_ecuatoriana_dieselectro_s.a. -> ['generico']
# Importer: electrofaype_s.a. -> ['generico']
# Importer: elicrom_cia._ltda. -> ['amazon']
# Importer: emcamex_s_a -> ['generico']
# Importer: empacadora_del_pacifico_sociedad_anonima_(edpacif_s.a.) -> ['team_aqua']
# Importer: empacadora_grupo_granmar_s.a._empagran -> ['generico']
# Importer: empresa_aquashrimps_s_a -> ['generico']
# Importer: empresa_publica_correos_del_ecuador_cde_e.p. -> ['generico']
# Importer: empresa_publica_municipal_de_telecomunicaciones,_agua_potable,_alcantarillado_y_saneamiento_de_cuenca_-_etapa_ep -> ['xylem_water_solutions']
# Importer: empresa_p‚blica_correos_del_ecuador_e.p. -> ['generico']
# Importer: energy_&_palma_energypalma_s.a. -> ['vr_ingenieria']
# Importer: escobar_brayan -> ['generico']
# Importer: escobar_robles_juan_hipolito -> ['generico']
# Importer: eslive_s.a. -> ['generico', 'hung_star', 'aquablue', 'aqua']
# Importer: espindola_estrada_roberto_arturo -> ['generico']
# Importer: espinosa_aguirre_jose_fernando -> ['generico']
# Importer: espinosa_valverde_jorge_fabricio -> ['generico']
# Importer: espinoza_guillermo -> ['generico']
# Importer: estefan_cid_rodrigo_elias -> ['pulltex']
# Importer: euro_dealer_s.c.c.i. -> ['checorepuestos']
# Importer: eurogress_s.a. -> ['webert']
# Importer: expresito_carga_s.a._exca -> ['generico']
# Importer: f.v._-_area_andina_s.a. -> ['fv', 'neoperl']
# Importer: f.v._area_andina_s.a -> ['generico']
# Importer: f.v._area_andina_s.a. -> ['generico']
# Importer: f.v_-_area_andina_s.a. -> ['generico', 'fv', 'neoperl', 'neoperl_italia_srl_a', 'nepoerl', 'metico', 'firstkink', 'neoperl_italia', 'firstlink']
# Importer: ferremundo_s.a. -> ['krauss']
# Importer: ferromaqyimport_s.a. -> ['generico']
# Importer: fizamaq_cia._ltda. -> ['generico']
# Importer: flyexpress_s.a. -> ['generico']
# Importer: franco_maria -> ['generico']
# Importer: freire_hernandez_nixon_fabian -> ['generico']
# Importer: fuentes_espinoza_pablo_gustavo -> ['generico']
# Importer: galarraga_vinueza_jorge_eduardo -> ['generico']
# Importer: galvez_fernando -> ['generico']
# Importer: geomil_george_mileni_s.a. -> ['generico']
# Importer: global_interprice_courier_intercourier_s.a. -> ['generico']
# Importer: godproex_productora_y_exportadora_s.a. -> ['generico']
# Importer: goldenshrimp_s_a -> ['generico']
# Importer: gonzaga_bustamante_ramiro_alexander -> ['generico']
# Importer: granjas_marinas_doble_a_gramada_s.a. -> ['generico']
# Importer: grifec_griferias_del_ecuador_s.a. -> ['krauss']
# Importer: grupo_degfer_cia._ltda. -> ['maofmadan']
# Importer: grupocamaron_s.a.s. -> ['generico']
# Importer: guevara_vargas_cristina_alexandra -> ['generico']
# Importer: guzman_bustamante_juan_carlos -> ['generico']
# Importer: haro_ochoa_jenny_del_carmen -> ['gimenez_and_cia_ltda']
# Importer: he_jinsheng -> ['generico']
# Importer: hestia-g_s.a. -> ['hongteng']
# Importer: hidalgo_salguero_david_ivan -> ['mercedes_original', 'vannucci']
# Importer: hidmol_s.a. -> ['annex']
# Importer: hidroinstalaciones_y_servicios_afines_hidrosa_s.a. -> ['paffoni']
# Importer: hormigonera_equinoccial,_equihormigonera_cia._ltda. -> ['export_wamgroup_llc']
# Importer: hormigones_del_valle_s.a._hormivalle -> ['blake_inc']
# Importer: horticoop_andina_s.a. -> ['biron_grow_solutions']
# Importer: hydroazul -> ['generico']
# Importer: imnac_importadora_nacional_cia._ltda. -> ['dutch_creative_brands', 'dutch_creative']
# Importer: imporparis_s.a. -> ['aquarame']
# Importer: import_green_power_technology,_equipment_&_machinery_item_s.a -> ['wangfa', 'generico']
# Importer: importacion_y_comercializacion_de_envases,_empaques_y_quimicos_soñarimport_s.a. -> ['soñar_import']
# Importer: importadora_aguilar,_garzon_imagga_s.a. -> ['generico']
# Importer: importadora_ecuasino_s.a. -> ['generico']
# Importer: importadora_formosa_s.a._informo -> ['generico']
# Importer: importadora_golden_bird_s.a._imporbird -> ['generico']
# Importer: importadora_lino_gamboa_cia._ltda._ilga -> ['generico', 'shuangqiao', 'ilga', 'fudu', 'sinmarca', 'haikai', 'jiangsu']
# Importer: importadora_murgueytio_yepez_cia._ltda. -> ['bcg_builders']
# Importer: importadora_proqualia_improqualia_s.a. -> ['generico']
# Importer: importadora_qaba_s.a. -> ['generico']
# Importer: importadora_qaba_s_a -> ['taizhou', 'generico']
# Importer: importadora_quitio_s.a.s. -> ['generico']
# Importer: importadora_vega_s.a. -> ['borras_griferias']
# Importer: imsuin_cia._ltda._importadora_de_suministros_industriales -> ['generico']
# Importer: industria_acuicola_vikas_cia_ltda -> ['generico']
# Importer: industria_arrocera_portilla_s.a._portiarroz -> ['kepler']
# Importer: industrial_pesquera_santa_priscila_s.a. -> ['beraqua']
# Importer: industrial_y_comercial_bohtri_s.a. -> ['hansgrohe']
# Importer: industrias_biosem_indbiosem_s.a. -> ['generico']
# Importer: industrias_reunidas_cia._ltda._indunidas_laboratorios_indunidas -> ['proenfar']
# Importer: ingemedica_del_ecuador_s.a. -> ['generico']
# Importer: ingenieria_de_seguridad_e_incendios_levo_cia._ltda. -> ['tsurumi']
# Importer: ingenieria_y_servicios_ambientales_s.a._isasa -> ['generico', 'mould']
# Importer: inmuebles_motores_&_equipos_inmeq_s._c._c. -> ['trapp']
# Importer: intedecam_s.a. -> ['generico']
# Importer: interandi_de_construcciones_ca -> ['tri-state']
# Importer: intertubep_s.a. -> ['generico']
# Importer: islas_galapagos_turismo_y_vapores_ca -> ['generico']
# Importer: japosa_s.a. -> ['generico']
# Importer: jaramillo_jaramillo_max_yoner -> ['generico']
# Importer: jarcelmar_cia_ltda -> ['pioneer']
# Importer: karaste_s.a. -> ['generico', 'changfa', 'diva']
# Importer: la_birreria_bar_restaurante_brlb_c.a. -> ['generico']
# Importer: la_llave_s.a._de_comercio -> ['cleaver-brooks']
# Importer: laar_courier_express_s.a. -> ['generico']
# Importer: laarcourier_express_s.a. -> ['generico']
# Importer: lacasaconalma_s.a. -> ['muy_import']
# Importer: lagos_lake_alejandro_andre -> ['ps_product_specialties_inc']
# Importer: larvanorte_s.a. -> ['generico']
# Importer: latin_travel_cia._ltda. -> ['generico']
# Importer: lavilista_s.a. -> ['generico']
# Importer: legatorie_s.a. -> ['generico']
# Importer: li_hui -> ['generico']
# Importer: limbomar_s.a. -> ['sun_asia_aeration']
# Importer: lin_xiaoyong -> ['generico']
# Importer: loffredo_allan -> ['generico']
# Importer: lopez_villavicencio_alexander_antonio -> ['generico']
# Importer: luthorcorp_s.a. -> ['sun_asia_aeration', 'diva']
# Importer: macromoda_s.a. -> ['zara']
# Importer: maldonado_gamboa_henrry_marcelo -> ['generico']
# Importer: mamut-equip_cia.ltda. -> ['generico']
# Importer: maquinarias_y_vehiculos_s.a._mavesa -> ['citroen', 'hino', 'bomag', 'generico']
# Importer: martrus_didimo -> ['generico']
# Importer: maxiriego_s.a. -> ['generico']
# Importer: mejia_alcivar_jose_fernando -> ['generico']
# Importer: menier_s_a -> ['generico']
# Importer: mexichem_ecuador_s.a. -> ['generico']
# Importer: milplast_cia._ltda -> ['mould']
# Importer: monegal_cia._ltda. -> ['aquarame']
# Importer: moreno_melo_patricio_ivan -> ['generico']
# Importer: morera_s.a. -> ['generico']
# Importer: mundigroup_s.a. -> ['generico']
# Importer: muñoz_bonilla_carlos_mauricio -> ['generico']
# Importer: nadeu_s.a. -> ['aquarame']
# Importer: nandesa_s.a. -> ['aquarame']
# Importer: naturisa_s._a. -> ['generico']
# Importer: negocios_automotrices_neohyundai_s.a. -> ['hyundai']
# Importer: negocios_cesch_cia._ltda. -> ['generico']
# Importer: nieto_montoya_gabriel_fernando -> ['generico']
# Importer: nivicela_gonzalez_wilson_jonathan -> ['qihong']
# Importer: nortverde_s.a. -> ['magritep']
# Importer: ochoa_guevara_oscar_santiago -> ['generico']
# Importer: oleas_rosales_fabio_fernando -> ['generico']
# Importer: operadora_y_procesadora_de_productos_marinos_omarsa_s.a. -> ['generico', 'mashow']
# Importer: ordoñez_raul -> ['generico']
# Importer: ortiz_gallardo_brian_anthony -> ['changfa', 'generico']
# Importer: oslinger_turf_equipment_s.a. -> ['to', 'toro', 'generico']
# Importer: pacetol_s.a. -> ['rui']
# Importer: paez_meza_rossana_del_carmen -> ['peugeot', 'af']
# Importer: palacios_silva_karen_alicia -> ['generico']
# Importer: palacios_solorzano_marcelo_geovanny -> ['generico']
# Importer: pedidos_express_pedidosexpress_cia.ltda. -> ['generico']
# Importer: pesquera_ugavi_s.a. -> ['rodapin']
# Importer: pinto_esparza_becker_edmundo -> ['generico']
# Importer: plasticaucho_industrial_s.a. -> ['sycsa']
# Importer: polanco_polania_harry_stewaet -> ['oxipez']
# Importer: ponce_aray_alejandro_humberto -> ['generico']
# Importer: pressionmax_s.a. -> ['generico']
# Importer: prodigytrading_importaciones_&_exportaciones_s.a. -> ['generico']
# Importer: producargo_s.a._productora_de_alcoholes -> ['generico']
# Importer: producsol_s.a. -> ['generico']
# Importer: productos_metalurgicos_s.a._promesa -> ['generico', 'paolo']
# Importer: productos_y_servicios_integrales_tresvicor_s.a. -> ['generico']
# Importer: produmar_s.a. -> ['sun_asia_aeration', 'diva']
# Importer: proveedora_de_maquinaria_varzut_s.a._provamaq -> ['generico']
# Importer: provefrut_s.a. -> ['generico']
# Importer: qualitymedico_s.a. -> ['airplus']
# Importer: quito_castillo_pedro_santiago -> ['aerator', 'generico']
# Importer: raidenpower_ecuador_s.a. -> ['taizhou_qihong_electrical_mechanical_co_ltd']
# Importer: reboch_network_marketing_cia._ltda. -> ['generico', 'pugliese', 'psa']
# Importer: recalde_carvajal_juan_carlos -> ['hunter']
# Importer: representaciones_tecnicas_y_mantenimiento_retena_sa -> ['ivr']
# Importer: representaciones_volta_labs_voltalabsecuador_cia.ltda. -> ['generico']
# Importer: rey_del_mar_reymar_s_a -> ['generico']
# Importer: riocargo_express_s.a. -> ['generico']
# Importer: rios_vivar_jaime_gustavo -> ['generico']
# Importer: rodas_zamora_jimmy_paul -> ['generico']
# Importer: rodriguez_borja_mario_ramiro -> ['generico']
# Importer: ron_jarrin_maria_del_carmen -> ['generico']
# Importer: rooster_s.a. -> ['beraqua']
# Importer: ruiz_abarca_angy_melissa -> ['nanrong']
# Importer: salcedo_rojas_mirian_guadalupe -> ['generico']
# Importer: santechasist_s.a. -> ['generico']
# Importer: satukin_s.a. -> ['generico']
# Importer: seatec_s.a._servicios_tecnologicos_para_acuacultura_s.a. -> ['land_sea_distributing_inc.', 'land_n_sea_distributing_inc', 'land_sea_distributing_inc', 'land_n_sea_distribiting', 'generico', 'donovan_marine']
# Importer: segarra_aguilar_luis_antonio -> ['generico']
# Importer: semillas_e_insumos_agropecuarios_semagro_s.a. -> ['james_engineering']
# Importer: servicios_integrados_nannan_petroleo_nannanservicios_s.a. -> ['thomsen']
# Importer: sesingaqua_s.a. -> ['greenheck']
# Importer: silva_morales_ulises_fernando -> ['generico']
# Importer: sociedad_civil_proaqua_y_cia -> ['dj', 'd&j']
# Importer: sociedad_de_hecho_simexpo -> ['buluna_international_trading_co_limited']
# Importer: soluciones_aquicolas_s.a._soluaqua -> ['evoqua']
# Importer: soluciones_globales_&_representaciones_alpheratz_cia._ltda. -> ['taizhou_wangfa_machinery_electric_co_ltd']
# Importer: soluciones_integrales_de_gerencia_de_riesgos_c.a._soinger -> ['generico']
# Importer: soluciones_tecnologicas_electricas_e_industriales_soltecelind_s.a. -> ['generico']
# Importer: soluinmaq_soluciones,_insumos_y_maquinarias_s.a. -> ['sagar', 'generico']
# Importer: south_florida_farming_floridafram_s.a. -> ['generico']
# Importer: storemachines_cia._ltda. -> ['generico']
# Importer: svf_ecuador_s.a. -> ['generico', 'svf']
# Importer: tamayo_triviño_jorge_kleber -> ['generico']
# Importer: tecknologistic_s.a. -> ['generico']
# Importer: tecnandina_s.a. -> ['generico', 'proenfar']
# Importer: tecnandina_sa_tensa -> ['generico']
# Importer: tecnificaciones_acuicolas_proqualia_s_a -> ['generico', 'wenling', 'zuma']
# Importer: tecnificaciones_acuícolas_proqualia_s.a. -> ['generico']
# Importer: tecnificaciones_acuícolas_proqualia_s_a -> ['wenling', 'generico']
# Importer: tecnotempe_s.a. -> ['generico']
# Importer: tecnotempe_s_a -> ['generico']
# Importer: tecsagroec_tecnologia_y_soluciones_agropecuarias_s.a.s. -> ['generico']
# Importer: teka_ecuador_s.a. -> ['teka']
# Importer: termal_c._ltda. -> ['generico']
# Importer: torres_jimenez_edgar_jose -> ['premium']
# Importer: torres_osorio_carlos_ignacio -> ['aequipe']
# Importer: torres_ponce_esteban_anibal -> ['generico']
# Importer: totalife_s.a. -> ['generico']
# Importer: toyocosta_s.a. -> ['peugeot']
# Importer: transauto_cia_ltda -> ['amazon']
# Importer: transportes_noroccidental_cia._ltda. -> ['liebherr_colombia_sas']
# Importer: trecx_cia._ltda. -> ['monto']
# Importer: trecx_s.a. -> ['monto']
# Importer: trocopersa_s.a. -> ['socoda']
# Importer: troya_chungata_cesar_leonardo -> ['generico', 'qihong', 'taizhou_qihong_electrical', 'shanghai_pretty', 'pretty']
# Importer: unacem_ecuador_s_a -> ['generico']
# Importer: unicasa_uniherramientas_unicaherr_s.a. -> ['generico', 'pentrilo']
# Importer: union_cementera_nacional_ucem_s.a. -> ['generico']
# Importer: valverde_lopez_alexis_ricardo -> ['generico']
# Importer: velez_ruperti_xavier_andres -> ['generico']
# Importer: villagomez_gonzalez_xavier_cristobal -> ['generico']
# Importer: villavicencio_quizhpi_ruth_priscila -> ['ningbo', 'generico']
# Importer: vinueza_andrade_jonathan_oswaldo -> ['generico']
# Importer: viprencar_s.a. -> ['wuxi_longway']
# Importer: wartsila_ecuador_s.a. -> ['wartsila']
# Importer: wen_shengwei -> ['hubei', 'generico']
# Importer: weng_xiujuan -> ['generico']
# Importer: workindus_s.a. -> ['generico']
# Importer: yanez_paredes_fredy_willinton -> ['sears']
# Importer: yang_ling_nancy_juliana -> ['generico']
# Importer: yehuda_naor_mizrachi -> ['generico']
# Importer: yu_wen_hsien -> ['generico', 'teco']
# Importer: zambrano_basurto_edgar_freddy -> ['generico']
# Importer: zopeti_s.a. -> ['generico']

# %%
unique_data_path = '/home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/product_data_unique.json'
with open(unique_data_path, 'w') as json_file:
    json.dump(unique_data, json_file, indent=4)

# Confirm save
print(f"Unique data saved to {unique_data_path}")
# Out:
# Unique data saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/product_data_unique.json

# %%
import csv
import os

# Path to the cleaned and unique JSON data
json_data_path = '/home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/product_data_unique.json'

# Path to save the CSV files
csv_output_path = '/home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/'

# Load the cleaned JSON data
with open(json_data_path, 'r') as json_file:
    data = json.load(json_file)

# Function to save each field as a separate CSV file with dynamic columns
def save_as_csv(data, output_path):
    # Create output directory if it doesn't exist
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    # Iterate over each field in the data
    for field, importers in data.items():
        # Find the maximum number of entries for any importer in this field
        max_entries = max(len(values) for values in importers.values())
        
        # Create column headers for each entry: 'telefono_1', 'telefono_2', ..., 'telefono_n'
        headers = ['Importer'] + [f"{field}_{i+1}" for i in range(max_entries)]
        
        # Define the CSV filename based on the field name
        csv_filename = f"{field}.csv"
        csv_filepath = os.path.join(output_path, csv_filename)

        # Open the CSV file for writing
        with open(csv_filepath, 'w', newline='', encoding='utf-8') as csv_file:
            writer = csv.writer(csv_file)
            
            # Write the header row
            writer.writerow(headers)
            
            # Write the rows for each importer
            for importer, values in importers.items():
                # Pad the values with 'nan' if there are fewer values than the maximum
                padded_values = values + ['nan'] * (max_entries - len(values))
                writer.writerow([importer] + padded_values)
        
        print(f"CSV file for '{field}' saved to {csv_filepath}")

# Save each field as a separate CSV
save_as_csv(data, csv_output_path)
# Out:
# CSV file for 'telefono' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/telefono.csv
# CSV file for 'agencia_de_transporte' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/agencia_de_transporte.csv
# CSV file for 'email' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/email.csv
# CSV file for 'direccion' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/direccion.csv
# CSV file for 'descripcion_arancelaria' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/descripcion_arancelaria.csv
# CSV file for 'pais_de_origen' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/pais_de_origen.csv
# CSV file for 'us$_fob' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/us$_fob.csv
# CSV file for 'agencia_de_carga' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/agencia_de_carga.csv
# CSV file for 'modelo_mercaderia' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/modelo_mercaderia.csv
# CSV file for 'marca_comercial' saved to /home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/marca_comercial.csv
