# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df_aerators = pd.read_csv('/home/luisvinatea/Data/Gdrive/BERAQUA/docs/datasets/csv/imp_aireadores_2010-2023.csv')

# Convert the 'fecha' column to datetime
df_aerators['fecha'] = pd.to_datetime(df_aerators['fecha'], format='%Y-%m-%d')

# Print the DataFrame's data types
print(df_aerators.dtypes)

# Print descriptive statistics
print(df_aerators.describe())

# Print the shape of the DataFrame
print(df_aerators.shape)
# Out:
# fecha                             datetime64[ns]
# partida_arancelaria                        int64
# producto                                  object
# ruc_importador                             int64
# probable_importador                       object
# email                                     object
# refrendo                                  object
# regimen_aduanero                          object
# pais_de_embarque                          object
# puerto_de_embarque                        object
# via_de_transporte                         object
# aduana                                    object
# nave                                      object
# empresa_de_transporte                     object
# dau                                      float64
# advalorem                                float64
# unidades                                 float64
# peso_neto                                float64
# peso_bruto                               float64
# ...

# %%
# Find rows where any column contains specific aerator brands (case-insensitive)

df_diva = df_aerators[df_aerators.apply(lambda row: row.astype(str).str.contains(r'diva', case=False, regex=True).any(), axis=1)]
df_beraqua = df_aerators[df_aerators.apply(lambda row: row.astype(str).str.contains(r'beraqua', case=False, regex=True).any(), axis=1)]
df_taiwan = df_aerators[df_aerators.apply(lambda row: row.astype(str).str.contains(r'taiwan', case=False, regex=True).any(), axis=1)]
df_maofmadan = df_aerators[df_aerators.apply(lambda row: row.astype(str).str.contains(r'maofmadan', case=False, regex=True).any(), axis=1)]
df_diesel = df_aerators[df_aerators.apply(lambda row: row.astype(str).str.contains(r'diesel', case=False, regex=True).any(), axis=1)]
df_india = df_aerators[df_aerators.apply(lambda row: row.astype(str).str.contains(r'india', case=False, regex=True).any(), axis=1)]
df_electrico = df_aerators[df_aerators.apply(lambda row: row.astype(str).str.contains(r'electrico', case=False, regex=True).any(), axis=1)]
df_generico = df_aerators[df_aerators.apply(lambda row: row.astype(str).str.contains(r'generico', case=False, regex=True).any(), axis=1)]
df_china = df_aerators[df_aerators.apply(lambda row: row.astype(str).str.contains(r'china', case=False, regex=True).any(), axis=1)]
